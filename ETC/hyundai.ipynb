# %% [markdown]
# https://talent.hyundai.com/apply/applyView.hc?recuYy=2024&recuType=N2&recuCls=25
#
# * 조직소개
# ■ 커머스, 웹/앱 등 대고객서비스를 비롯한 당사 전반의 IT시스템 및 데이터의 전략을 수립하고,
#   모빌리티의 기반이 되는 서비스와 플랫폼을 구축/관리하고 있습니다.
#
# ■ 전사/글로벌 데이터에 대한 관리정책을 명확히 하고, 기준정보와 같은 핵심 데이터를
#   자산화/표준화하여 데이터 품질 확보 및 활용성을 제고합니다.
#
#
# * 직무상세
# ■ 전사 데이터모델 표준화 및 메타데이터 관리 시스템 운영
#    • DBMS로 관리되는 데이터에 대한 표준 관리 항목 선정 및 데이터표준사전 관리
#    • 데이터 오브젝트 변경 관리를 통한 표준 운영
#    • 레거시 시스템에 대한 데이터모델 자산화
#
# ■ 데이터 모델링
#    • 전사 아키텍처(Enterprise Architecture)에 입각한 데이터 아키텍처 설계
#    • 주요 비즈니스에 대한 표준 데이터 모델 선정 및 가이드
#    • IT시스템의 데이터 모델 설계 및 구축, 운영 (논리/물리 모델)
#
# ■ 기준정보 표준화
#    • 전사 기준정보를 식별하고 기준정보의 구조 및 값에 대한 표준화
#    • 전사 공통코드 표준화 및 관리
#
# ■ 데이터 품질관리
#    • 데이터 품질관리 항목 및 기준 선정 (DQI, CTQ)
#    • 데이터 관리 업무규칙(BR) 정의 및 데이터 품질 관리
#
#
# * 지원자격
#    • 데이터 아키텍트(Data Architect) 업무를 5년 이상 수행하신 분
#    • 데이터를 활용한 판매, 고객, 상품 등 혁신 과제 업무 경험을 보유하신 분
#    • IT시스템/데이터 개발 체계 및 프로세스, 시스템 구성 등에 대한 전반적인 지식을 보유하신 분
#
#
# * 우대사항
#    • DAP, DAsP, SQLP, SQLD 등 데이터 관련 자격증을 보유하신 분
#    • 대량의 데이터를 취급하는 국내/외 기업 또는 기관에서 3년 이상 근무 경력을 보유하신 분
#    • 기준정보(MDM) 정의/수립/설계 관련 경력을 보유하신 분
#    • 차세대 프로젝트에서 데이터모델러 직무로 데이터모델링을 직접 수행하신 분
#    • 데이터 아키텍처(DA) 설계 공모대전 수상 이력을 보유하신 분
#
#
# * 전형단계
#    1. 지원서 접수
#    2. 서류전형
#    3. 면접전형
#    4. 채용검진
#    5. 최종합격
#
#
# * 기타
# [기타 유의사항]
# • 필요 시 별도의 추가 과제가 있을 수 있습니다.
# • 본 공고는 지원서 제출 순서에 따라 전형이 진행되며, 상세 일정은 전형 별 합격자에 한하여 개별 안내 드릴 예정입니다. (채용 완료 시 공고가 조기 종료될 수 있습니다.)
# • 지원서의 내용이 사실과 다르거나 문서로 증빙이 불가할 경우 합격이 취소되거나 전형상의 불이익을 받을 수 있습니다.
# • 최종 합격 후, 회사가 지정하는 입사일에 입사 불가할 경우 합격이 취소되거나 전형상의 불이익을 받을 수 있습니다.
# • 해외여행에 결격 사유가 있는 분(남성의 경우, 회사가 지정한 입사일까지 병역 미필 또는 병역 면제되지 않은 분 포함)은 합격이 취소되거나 전형상 불이익을 받을 수 있습니다.
# • 회사 내규상 정상근무가 불가능할 경우 합격이 취소되거나 전형상의 불이익을 받을 수 있습니다.
# • 채용 전형 진행에 따라 일정이 조정될 수 있는 점 유의 바랍니다.
#
# [지원자 참고사항]
# • 취업보호대상자(장애,보훈 등)는 관계 법령에 의거하여 우대합니다.
# • 지원서 접수 마감일에는 지원자가 대거 몰려 입사지원이 어려울 수 있으니, 여유있게 미리 제출하시기를 권장합니다.
# • 지원서 접수는 현대자동차 채용 홈페이지를 통해 접수하며, 그 외의 개별 접수는 받지 않습니다.
# • 공고 내 직급 수준은 예상 직급으로 변동 가능성이 있으며, 개인별 경력 및 평가를 고려하여 처우협의 과정을 통하여 최종 확정됩니다.
# • 채용 관련 문의는 채용 홈페이지 內 [FAQs] 메뉴를 확인하시거나 '1:1 문의하기'를 이용바랍니다.

# %% [markdown]
# https://talent.hyundai.com/apply/applyView.hc?recuYy=2023&recuType=N2&recuCls=230
#
# * 조직소개
# ■ 커머스, 웹/앱 등 대고객서비스를 비롯한 당사 전반의 IT시스템 및 데이터의 전략을 수립하고,
# 모빌리티의 기반이 되는 서비스와 플랫폼을 구축/관리하고 있습니다.
#
# ■ 전사/글로벌 데이터에 대한 관리정책을 명확히 하고, 기준정보와 같은 핵심 데이터를
# 자산화/표준화하여 데이터 품질 확보 및 활용성을 제고합니다.
#
#
# * 직무상세
# ■ 전사 데이터베이스 모델 표준화 및 운영
#    • 표준 스키마 모델링 도구 선정
#    • DBMS로 관리되는 데이터에 대한 표준 관리 항목 선정 및 데이터 카탈로그 관리
#    • 데이터 오브젝트 변경 관리를 통한 표준 운영
#
# ■ 데이터 모델링
#    • 전사 아키텍처(Enterprise Architecture)에 입각한 데이터 아키텍처 설계
#    • 주요 비즈니스에 대한 표준 데이터 모델 선정 및 가이드
#    • IT시스템의 데이터 모델 설계 및 구축, 운영 (논리/물리 모델)
#
# ■ 데이터 품질관리
#    • 기준 데이터 선정 및 관리
#    • 데이터 품질관리 항목 및 기준 선정 (DQI, CTQ)
#    • 데이터 관리 업무규칙(BR) 정의 및 데이터 품질 관리
#
#
# * 지원자격
#    • 데이터 아키텍트(Data Architect) 업무를 5년 이상 수행하신 분
#    • 데이터를 활용한 판매, 고객, 상품 등 혁신 과제 업무 경험을 보유하신 분
#    • IT시스템/데이터 개발 체계 및 프로세스, 시스템 구성 등에 대한 전반적인 지식을 보유하신 분
#
#
# * 우대사항
#    • DAP, DAsP, SQLP, SQLD 등 빅데이터 관련 자격증을 보유하신 분
#    • 대량의 데이터를 취급하는 국내/외 기업 또는 기관에서 3년 이상 근무 경력을 보유하신 분
#    • 기준정보(MDM) 정의/수립/설계 관련 경력을 보유하신 분
#    • DBA 경력을 보유하신 분
#    • 차세대 프로젝트에서 데이터모델러 직무로 데이터모델링을 직접 수행하신 분
#    • 데이터 아키텍처(DA) 설계 공모대전 수상 이력을 보유하신 분
