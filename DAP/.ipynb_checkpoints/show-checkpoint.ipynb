# %% [markdown]
# https://creco.today/about

# %% [markdown]
#         - 21년 1월 회원개편, aml, 모델링
#         - 21년 2월 회원개편, aml, fido생체인증 모델링
#         - 21년 3월 회원개편, aml, 회원api 모델링
#         - 21년 4월 회원개편(개인, 법인, 관계인, kyc인증, 관계), 렌딩서비스, 간편고객
#         - 21년 5월 미사용 테이블 삭제
#         - 21년 6월 공통코드 관리, 법인 세금계산서 솔루션 인터페이스 설계
#         - 21년 7월 코인이중출금 sms 발송, 이상출금관리, 제휴쿠폰그룹
#         - 21년 8월 서비스화이트리스트, 법인 정산집계, 과세시스템, wm서비스
#         - 21년 9월 과세시스템, 트래블룰
#         - 21년 10월 과세시스템, 과세일배치관련
#         - 21년 11월 트래블룰, 탈퇴이관
#         - 21년 12월 과세, 고객확인관리자
#         - 22년 1월 결재프로세스 고도화, abc 프로젝트
#         - 22년 2월 결재프로세스 고도화, abc 프로젝트, 버티카 ods 테이블 관리

# %% [markdown]
# - 프로젝트명: 가상화폐 거래소 비즈니스 파악 (수행기간: 2020.10 ~ 2020.12)
# - 기술환경: Oracle / ㈜엔코아 솔루션(DA#) / Vertica / TeraStream
# - 수행내역
# 1. 가상화폐 거래소 비즈니스 파악
#     - DA# 리버스 엔지니어링 작업으로 데이터 현황 파악
#     - DA# 논리모델을 통한 비즈니스 파악
#     - 업무 요건에 맞는 데이터 추출 쿼리 확인
#     - 테이블 정의서 확인
# 2. 가상화폐 정보계 데이터 확인
#     - ODS, DW, DM 등 각 영역별 테이블 현황 파악
#     - 기간계 -> 정보계 ETL 로직 현황 파악
# 3. ERD 및 표준 사전 정리
#     - 기간계, 정보계 ERD 최신화 작업 진행
#
# * 성과
#     - ERD 최신화 진행 -> 현행 시스템 및 신규 시스템 개발의 참고 자료 제공

# %% [markdown]
# - 프로젝트명: 특금법 개정에 따른 AML(자금세탁방지) 시스템 구축 프로젝트 (수행기간: 2021.01 ~ 2021.06)
# - 기술환경: Oracle / ㈜엔코아 솔루션(DA#)
# - 수행내역
# 1. AML 관련 데이터 모델 설계
#     - 고객 CDD, EDD, 거래내역 등 AML 시스템 관련 데이터 모델링
#     - 고객, 거래, 자산, 회원체계 개선을 위한 데이터 모델링
# 2. AML 데이터 흐름도 관리
#     - 회원가입부터 AML 고객확인까지 프로세스별 데이터 흐름도 관리
# 3. AML 데이터 이행 작업
#     - 기존 고객 데이터 이행을 위한 SQL 로직 작성
#     - 기간계 및 AML 시스템간 데이터 이행 맵핑 정의서 관리
# * 성과
#     - 회원체계 통합 모델링 -> 데이터 흐름 및 품질 향상으로 데이터 명확성, 활용도 증대

# %% [markdown]
# - 프로젝트명: 가상자산 과세시스템 구축 프로젝트 (수행기간: 2021.07 ~ 2021.12)
# - 기술환경: Oracle / ㈜엔코아 솔루션(DA#)
# - 수행내역
#     - 가상자산 과세시스템 데이터 모델 설계
#         - 거래내역, 과세거래원장, 가상자산잔액 등 과세 시스템 데이터 모델링
#     - 과세 데이터 확인을 위한 비즈니스 룰 로직 설계
#         - 과세 선행 프로세스, 선입선출등 데이터 정합성을 위한 비즈니스 로직 구축
#     - 가상자산 과세를 위한 데이터 마트 설계
#         - 가상자산소득명세, 원천징수, 납부세액 등 과세 서비스를 위한 마트 설계
#
# * 성과
#     * 가상자산 과세시스템 서비스 영역의 표준 사전 및 ERD 구축 -> 정형화된 데이터 관리 및 명확한 의사소통 증대

# %% [markdown]
# - 프로젝트명: 특금법 트래블룰 반영 구축 프로젝트  (수행기간: 2022.01 ~ 2022.03)
# - 기술환경: Oracle / ㈜엔코아 솔루션(DA#)
# - 수행내역
# 1. 트래블룰 관련 데이터 모델 설계
#     - 특금법 규제 적용을 위한 가상자산, 거래소, 개인지갑 등 트래블룰 검증을 위한 데이터 모델링
#     - 트래블룰 입금 및 출금 시스템 프로세스 데이터 모델링
#     - 가상자산 심사 및 반영 프로세스 데이터 모델링
# 2. 트래블룰 데이터 검증 비즈니스 룰 관리
#     - 외부 거래소간 연동 서비스별 데이터 무결성 검증 로직 작성
#     - 외부 출금시 출금한도별 기준 확인 로직 작성

# %% [markdown]
# - 프로젝트명: 메타 관리 시스템 구축 (수행기간: 2022.04 ~ 2022.09)
# - 기술환경: Oracle/ Vertica / ㈜엔코아 솔루션(DA#, META#)
# - 수행내역
# 1. 메타 관리 시스템 구축
#     - 전사 데이터 모델 관리
#         - 기간계, 정보계 모델 관리
#         - 데이터 모델-DBMS 갭 반영 관리
#     - 표준 데이터 사전 구축
#         - 표준 단어, 도메인, 용어, 코드
#         - 각 표준별 명명규칙 수립
#     - 서버간 DBMS 오브젝트 반영 관리
#         - DBMS 오브젝트 반영 및 영향도 관리
# 2. 데이터 모델 및 표준 관리 정책 및 프로세스 수립
#     - 표준 적용 데이터 모델 프로세스 수립 및 운영
#     - 데이터 표준 정의서 작성
#     - DB 오브젝트, 표준 데이터 등록 및 수정 프로세스 정책
# 3. 메타 시스템(META#) 사용자 교육
#
# * 성과
#     - 가상화폐거래소 업무 용어 사전 구축 -> IT, 협업 부서간 의사소통 용어 통일로 업무 혼선 방지
#     - 데이터 모델, 표준 사전 구축 -> 임직원 비즈니스 업무 파악 효과 증대
#     - 데이터 표준 정의서 작성 -> 일관된 데이터 형식 및 규칙의 적용으로 인한 데이터 품질 향상

# %% [markdown]
# - 프로젝트명: 블록체인 입출금 시스템 고도화 (수행기간: 2022.10 ~ 2023.01)
# - 기술환경: Mysql / ㈜엔코아 솔루션(DA#, META#)
# - 수행내역
# 1. 블록체인 데이터 서비스 모델 설계
# 	- AS-IS 블록체인 데이터 서비스 분석
# 		- 블록체인 노드 트랜잭션 탐색 관련
# 		- 트랜잭션 데이터 정형화 관련
# 		- 고객 지갑 주소 입출금 관련
# 	- TO-BE 블록체인 데이터 서비스 모델 설계
# 		- 주제영역 선정(블록체인 네트워크, 코인, 트랜잭션, 지갑주소 등)
# 		- 엔터티 상세화 및 정규화
#     - 데이터 표준 사전 구축 및 데이터 정책 정의
#         - 단어, 도메인, 용어, 코드등의 표준 사전 구축
#         - 데이터 관리 방법, 네이밍룰, 주제영역 정의 등
#
# * 성과
#     - 블록체인 서비스 영역의 표준 사전 및 ERD 구축 -> 정형화된 데이터 관리 및 명확한 의사소통 증대

# %% [markdown]
# **데이터 거버넌스 구축**
# - 시스템 및 전사 표준 가이드 작성
# - 데이터 모델 변경 프로세스 도입
# - 검토 프로세스
#     - 테이블 검토 프로세스
#         - 개발자, DA, DBA로 연결되는 테이블 검토 및 생성 프로세스
#     - 표준 검토 프로세스
#         - 테이블 및 컬럼 생성에 필수 요소인 표준화된 단어, 용어, 도메인을 관리하는 프로세스
#     - 테이블 검토 체크 리스트
#         - 테이블 및 컬럼의 생성 변경 체크 리스트

# %% [markdown]
# ***********************************************
# 1. 프로젝트 개요
# - 프로젝트명
# 	- 입출금 시스템 개편
# - 목적
# 	- 입/출금 시스템의 거래소 분리를 위한 1차 목표인 블록체인 데이터 서비스 프로토타입 구현을 통해
# 	  기존 거래소 시스템에 종속되지 않는 독립적인 입/출금 시스템 설계 방향성 제시
#
# 1.1 프로젝트 배경
# - 기존 거래소 내 구축된 시스템은 거래소 기능과 입출금 시스템 기능에 대한 명확한 분리가 되지 않은 상황임
# 	- 입/출금 시스템 기능에 대한 명확한 분리 및 역할 구분 필요
# 	- 관리 주체가 명확하지 않아 유지 보수 및 개선의 어려움 존재
# 	- 신규 상장 시 거래소 내 소스코드 및 DB에 대한 변경 작업 발생으로 인한 시스템 영향도 문제 발생
# 	- 크론탭을 사용한 스케쥴링 기반의 데이터 처리로 인한 기능적 한계 존재
# - 당사 거래소의 시스템 개선 및 경쟁력 향상을 위해서 거래소 기능과 입출금 시스템 기능의 분리가 필요함
# 	- 각각의 기능에 대한 명확한 R&R 할당을 통해서 업무 효율성 및 생산성 증대 가능
# 	- 거래소 분리 시 입출금 서비스의 성능 향상 뿐만 아니라 향후 사업 다각화를 통한 신규 Biz 수립 가능
# - 거래소 분리를 위해서는 전체 내부 시스템의 아키텍처 전환이 필요하기 때문에 단계적으로 개발 및 전환이 필요함
# 	- 블록체인 네트워크와의 통신하는 데이터 처리 시스템 구축을 시작으로 신규 입출금 시스템 개발, 관련 인터페이스 API 개발 등 점진적인 개발이 필요로 함
# 	- 개발 뿐만 아니라 전체적인 전환을 위한 신규 정책 설계, 사용자 (관리자) 업무 환경 분석 및 개선 등의 작업들이 필요로 함
#
# 1.2 프로젝트 목적 및 기대효과
# - 본 프로젝트의 궁극적인 목표는 입출금 시스템 기능과 거래소 기능의 분리를 통해서 당사의 전체 운영 시스템 개선을 목표로 함
# 	- 프로젝트의 범위가 매우 넓은 만큼 아래 로드맵과 같이 단계별로 프로젝트 진행을 통해 점진적인 전환 예정
# - Phase 1,2 단계: 입출금 시스템 개편
# 	- 목적
# 		- 기존 데몬로그 수집 영역에 대한 현황 분석을 통해 업무 및 기능을 재정의하여 신규 블록체인 데이터 서비스 (가칭) 개발
# 	- 기대효과
# 		- 실시간 데이터 처리 및 처리량 개선
# 		- 입출금 시스템 정책의 유연성 적용
# 		- 네트워크 단위 관리를 통한 Multi-chain 및 다양한 형태의 서비스 제공 가능
# 		- 업무상 필요한 다양한 기능 (Data explorer, Open API) 구현 가능
# - Phase 3 단계: 거래소 분리
# 	- 목적
# 		- 최종 목표인 거래소 기능 분리를 위해 거래소 및 입출금 시스템 간 외부 API 개발
# 	- 기대효과
# 		- 신규 상장 업무에 대한 전반 프로세스 개선 가능
# 		- 가상자산 관련 유지보수 업무 효율성 제고
# 		- 이슈 발생에 대한 기민한 대응 가능
#
# 1.3 고려사항
# - 신규 서비스와의 연동을 위한 기존 입출금 시스템 개편 전략 수립
# 	- 비즈니스 로직 수행 영역을 한 영역으로 집중 필요 (IDC → AWS 전환 구축)
# 	- 기존 콘솔망(CD/CW)는 보안이 중요한 민감한 데이터, 파일의 보관 및 해당 정보를 활용한 기능만을 수행 (집금/출금에 대한 트랜잭션 서명 처리)
# - 기존 레거시 시스템과 병행 운영을 위한 전략 수립
# 	- 레거시 시스템과 병행 운영을 통해 안정적이고 점진적으로 시스템 개편 전환 필요
# 	- 기존 레거시 시스템과의 연동을 위한 내부 API 구현 필요
#
#
# ***********************************************
# 블록체인 데이터 서비스
# - 핵심 제공 기능
# 	- 다양한 블록체인 네트워크의 데이터를 비즈니스 요구사항에 맞게 수집하고 처리한다.
# 	- 다양한 블록체인 네트워크에 트랜잭션을 전송 할 수 있다.
# 	- 블록체인 네트워크 관련 기준정보를 관리(코인, 회원 주소, 코인 서버)한다.
# 	- OpenAPI Spec 기반 블록체인 데이터 API 제공
# 	- 블록체인 데이터 로그 모니터링
# 	- 블록체인 노드 모니터링 및 실시간 지표 제공
#
# 주요 Components
# - 카프카 클러스터
# 	- 블록체인 데이터를 수집
# 	- 카프카 스트림즈을 활용하여 카프카에 저장된 데이터를 입/출금 정책에 맞게 처리
# 	- 트랜잭션 전송 요청 건 처리
# - Open API: 블록체인 데이터 및 네트워크 정보 제공을 위한 API 서비스
# - 기분 정보 관리: 블록체인 네트워크 및 서버, 코인, 주소 정보 관리
# - 모니터링 도구: 블록체인 노드 실시간 지표 및 알림 서비스 제공
# - 로그 모니터링: 블록체인 데이터 로그 모니터링
#
#
# ***********************************************
# 입출금 관리 시스템
# - 핵심 제공 기능
# 	- 코인 입/출금 관련된 처리 기능을 제공
# 	- 블록체인 네트워크에 서명된 트랜잭션 요청 처리
# 	- 코인 상세, 회원 주소, 블록체인 노드 정보 등의 기준정보 관리
# 	- 거래소와의 입/출금 관련 데이터 통신을 위한 API 제공
# 	- 입/출금 업무 처리를 위한 관리 페이지
#
# 주요 Components
# - 입금 처리: 입금 관련 프로세스를 처리하는 서비스(블록체인 데이터로부터 발생)
# - 출금 처리: 출금 관련 프로세스를 처리하는 서비스(외부 API로 부터 발생)
# - 집금 처리: 코인 내부 이동(집금)을 위한 기능 제공(내부 작업자에 의해 발생)
# - 트랜잭션 관리: 서명된 트랜잭션 데이터를 관리 및 블록체인 노드로 요청
# - 기준 정보 관리: 코인, 주소, 회원, 블록체인 노드 등의 입출금 시스템 관리를 위한 모든 기준 정보 관리
# - 노티 서비스: 슬랙, 텔레그램, 문자 등의 알람 서비스
# - 카프카 클러스터: 입출금 시스템 내 콘솔망을 통한 이벤트 데이터 처리
# - 외부 API: 거래소 연동을 위한 API 서비스
# 	- 이벤트 기반: 거래소측에서 입출금 시스템 이벤트에 대한 실시간 데이터 처리가 필요한 경우
# 	- REST API: 거래소에서 조회가 필요한 경우
# - 관리 페이지: 기존 B Manage 화면과 유사한 백오피스 기능 제공

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 현대차/기아 고객, 판매 데이터 자산화 프로젝트
#     - 54개 시스템 데이터 프로파일링 수행 및 데이터 표준화, 데이터 모델 현행화 수행 중
# - 현대차/기아 데이터 체계 수립 및 데이터 관리시스템 구축 프로젝트
#     - 데이터 모델링, 데이터 표준화, 데이터 품질관리 등 전사 데이터 관리 체계 수립
#     - 17개 시스템 데이터 프로파일링 수행 및 모델 현행화
#     - 데이터 품질 진단 수행
# - 흥국생명 차세대 마스터 플래닝 프로젝트
#     - 현행 전사 데이터 관리 체계 현황 분석 및 개선 과제 가이드
#     - 11개 시스템에 대해 데이터 프로파일링 수행 및 데이터 품질 진단 수행
# - 한국수자원공사 데이터 관리 체계 수립 및 품질관리시스템 구축 프로젝트
#     - DQC-M 레벨 3 도입에 따른 전사 데이터 관리체계 수립 가이드
#     - 12개 시스템에 대한 데이터 프로파일링 수행 및 데이터 품질 진단
#     - DBMS: Oracle, Tibero, MS-SQL
#     - 모델링툴: DA#, 데이터관리시스템: META#

# %% [markdown]
# /***프로젝트명: 가상화폐 거래소 비즈니스 파악 (수행기간: 2020.10 ~ 2020.12)
# - 기술환경: Oracle / DA#(데이터모델링 툴) / Vertica / TeraStream(ETL 솔루션)
# - 수행내역
#
# 1. 가상화폐 거래소 비즈니스 파악
# 	- DA# 리버스 엔지니어링 작업으로 데이터 구조 파악
# 	- DA# 논리모델을 통한 비즈니스 파악
# 	- 테이블 정의서 및 데이터 추출 쿼리 확인
#
# 2. 가상화폐 정보계 데이터 확인
# 	- ODS, DW, DM 등 각 영역별 테이블 현황 파악
# 	- 기간계 -≫ 정보계 ETL 로직 현황 파악*/
#
#
# /***프로젝트명: 특금법 개정에 따른 AML 시스템 구축 프로젝트 (수행기간: 2021.01 ~ 2021.05)
# - 기술환경: Oracle / DA#(데이터모델링 툴)
# - 수행내역
#
# 1. 데이터 모델 설계
# 	- 특금법 개정에 따른 회원체계 개선 데이터 모델링
# 	- 고객확인, 계좌인증, 자산관리 등
# 	- AML 시스템 데이터 모델링
# 	- STR, KYC, CTR 등 평가항목별 모델 설계
#
# 2. 데이터 흐름도 관리
# 	- 회원가입부터 고객확인까지 프로세스별 데이터 흐름도 관리
#
# 3. 데이터 이행 작성 및 관리
# 	- 기존 고객 데이터 이행을 위한 SQL 로직 작성
# 	- 기간계 및 AML 시스템간 데이터 이행 맵핑 정의서 관리 */
#
#
# /***프로젝트명: 가상자산 과세시스템 구축 프로젝트 (수행기간: 2021.06 ~ 2021.10)
# - 기술환경: Oracle / DA#(데이터모델링 툴)
# - 수행내역
#
# 1. 가상자산 과세시스템 데이터 모델 설계
# 	- 거래내역, 과세거래원장, 가상자산잔액 등 과세 시스템 데이터 모델링
#
# 2. 과세 데이터 확인을 위한 비즈니스 룰 로직 설계
# 	- 과세 선행 프로세스, 선입선출 등 데이터 정합성을 위한 비즈니스 로직 구축
#
# 3. 가상자산 과세를 위한 데이터 마트 설계
# 	- 가상자산소득명세, 원천징수, 납부세액 등 과세 서비스를 위한 마트 설계*/
#
#
# /***프로젝트명: 특금법 규제 적용 트래블룰 서비스 구축 프로젝트 (수행기간: 2021.11 ~ 2022.03)
# - 기술환경: Oracle / DA#(데이터모델링 툴)
# - 수행내역
#
# 1. 데이터 모델 설계
# 	- 트래블룰 관련 데이터 모델 설계
# 		- 가상자산 거래소, 입출금지갑주소, 증빙서류 영역 설계
# 		- 가상자산 입출금 등록 및 유효성 검증 영역 설계
# 		- 트래블룰 결재 및 심사 영역 설계
#
# 2. 트래블룰 데이터 검증 프로세스 관리
# 	- 외부 거래소간 연동 서비스별 데이터 무결성 검증 프로세스 로직 작성
# 	- 트래블룰 정책 심사 프로세스 검증 로직 작성
# 	- 입출금 요청 및 심사 프로세스 검증 로직 작성*/
#
#
# /***프로젝트명: 메타 관리 시스템 구축 (수행기간: 2022.04 ~ 2022.09)
# - 기술환경: Oracle/ Vertica / DA#(데이터모델링 툴) / META#(메타관리시스템)
# - 수행내역
#
# 1. 메타 관리 시스템 구축
# 	- 전사 데이터 모델 관리
# 		- 기간계 논리 & 물리모델 관리
# 		- 정보계 논리 & 물리모델 관리
# 	- DBMS 반영 관리
# 		- 데이터 모델 - DBMS 갭 반영 관리
# 	- 표준 데이터 사전 구축
# 		- 표준 단어, 도메인, 용어, 코드 구축 및 관리
# 		- 각 표준별 명명규칙 수립
# 		- 엔터티 및 속성 분류어 관리
# 	- 서버간 DBMS 오브젝트 반영 및 영향도 관리
# 	- 개인정보 & 암호화 엔터티 및 속성 관리
#
# 2. 데이터 모델 및 표준 관리 정책 및 프로세스 수립
# 	- 표준 적용 데이터 모델 프로세스 수립
# 	- 데이터 표준 정의서 작성
# 	- DB 오브젝트, 표준 데이터 등록 및 수정 프로세스 정책
#
# * 성과
# 	- 가상화폐거래소 업무 용어 사전 구축 -> IT, 협업 부서간 의사소통 용어 통일로 업무 혼선 방지
# 	- 데이터 모델, 표준 사전 구축 -> 임직원 비즈니스 업무 파악 효과 증대
# 	- 데이터 표준 정의서 작성 -> 일관된 데이터 형식 및 규칙의 적용으로 인한 데이터 품질 향상*/
#
#
# /***프로젝트명: 블록체인 입출금 시스템 개편 프로젝트 (수행기간: 2022.10 ~ 2022.12)
# - 기술환경: Mysql / DA#(데이터모델링 툴) / META#(메타관리시스템)
# - 수행내역
#
# 1. 블록체인 데이터 서비스 비즈니스 분석
# 	- 블록체인 네트워크 및 데몬서버 관리 영역
# 	- 블록체인 노드 트랜잭션 탐색 영역
# 	- 암호화폐 지갑주소 관리 영역
#
# 2. 블록체인 데이터 서비스 모델 및 표준 관리
# 	- 주제영역 선정(블록체인 네트워크, 코인, 트랜잭션, 지갑주소 등)
# 	- 데이터 표준 사전 구축 및 데이터 정책 정의
# 		- 단어, 도메인, 용어, 코드등의 표준 사전 구축
# 		- 표준 네이밍 룰, 약어 최대 길이, 도메인그룹 등
#
# * 성과
# 	- 블록체인 데이터 서비스 영역 ERD 및 표준 사전 관리 -> 정형화된 업무 용어로 명확한 의사소통 증대*/
#
#
# /***프로젝트명: 원화 입출금은행 변경 프로젝트 (수행기간: 2023.01 ~ 진행중)
# - 기술환경: Oracle/ DA#(데이터모델링 툴) / META#(메타관리시스템)
# - 수행내역
#
# 1. 비즈니스 영향도 분석
#     - 원화입출금 은행 변경에 따른 영향도 오브젝트 분석
#     - 원화입출금 데이터 흐름도 분석
#
# 2. 데이터 모델 설계
# 	- 다계정 회원 자산통합 신청 및 처리 데이터 모델링
# 	- 신규계좌관리, 타행이체, 지급정지 등 데이터 모델링*/
