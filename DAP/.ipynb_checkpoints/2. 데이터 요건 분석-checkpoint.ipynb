# %% [markdown]
# -------------------------------------------------------------------------------
# # 정보 요구 사항 개요 (p.177)
# * 정보 요구 사항
#    - 정보 요구 사항 생명주기 모형
#       - 도출 -> 분석 및 정의 -> 명세화 -> 검증
#    - 정보 요구 사항 유형
#       - 소프트웨어 사업 요구 사항 분류
#          - 기능, 비기능, 기타
#       - 정보 요구 사항 유형
#          - 외부 인터페이스 요건
#          - 기능 개선 요건
#          - 성능 개선 요건
#          - 보안 개선 요건
# * 정보 요구 사항 관리
#    - 정보 요구 사항 프로세스
#       - 업무 흐름 프로세스
#          - 요구 사항 발송 -> 수렴 -> 검토 -> 분석 -> 공식화 -> 작업 계획 수립
#       - 수행 조직 및 수행 업무
#          - 사용자
#          - 담당자
#          - 데이터 아키텍처 전문가
#
# -------------------------------------------------------------------------------
# # 정보 요구 사항 조사 (p.191)
# * 정보 요구 사항 수집
#    - 정보 요구 사항 수집 형태
#       - 문서 수집
#       - 사용자 면담
#          - 면담조사 종류
#             - 방법
#                - 개인 면담, 집단 면담, 표준화 면담, 비표준화 면담
#             - 방식
#                - 피라미드 구조, 퍼널 구조, 다이아몬드 구조
#          - 사용자 면담 진행
#             - 면담 진행 팀 구성
#                - 면담자, 기록자, 관찰자
#       - 워크숍
#       - 매뉴얼
#       - 산출물
# * 정보 요구 사항 정리
#    - 정보 요구 사항 정리
#       - 사용자 면담 정리, 업무 조사서 정리, 워크숍 정리
#    - 정보 요구 우선순위 분석
#       - 화폐가치 산출 방법
#          - 기업 차원 + 시스템 차원 + 다른 정보 요구 사항 도움
#       - 상대적 중요도 산정 방법
#          - 업무 기여 + 다른 요구 사항 관여 + 현행 정보 요구 사항 충족도
# * 정보 요구 사항 통합
#    - 정보 요구 사항 목록 검토
#    - 정보 요구 사항 목록 통합/분할
#       - 동일 부서 내 중복 요구 사항 검토
#       - 서로 다른 부서 간 중복 요구 사항 검토
#
# -------------------------------------------------------------------------------
# # 정보 요구 사항 분석 (p.217)
# * 분석 대상 정의
#    - 현행 업무 분석 대상 정의
#       - 현행 업무 흐름도, 설명서, 분장 기술서
#    - 현행 시스템 분석 대상 정의
#       - 업무 영역 · 현행 시스템 매트릭스
#       - 평가 기준
#          - 유용성, 완전성, 정확성, 유효성
# * 정보 요구 사항 상세화
#    - 프로세스 관점의 정보 요구 사항 상세화
#       - 프로세스 분해 · 상세화
#          - 단위 업무 기능별
#          - 프로세스 분해
#          - 프로세스 분해 깊이
#          - 프로세스 명칭
#          - 프로세스 계층도
#       - 정보 항목 도출 및 표준화
#          - 기본 프로세스별
#          - 등록(C), 조회(R), 변경(U), 삭제(D)
#       - 정보 항목별 통합성, 분리성 여부 검토
#          - 프로세스별
#          - 전사 관점 통합/분리
#    - 객체지향 관점의 정보 요구 사항 상세화
#       - 유스케이스 다이어그램
#          - 액터
#          - 유스케이스
#          - 액터와 유스케이스 간의 관계
#       - 유스케이스 상세화
#       - 클래스 다이어그램 작성
#
# * 정보 요구 사항 확인
#    - 수행 작업 내용
#       - 재검토 계획 수립
#       - 재검토 실시
#       - 보완 결과 확인
#    - 수행 시 고려 사항
#       - 완전성, 정확성, 일관성, 안정성
#
#
# -------------------------------------------------------------------------------
# # 정보 요구 사항 명세화 (p.237)
# * 정보 요구 사항 명세 정의
#    - 정보 요구 사항 명세 정의
#       - 정보 요구 사항 명세서
#          - 사용자 - 개발자 연결시키는 중요 문서
#          - 사용자와 개발자 간의 계약서
#          - 사용자, 개발자, 테스터 입장
#       - 요구 분석 명세서 작성 시 주의 사항
#          - 쉽게, 효과적, 명확히, 정량적, 품질 우선순위
# * 정보 요구 사항 명세 상세화
#    - 요구 사항 상세내역 작성
#       - 요구 사항 고유번호, 명칭, 분류, 상세설명, 산출정보, 관련 요구 사항
#
# -------------------------------------------------------------------------------
# # 정보 요구 사항 검증 및 변경 관리  (p.247)
# * 정보 요구 사항 검증 정의
#    - 요구 사항 검증 활동
#       - 요구 사항 명세서 검토
#       - 요구 사항 용어 검증
#       - 요구 사항 베이스라인 설정
# * 정보 요구 사항 상관분석 기법
#    - 주체별 분류
#       - 요구 사항 분석가 수행
#       - 품질보증 팀 수행
#       - 외부 감리 수행
#    - 정보 요구 · 애플리케이션 상관분석
#       - 기본 프로세스
#       - C > D > U > R
#    - 정보 요구 · 업무 기능 상관분석
#       - 전사 업무 기능
#       - 생성, 수정, 삭제 == C
#       - 검색 == U
#       - 관련 X == 빈칸
#    - 정보 요구 · 조직 기능 상관분석
#       - 기업 조직
#       - 생성, 수정, 삭제 == C
#       - 검색 == U
#       - 관련 X == 빈칸
# * 추가 및 삭제 정보 요구 사항 도출
#    - 정보 요구 · 애플리케이션 상관분석
#       - 매트릭스 분석
#          - 기본 프로세스 사용, 7개 이상, 생성 등
#    - 정보 요구 · 업무 기능 상관분석
#       - 매트릭스 분석
#          - 한 번 이상 'C', 다른 업무 기능에 의해 사용 'U'
#    - 정보 요구 · 조직 기능 상관분석
#       - 매트릭스 분석
#          - 한 번 이상 'C', 다른 업무 기능에 의해 사용 'U'
# * 정보 요구 사항 변경 관리
#    - 요구 사항 변경 관리 활동
#       - 요구 사항 변경 제어
#       - 요구 사항 추적 제어
#       - 요구 사항 버전 제어

# %% [markdown]
# # 정보 요구 사항 개요 (p.177)
#
#
# * 정보 요구 사항
# 	- 정의
# 		- 현행 시스템 분석
# 		- 사용자 요구 사항 수집
# 		- 제안 요청서
# 		- 사업 수행 계획서
# 		- 요구 사항 유형
# 			- 비즈니스 요구 사항
# 			- 이해관계자 요구 사항
# 			- 해결책 요구 사항
# 				- 기능적 요구 사항
# 				- 비기능적 요구 사항
# 			- 전환 요구 사항
# 			- 프로젝트 요구 사항
# 			- 품질 요구 사항
# 		- 프로젝트 실패 요인
# 			- 계획과 추정 요인
# 			- 실행 요인
# 			- 인간적 요인
# 	- 정보 요구 사항 생명주기 모형
# 		- 요구 사항 개발
# 			- 요구 사항 도출
# 				- 인터뷰, 설문지, 워크숍 등
# 			- 요구 사항 분석·정의
# 				- 요구사항 정리 및 정의
# 			- 요구 사항 명세
# 				- 세밀하게 분석 및 기록
# 			- 요구 사항 검증
# 				- 비즈니스, 조직, 애플리케이션 관점 검증
# 		- 요구 사항 관리
# 			- 요구 사항 변경 요청
# 			- 변경 영향도 분석
# 	- 정보 요구 사항 유형
# 		- 정보 요구 사항 분류
# 			- 기능
# 				- 시스템 기능 개발
# 			- 비기능
# 				- 시스템 원활한 동작 실행, 성능, 프로젝트 관리 및 지원 사항
# 			- 기타
# 				- 시스템 구축 유지관리 사항, 컨설팅, 공사 등
# 		- 데이터 관점 정보 요구 사항 유형
# 			- 외부 인터페이스 요건
# 			- 기능 개선 요건
# 			- 성능 개선 요건
# 			- 보안 개선 요건
#
#
# * 정보 요구 사항 관리
# 	- 정보 요구 사항 관리
# 		- 데이터, 애플리케이션, 비즈니스 등의 요구 사항을 전부 포함하는 통합 관리 프로세스 정립
# 	- 정보 요구 사항 프로세스
# 		- 업무 흐름 프로세스
# 			- 요구 사항 관리
# 				- 요구 사항 발송
# 				- 요구 사항 수렴
# 				- 요구 사항 검토
# 			- 반영 계획 수립
# 				- 영향도 분석
# 					- 설계서, 애플리케이션, 데이터베이스
# 				- 공식화
# 				- 반영 작업 계획 수립
# 		- 수행 조직 및 수행 업무
# 			- 사용자
# 			- 담당자
# 			- 데이터 아키텍처 전문가

# %% [markdown]
# # 정보 요구 사항 조사 (p.191)
#
#
# * 정보 요구 사항 수집
# 	- 정보 요구 사항 수집 형태
# 		- 관련 문서
# 			- 문서 수집 목적
# 				- 구현 시스템의 대상과 범위를 명확하게 정의 및 이해하기 위해
# 			- 문서 수집 자료
# 				- 경영 계획에 대한 자료
# 				- 정보시스템에 대한 자료
# 				- 과거 수행한 컨설팅 보고서
# 				- 전산 처리 업무 매뉴얼
# 				- 현업 부서 업무 자료(실무 교육 자료)
# 				- 문서 수집 대상 문서
# 					- 기업 관련정보
# 					- 업무 양식
# 					- 시스템 관리
# 					- 외부 문서
# 			- 문서 수집 원칙
# 				- 문서를 변형하지 않고 수집, 정보시스템 자료는 별도 정리 양식을 이용
# 				- 문서를 바탕으로 경영 및 정보시스템 현황 요약표 작성
# 				- 문서들은 계획 수립 기간, 문서 관리자 지정 및 운영
# 				- 문서 분류 방식을 결정 -> 일정한 장소에 보관
# 				- 문서는 대외비 성격이 강함 -> 개인별 보관x, 문서 보안 관리 주의
# 		- 사용자 면담
# 			- 사용자 면담 종류
# 				- 면담조사 방법
# 					- 개인 면담
# 					- 집단 면담
# 					- 표준화 면담
# 					- 비표준화 면담
# 				- 면담조사 방식
# 					- 피라미드 구조
# 					- 퍼널 구조
# 					- 다이아몬드 구조
# 			- 사용자 면담 진행
# 				- 계획 및 준비
# 					- 면담 주제 선정
# 					- 면담 진행 팀 구성
# 						- 면담자
# 						- 기록자
# 						- 관찰자
# 					- 면담 대상자 선정
# 						- 업무에 대한 명확한 이해 시켜줄 수 있는 사람
# 						- 사용자측으로 부터 추천을 받는 것이 좋다.
# 						- 차이점 파악을 위하여 두 명 이상의 면담 대상자 선정
# 					- 면담 일정 수립
# 					- 면담 준비
# 						- 면담 시나리오는 면담 대상자에게 배포하지 않는다.
# 				- 면담
# 					- 면담 시작
# 					- 면담 주제 토의
# 				- 면담 결과 분석
# 				- 분석 결과 피드백
# 					- 면담 대상자에게 면담 결과를 승인 받아야 한다.
# 				- 면담 수행 시 고려 사항
# 					- 면담 시간 준수
# 					- 비밀 보장
# 					- 기대 수준 설정
# 					- 면담 범위 준수
# 					- 적절한 대상자 선정
# 					- 응답 유도
# 					- 면담 내용 문서화
# 					- 잘못된 선입견의 배제
# 		- 워크숍
# 			- 워크숍 정의 및 목적
# 				- 경영층 또는 현업 부서장의 공통된 의견 도출
# 				- 전문가들의 판단력을 이용하여 최적의 결론을 도출
# 			- 워크숍 준비
# 			- 워크숍 수행
# 		- 현행 업무 조사서
# 		- 현행 프로그램 · 데이터 관련 문서
# 			- 현행 시스템 프로세스 계층도 == 업무 모델 완전성 검증
# 			- 현행 데이터 저장소 구조 == 데이터 구조 이해 (업무 요건 및 업무 규칙, 화면, 양식)
# 		- 관찰
# 		- 브레인스토밍
# 		- 프로토타이핑
#
# * 정보 요구 사항 정리
# 	- 정보 요구 사항 정리
# 		- 사용자 면담 정리
# 		- 업무 조사서 정리
# 		- 워크숍 정리
# 		- 기타 기법 저일
# 	- 정보 요구 우선순위 분석
# 		- 화폐가치 산출 방법
# 			- 최종적으로 구해진 가치가 높을수록 우선순위가 높다.
# 			- 기업 차원 중요성 1 ~ 3 점
# 			- 시스템 차원 중요성 1 ~ 3 점
# 			- 상호 관련성 1 ~ 5 점
# 		- 상대적 중요도 산정 방법
# 			- 업무 기여도 1 ~ 5 점
# 			- 정보 요구 사항 매트릭스 관여 점수 9 ~ 1 점
# 			- 현재 정보시스템 정보 요구 사항 얼마나 충족 1 ~ 3 점
#
# * 정보 요구 사항 통합
# 	- 정보 요구 사항 목록 검토
# 	- 정보 요구 사항 목록 통합/분할

# %% [markdown]
# # 정보 요구 사항 분석 (p.217)
#
#
# * 분석 대상 정의
# 	- 현행 업무 분석 대상 정의
# 		- 분석 대상 자료
# 			- 현행 업무 흐름도
# 			- 현행 업무 설명서
# 			- 현행 업무 분장 기술서
# 		- 분석 대상 업무 영역 선정
# 			- 분석 대상 업무 목록표
# 	- 현행 시스템 분석 대상 정의
# 		- 분석 대상 현행 시스템 선정
# 			- 업무 영역·현행 시스템 매트릭스
# 			- 분석 대상 시스템 목록
# 		- 분석 대상 현행 시스템 관련 자료
# 			- 현행 시스템 구성도
# 			- 현행 시스템의 분석, 설계 및 개발 보고서
# 			- 화면, 장표 및 보고서 레이아웃
# 			- 현행 시스템 테이블 목록 및 테이블 정의서
# 			- 프로그램 목록
# 			- 사용자 및 운영자 지침서
# 			- 시스템 지원 및 유지 보수 이력
# 			- 시스템 개선 요구 사항 등
#
# * 정보 요구 사항 상세화
# 		- 비기능적 정보 요구 사항
# 			- 시스템이 만족시켜야 하는 제약조건
# 			- 시스템이 반드시 만족시켜야 하는 주요 성능 척도
# 	- 프로세스 관점의 정보 요구 사항 상세화
# 		- 기본 프로세스: 프로세스 더이상 분해되지 않는 최소 단위의 업무
# 		- 수행 절차
# 			- 프로세스 목록, 계층도, 정의서를 작성
# 			- 기본 프로세스 필요 정보 항목, 산출 정보항목 기본 로직 필요 정리
# 			- 통합성/분리성 검토 후 정보 항목 목록 정의
# 		- 수행 작업 내용
# 			- 프로세스 관점의 정보 요구 상세화
# 				- 프로세스 분해·상세화
# 				- 정보 항목 도출 및 표준화
# 				- 정보 항목별 통합성, 분리성 여부 검토
# 		- 수행 작업 지침
# 			- 프로세스 분해·상세화
# 				- 프로세스의 분해
# 					- 단위 업무 기능부터 점진적 수행 (단위업무기능: 프로세스만으로 구성된 업무 기능)
# 					- 해당 업무 영역의 전체 단위 업무 기능, 프로세스의 분해 수준을 맞추어 점진적으로 분해
# 					- 단위 업무 기능 수준까지 더 분해한 후 프로세스 도출
# 				- 프로세스 분해 깊이
# 					- 업무적인 특성을 고려하여 3차 수준까지 분해
# 					- 업무 활동 분해의 근본적인 목적은 기본 프로세스 도출
# 					- 도출할 프로세스 대상은 데이터의 상태(생성, 수정, 삭제)를 변화시키는 것만으로 한다.
# 				- 프로세스 명칭
# 					- 이름만으로도 개략적인 수행 내용의 파악이 가능하도록 유일한 이름 부여
# 				- 프로세스 계층도
# 					- 프로세스 계층도를 작성하는 목적이 기본 프로세스 도출
# 					- 프로세스 계층도는 높은 응집도 및 낮은 결합도 유지
# 					- 상위 프로세스에 포함되는 하위 프로세스가 7개 초과 -> 상위 프로세스를 분리 고려
# 					- 기본 프로세스는 반드시 작성
# 					- 현 수준의 프로세스 계층도를 더욱 상세하게 분해 -> 업무의 최소 단위인 기본 프로세스까지 도출
# 			- 정보 항목 도출 및 표준화
# 				- CRUD 매트릭스 분석기법
# 				- 기본 프로세스별로 등록(C), 조회(R), 변경(U), 삭제(D) 기능 구분
# 			- 정보 항목별 통합성 검증
# 				- 정보 유형별 및 정보 항목별로 전사 관점에서의 통합/분리 여부 검토
# 				- 통합 장점
# 					- 정보 항목 관리 용이
# 					- 통합 정보 유형으로 수용 가능
# 				- 통합 단점
# 					- 정보 항목의 애매모호성 존재
# 					- 관리 부족으로 통합의 의미 상실 가능성 존재
# 	- 객체지향 관점의 정보 요구 사항 상세화
# 		- 정보시스템의 기능적 정보 요구 사항 정의
# 		- 다이어그램은 사용자와의 의사소통이 원활하게 도움
# 		- 유스케이스 다이어그램
# 			- 액터
# 				- 정보 서비스를 받는 객체
# 			- 유스케이스
# 				- 개발 시스템에서 제공해야 하는 기능
# 				- 사건 흐름에 대한 개요를 간략하게 기술
# 			- 액터와 유스케이스 간의 관계
# 				- 확장
# 					- 한 유스케이스가 다른 유스케이스를 경우에 따라 선택적으로 수행하는 경우
# 				- 포함
# 					- 하나의 유스케이스가 다른 유스케이스를 반드시 수행하는 경우
# 				- Communicates
# 					- 행위자와 유스케이스 사이의 유일한 관계
# 			- 유스케이스 상세화
# 				- 유스케이스의 특별 정보 요구 사항을 정의
# 				- 유스케이스에 대한 개략적인 설명
# 				- 사건 흐름
# 				- 사전, 사후 조건
# 				- 비기능적인 정보 요구 사항
# 				- 주된 사건 흐름에 대체될 수 있는 대안 흐름
# 				- 예외 처리 사항
# 		- 클래스 다이어그램 작성
# 			- 엔터티 클래스 도출
# 				- 유스케이스 다이어그램을 조사하여 명사 및 명사구를 후보 객체로 선정
# 				- 의미가 모호한 것은 제거
# 				- 이음동의어 및 동음이의어를 고려하여 선정
# 				- 문제 영역과 관련이 없는 것은 제거
# 				- 유사한 구조와 행위를 가진 객체들을 클래스로 그루핑
# 			- 관계 도출 및 클래스 도출
# 				- 관계란 의미 있고 관심 있는 연결을 나타내는 클래스 간의 관계
# 			- 속성 정의
# 				- 속성이란 클래스가 나타내는 객체의 특성을 의미
#
#
#
# * 정보 요구 사항 확인
# 	- 수행 절차
# 		- 분석 결과 도출된 산출물에 대해 재검토 기준을 정의하고, 재검토 계획을 수립한다.
# 		- 재검토 대상 산출물의 완전성, 정확성, 일관성, 안정성 등 다양한 측면에서 재검토를 실시한다.
# 		- 재검토 결과, 추가 및 보완 사항이 존재하는 경우에 내용을 문서로 정리 -> 해당 산출물에
# 		  추가 반영 여부를 확인
# 	- 수행 작업 내용
# 		- 재검토 계획 수립
# 			- 재검토 대상이 되는 분석 결과 및 정보 요구 사항 정의서 산출물 확인
# 			- 대상 산출물별로 재검토 기준(체크 리스트) 정의
# 		- 재검토 실시
# 			- 재검토 계획서 작성 및 승인
# 			- 재검토 대상 산출물 준비 및 배포와 재검토 담당자별 역할 분담
# 			- 업무 영역별로 재검토 대상 산출물을 재검토
# 		- 보완 결과 확인
# 			- 재검토 결과를 토대로 업무 영역별로 산출물 보완
# 			- 재검토 결과 반영 여부 확인 및 미반영 사유 검토
# 			- 정보 요구 사항 정의서의 안정성 분석
# 			- 재검토 결과를 토대로 보완 목록 수정
# 	- 수행 작업 지침
# 		- 재검토 계획 수립
# 			- 분석 결과 산출물 확인
# 				- 정보 요구 사항 정의서
# 				- 정보 항목 목록
# 				- 유스케이스 정의서
# 				- 클래스 다이어그램
# 			- 재검토 및 검증 기준
# 				- 완전성
# 				- 정확성
# 				- 일관성
# 				- 안정성
# 		- 재검토 실시
# 			- 재검토 담당자별로 재검토 대상 산출물 검토
# 			- 재검토 결과 정리되면 보완 사항을 유형에 따라 보완 목록 작성
# 			- 정보 요구 사항 간의 일관성이 유지되도록 주의
# 		- 보완 결과 확인
# 			- 재검토 결과
# 			- 보완 목록
# 			- 보완 사항
# 			- 정보 요구 사항 정의서
# 	- 수행 시 고려 사항
# 		- 일관성 있는 기준 및 명확한 일정을 수립
# 		- 재검토 기준을 명확히 하여 해당 기준에 초점을 맞추어 수행
# 		- 진행 효율성을 감안하여 적정한 참여 대상을 선정

# %% [markdown]
# # 정보 요구 사항 명세화 (p.237)
#
#
#
# * 정보 요구 사항 명세 정의
# 	- 정보 요구 사항 명세 정의
# 		- 정보 요구 사항 문서화
# 			- 기능적 요구를 정확하게 서술
# 			- 비기능적 요구 사항도 서술
# 		- 정의
# 			- 요구 분석 과정의 최종 산출물 == 사용자와 개발자 연결시키는 중요한 문서
# 			- 설계 및 구현에서 참조할 사항, 전반적 사항 포함 문서
# 			- 사용자와 개발자 간의 계약서
# 		- 정보 요구 분석 명세서
# 			- 사용자 입장
# 				- 사용자와 의사소통 도구 및 계약서
# 			- 개발자 입장
# 				- 기능적/비기능적 요구 사항 기반 분석, 설계 코딩
# 				- 점검 항목으로 사용
# 			- 테스터 입장
# 				- 테스트를 수행하기 위한 테스트 케이스 만드는 데 사용
# 	- 요구 분석 명세서 작성 시 주의 사항
# 		- 사용자가 쉽게 읽고 이해할 수 있도록 작성한다.
# 		- 개발자가 설계와 코딩에 효과적으로 사용할 수 있도록 작성한다.
# 		- 비기능적 요구를 명확히 작성한다.
# 		- 테스트 기준 용도로 사용할 수 있도록 정량적으로 작성한다.
# 		- 품질에 대한 우선순위를 명시한다.
#
#
# * 정보 요구 사항 명세 상세화
# 	- 요구 사항 상세내역 작성
# 		- 상세 요구 사항 세부내용
# 			- 요구 사항 고유번호
# 			- 요구 사항 명칭
# 			- 요구 사항 분류
# 				- 11개 상세 요구 사항 분류 기준에 따라 분류
# 				- ex) 기능, 성능, 데이터, 테스트 요구 사항 등
# 			- 요구 사항 상세설명
# 				- 정의 + 세부내용
# 			- 산출정보
# 			- 관련 요구 사항
# 			- 요구 사항 출처
# 	- 요구 사항 상세내역 작성 시 고려사항
# 		- 수작업 수반은 구체적인 요구 사항을 도출
# 		- 데이터 요구 사항은 기능 요구 사항과 높은 관련성을 갖는다.

# %% [markdown]
# # 정보 요구 사항 검증 및 변경 관리  (p.247)
#
#
# * 정보 요구 사항 검증 정의
# 	- 요구 사항 검증 활동
# 		- 요구 사항 명세서 검토
# 		- 요구 사항 용어 검증
# 		- 요구 사항 베이스라인 설정
#
#
# * 정보 요구 사항 상관분석 기법
# 	- 주체별 상관분석
# 		- 요구 사항 분석가 수행
# 			- 객관성 저하 문제점이 발생
# 			- 상관분석에 추가 인력 투입 없이 원활하게 진행
# 			- 높은 업무 이해도 -> 상관분석 정확한 업무의 분석
# 		- 품질보증 팀 수행
# 			- 전체적인 인터페이스 검증에 용이
# 			- 낮은 업무 이해도 -> 정확한 분석 단점 지적 어려움
# 		- 외부 감리 수행
# 			- 제 3자의 시각으로 검토
# 			- 내부 인력 효과적 지원 x -> 상황에 맞지 않는 분석 결과 초래
# 			- 상관분석의 객관성 극대화
# 	- 정보 요구 · 애플리케이션 상관분석
# 		- 애플리케이션 아키텍처 프로세스 모델과 비교
# 			- 애플리케이션 ==> 기본 프로세스
# 		   -> 상호 간 일관성 확보
# 		   -> 품질 수준 향상
# 		   -> 누락 or 중복된 정보 요구 사항 점검
# 		- 정보 요구 대 애플리케이션 상관분석 매트릭스
# 			- 기본 프로세스 액션 정의
# 				- C: 생성
# 				- R: 조회
# 				- U: 수정
# 				- D: 삭제
# 				- 복수 액션 우선순위: C > D > U > R
# 			- 정보 요구 사항 <-> 기본 프로세스 도출 == 완성도 및 일관성 검증
# 			- 모든 정보 항목 - 모든 기본 프로세스 사용 or 모든 정보 항목을 사용
# 	- 정보 요구 · 업무 기능 상관분석
# 		- 비즈니스 아키텍처 업무 기능과 비교
# 			- 비즈니스 ==> 업무 기능
# 			-> 상호 간 일관성 확보
# 			-> 품질 수준 향상
# 			-> 누락 or 중복된 정보 요구 사항 점검
# 			- 정보 요구 사항 <-> 업무 기능 도출 == 데이터 모델링 근간
# 		- 정보 요구 대 업무 기능 매트릭스
# 			- 최하위 수준의 전사 업무 기능 도출 == 매트릭스 열
# 			- 정보 요구 사항 == 매트릭스 행
# 			- 정보 항목
# 				- 생성, 수정, 삭제 == 'C'
# 				- 검색 == 'U'
# 				- 아무 관련 없는 것 == '빈칸'
# 	- 정보 요구 · 조직 기능 상관분석
# 		- 비즈니스 아키텍처 조직 단위와 비교
# 			- 비즈니스 ==> 조직 단위
# 			-> 정보 항목 생성 주체 및 활용 부서 매핑
# 			-> 오너십 할당하여 관리
# 			-> 데이터 효율적 관리
# 		- 정보 요구 대 조직 기능 상관분석 매트릭스
# 			- 조직 단위명은 조직 순서로 입력
# 			- 조직 단위 == 매트릭스 열
# 			- 정보 항목 == 매트릭스 행
# 			- 정보 항목
# 				- 생성, 수정, 삭제 == 'C'
# 				- 검색 == 'U'
# 				- 아무 관련 없는 것 == '빈칸'
#
#
# * 추가 및 삭제 정보 요구 사항 도출
# 	- 정보 요구 · 애플리케이션 상관분석
# 		- 애플리케이션 충족도 분석 매트릭스
# 			- 정보 항목을 생성하는 기본 프로세스가 반드시 존재
# 			- 정보 항목의 상태를 종료시키는 기본 프로세스가 존재
# 			- 생성된 정보 항목은 조회, 수정, 삭제 액션 중 하나가 발생
# 			- 하나의 정보 항목을 생성, 수정, 삭제하는 프로세스 합은 7개 초과 X
# 			- 수작업 or 조회 전용 기본 프로세스 제외한 나머지 기본 프로세스 생성, 수정, 삭제 액션 필수
# 		- 매트릭스 분석
# 			- 기본 프로세스가 사용하는 정보 항목 없음
# 				- 정보 항목의 누락 == 정보 항목 도출
# 				- 기본 프로세스 필요없음 == 기본 프로세스 삭제
# 				- 기본 프로세스 분석 대상 업무 영역에 속하지 않음 == 해당 업무 영역으로 이동
# 			- 정보 항목이 7개 이상의 기본 프로세스에서 사용됨
# 				- 정보 항목이 너무 큼 == 정보 항목의 세분화 필요
# 			- 정보 항목을 생성하는 기본 프로세스가 없음
# 				- 기본 프로세스의 누락 정보 항목이 필요 없음 == 기본 프로세스 도출 정보 항목 삭제
# 				- 정보 항목이 분석 대상 업무 영역에 속하지 않음 == 해당 업무 영역으로 이동
# 			- 정보 항목을 생성하는 기본 프로세스가 둘 이상 존재
# 				- 기본 프로세스 중복 == 기본 프로세스 합성
# 			- 엔터티를 삭제하는 기본 프로세스가 없음
# 				- 기본 프로세스 누락 == 기본 프로세스 도출
# 				- 업무에 삭제가 존재하지 않음 == 전산상의 오류인 경우에 삭제가 필요한지 확인
# 				- 기본 프로세스가 분석 대상 업무 영역에 속하지 않음 == 해당 업무 영역으로 이동
# 			- 정보 항목을 삭제하는 기본 프로세스가 둘 이상 존재
# 				- 기본 프로세스 중복 == 기본 프로세스 합성
# 			- 정보 항목이 생성만 되고 사용되는 곳이 없음
# 				- 기본 프로세스 누락 == 기본 프로세스의 도출
# 			- 기본 프로세스가 정보 항목을 조회만 함
# 				- 기본 프로세스가 아님 == 모듈 검토
# 			- 기본 프로세스가 여러 액션을 수행함
# 				- 정의된 기본 프로세스가 너무 큼 == 프로세스 추가 분해
# 	- 정보 요구 · 업무 기능 상관분석
# 		- 매트릭스 분석
# 			- 모든 업무 기능은 정보 항목과 연관이 있는가?
# 			- 각 정보 항목은 적어도 한 번 이상의 'C'를 갖는가?
# 			- 생성된 정보 항목은 다른 업무 기능에 의해 사용(U)되는가?
# 		- 정보 항목과 연관성 없는 업무 기능
# 			- 업무 기능 도출 적절성
# 			- 관련 정보 항목 다시 파악
# 		- 정보 항목에 매핑이 없는 업무 기능
# 			- 정보 요구 사항 보유 여부 확인
# 			- 추가적인 정보 요구 사항 -> 정보 요구 목록에 신규로 추가
# 	- 정보 요구 · 조직 기능 상관분석
# 		- 매트릭스 분석
# 			- 모든 업무 기능은 정보 항목과 연관이 있는가?
# 			- 각 정보 항목은 적어도 한 번 이상의 'C'를 갖는가?
# 			- 생성된 정보 항목은 다른 업무 기능에 의해 사용(U)되는가?
# 		- 정보 항목의 활용도 파악
# 			- 정보 항목 수요가 많은 경우 -> 물리모델링 단계에서 성능·활용 측면 모델링 기법 적용
# 		- 정보 항목을 생성하는 조직 단위가 복수로 존재
# 			- 정보 항목에 대한 데이터 관리 주체 선정
#
#
# * 정보 요구 사항 변경 관리
# 	- 요구 사항 변경 관리 활동
# 		- 요구 사항 변경 제어
# 			- 요구 사항 변경에 대해 비용, 일정 등에 따라 변경 식별 및 평가, 제어 및 재설정 등을 수행
# 		- 요구 사항 추적 제어
# 			- 요구 사항 변경에 의해 다른 형상에 영향을 미치는 요구 사항을 식별, 영향을 받는 요구 사항 추적
# 		- 요구 사항 버전 제어
# 			- 형상관리 기반으로 모든 요구 사항 정보를 관리
# 	- 요구 사항 추적 (요구 사항 버전 제어)
# 		- 요구 사항 추적 매트릭스
# 			- 요구 사항 기능과 비기능 항목으로 정의
# 	- 요구 사항 변경요청 (요구 사항 추적 제어)
# 		- 요구 사항 변경 원인
# 			- 요구 사항의 오류, 충돌
# 			- 요구 사항 간의 불일치
# 			- 기술적, 시간적인 문제와 비용상의 문제
# 			- 사용자 혹은 고객의 우선순위 변경
# 			- 법제도, 경제상황 등 환경의 변화
# 			- 조직의 비즈니스 측면에 의한 변경
# 			- 기술 발전에 따른 신기술 반영결정
# 		- 요구 사항 변경 요청서
# 			- 요구 사항 변경요청서 작성 항목
# 			- 요구 사항 변경유형
# 	- 변경 영향분석 (요구 사항 변경 제어)
# 		- 요구 사항 변경 영향분석
# 	- 변경 승인 · 기각
