# %% [markdown]
# #############################################################################
# #############################################################################
# 과목 1 전사아키텍처 이해
# 	제 1장 전사아키텍처와 데이터아키텍처
# 		 제 1절 전사아키텍처 정의
# 		 	- 전사아키텍처 개념
# 		 		- 전사아키텍처 도입 배경
# 		 		- 전사아키텍처 정의
# 		 		- 전사개념
# 		 		- 아키텍처 개념
# 	 		- 전사아키텍처 추진 현황
# 	 		- 전사아키텍처 관련 데이터아키텍처 전문가 역할
# 		 제 2절 전사아키텍처 프레임워크
# 		 	- 전사아키텍처 프레임워크 개념
# 		 	- 전사아키텍처 프레임워크 구성
# 		 		- 전사아키텍처 정책
# 		 		- 전사아키텍처 정보
# 		 			- '비즈니스 아키텍처'
# 		 				- 조직의 목적 및 임무 지원을 위해 업무를 관리
# 		 			- '데이터 아키텍처'
# 		 				- 효과 적인 업무 처리 및 의사결정을 위한 정보 관리
# 		 			- '애플리케이션 아키텍처'
# 		 				- 조직의 임무를 수행하는데 필요한 애플리케이션 관리
# 		 			- '기술 아키텍처'
# 		 				- 비즈니스, 데이터, 애플리케이션 아키텍처 구성을 위한 기술 인프라 관리
#  				- 전사아키텍처 관리
# 			- 아키텍처 도메인 구성
# 				- 비즈니스 아키텍처
# 					- 기업 업무 구조를 체계화
# 				- 애플리케이션 아키텍처
# 					- 기업 업무 애플리케이션 구조를 체계화
# 				- 데이터 아키텍처
# 					- 기업 업무 데이터의 구조를 체계화
# 				- 기술 아키텍처
# 					- 기업 업무 기술 인프라 체계화
# 					- 하드웨어, 시스템 소프트웨어, 통신 네트워크, 시스템 개발도구
# 			- 전사아키텍처 프레임워크 사례
# 		 제 3절 전사아키텍처 참조모델
# 		 	- 참조 모델 정의
# 		 		- 참조 모델 개념
# 		 		- 참조 모델 현황
# 		 		- 참조 모델 구축 방법
# 	 		- 참조 모델 사례
# 	 			- '업무 참조 모델'
# 	 				- 특정 기관의 독립적인 업무 기능을 중심으로 정의한 참조 모델
#  				- '서비스 참조 모델'
#  					- 업무 수행과 목표 달성을 지원하는 서비스 요소를 분류 참조 모델
# 				- '기술 참조 모델'
# 					- 업무와 서비스 구성 요소의 전달, 구축을 지원해 주는 표준, 명세, 기술 요소를 기술
# 				- '데이터 참조 모델'
# 					- 기관 간의 공통 정보 파악과 활용을 지원하기 위한 모델
# 				- '성과 참조 모델'
# 					- 정보화 성과 관리를 위한 구성 요소와 관계를 정의
# 			- 참조 모델 활용
# 		 제 4절 전사아키텍처 프로세스
# 		 	- 전사아키텍처 프로세스 개요
# 		 	- 전사아키텍처 프로세스 구성
#
# 	제 2장 전사아키텍처 구축
# 		제 1절 전사아키텍처 방향 수립
# 			- 전사아키텍처 정보 구성 정의
# 		 	- 전사아키텍처 환경 분석
# 		 	- 전사아키텍처 구축 방향 정의
# 		 		- 목적 및 범위 정의
# 		 		- 전사아키텍처 비전 수립
# 		 		- 전사아키텍처 프레임워크 정의
# 		제 2절 전사아키텍처 정보 구성 정의
# 			- 전사아키텍처 정보 구성 개요
# 			- 아키텍처 매트릭스 정의
# 				- 아키텍처 매트릭스 개념
# 				- 아키텍처 매트릭스 구성
# 				- 산출물 정의
# 				- 전사아키텍처 정보 구성요소 정의
# 				- 아키텍처 매트릭스 정의시 고려사항
# 			- 참조 모델 정의
# 			- 전사아키텍처 원칙 수립
# 		제 3절 전사아키텍처 정보 구축
# 			- 전사아키텍처 정보 구축 정비
# 				- 자료 수집
# 				- 전사아키텍처 정보 구축 방식
# 			- 현행 아키텍처 정보 구축
# 				- 현행 비즈니스 아키텍처 정보 구축
# 				- 현행 애플리케이션 아키텍처 정보 구축
# 				- 현행 데이터아키텍처 정보 구축
# 				- 현행 기술 아키텍처 정보 구축
# 			- 목표 아키텍처 정보 구축
# 				- 목표 비즈니스아키텍처 구축
# 				- 목표 애플리케이션 아키텍처 정보 구축
# 				- 목표 데이터아키텍처 정보 구축
# 				- 목표 기술 아키텍처 정보 구축
#
#    	제 3장 전사아키텍처 관리 및 활용
# 		제 1절 전사아키텍처 관리 체계
# 			- 전사아키텍처 관리 체계 개요
# 				- 전사아키텍처 관리 체계 개념
# 				- 전사아키텍처 관리 체계 구축 방향
# 			- 전사아키텍처 관리 조직 체계
# 				- 전사아키텍처 관리 조직 개요
# 				- 전사아키텍처 관리 조직의 정의
# 			- 전사아키텍처 관리 프로세스
# 				- 전사아키텍처 관리 프로세스 개요
# 				- 전사아키텍처 관리 프로세스 구성
# 			- 전사아키텍처 관리 이력
# 				- 전사아키텍처 관리 인력 개요
# 				- 전사아키텍처 전문가 육성
# 		제 2절 전사아키텍처 관리 시스템
# 			- 전사아키텍처 관리 시스템
# 				- 전사아키텍처 관리 시스템 개요
# 			- 전사아키텍처 정보 정의 도구
# 			- 전사아키텍처 정보 관리 시스템
# 		제 3절 전사아키텍처 활용
# 			- 전사아키텍처 활용 개요
# 			- 목표 아키텍처 이행 계획
# 			- 전사아키텍처 정보 상시 활용
# 			- 전사아키텍처와 데이터아키텍처 전문가 영역
# 				- 전사아키텍처와 데이터아키텍처 프레임워크
# 				- 전사아키텍처와 데이터아키텍처
#
#
#
# #############################################################################
# #############################################################################
# 과목 2 데이터 요건 분석
# 	제 1장 정보 요구 사항 개요
# 		제 1절 정보 요구 사항
# 			- 정의
# 			- 정보 요구 사항 생명주기 모형(Life Cycle)
# 				- 정보 요구 사항 수집
# 				- 정보 요구 사항 분석 및 정의
# 				- 정보 요구 사항 상세화
# 				- 정보 요구 사항 검증
# 			- 정보 요구 사항 유형
# 		제 2절 정보 요구 사항 관리
# 			- 정의 및 관리 목적
# 			- 정보 요구 사항 관리 프로세스
# 				- 업무흐름 프로세스
# 				- 수행 조직 및 수행 업무
#
#    	제 2장 정보 요구 사항 조사
# 		제 1절 정보 요구 사항 수집
# 			- 정보 요구 사항 수집 형태
# 			- 관련 문서 수집
# 				- 문서수집 목적
# 				- 문서수집 자료
# 				- 문서수집 원칙
# 			- 사용자 면담
# 				- 사용자 면담 진행
# 				- 면담
# 				- 면담 결과 분석
# 				- 분석 결과 피드백
# 				- 면담 수행시 고려사항
# 			- 워크숍
# 				- 워크숍 개요 및 목적
# 				- 워크숍 준비
# 				- 워크숍의 수행
# 			- 현행 업무조사서
# 			- 현행 프로그램/데이터 관련 문서
#
#    		제 2절 정보 요구 사항 정리
# 			- 정보 요구 사항 정리
# 				- 사용자 면담 정리
# 				- 업무 조사서 정리
# 				- 워크숍 정리
# 				- 기타 기법 정리
# 			- 정보 요구 우선순위 분석
# 				- 화폐가치 산출 방법
# 				- 상대적 중요도 산정 방법
#
#    		제 3절 정보 요구 사항 통합
# 			- 정보 요구 사항 목록 검토
# 			- 정보 요구 사항 목록 통합/분할
# 				- 동일 부서 내 중복 요구 사항 검토
# 				- 서로 다른 부서간 중복 요구 사항 검토
#
#    	제 3장 정보 요구 사항 분석
# 		제 1절 분석 대상 정의
# 			- 현행 업무 분석 대상 정의
# 				- 분석 대상 자료
# 				- 분석 대상 업무 영역 선정
# 			- 현행 시스템 분석 대상 정의
# 				- 분석 대상 현행 시스템 선정
# 				- 분석 대상 현행 시스템 관련 자료
# 				- 추가적인 분석 대상
# 		제 2절 정보 요구 사항 상세화
# 			- 프로세스 관점의 정보 요구 사항 상세화
# 				- 수행 절차
# 				- 수행 작업 내용
# 				- 수행 작업 지침
# 			- 객체지향 관점의 정보 요구 사항 상세화
# 				- 유즈케이스 다이어그램
# 				- 유즈케이스 상세화
# 				- 클래스 다이어그램 작성
# 		제 3절 정보 요구 사항 확인
# 			- 수행 절차
# 			- 수행 작업 내용
# 			- 수행 작업 지침
# 				- 재검토 계획 수립
# 				- 재검토 실시
# 				- 보완 결과 확인
# 			- 수행시 고려사항
#
#    	제 4장 정보 요구 검증
# 		제 1절 정보 요구 상관분석 기법
# 			- 주제별 분류
# 				- 요구 사항 분석가 수행
# 				- 품질보증팀 수행
# 				- 외부 감리 수행
# 			- 정보 요구 / 애플리케이션 상관분석
# 				- 생성				== 'C'
# 				- 조회				== 'R'
# 				- 수정				== 'U'
# 				- 삭제 				== 'D'
# 			- 정보 요구 / 업무 기능 상관분석
# 				- 생성, 수정 삭제 	== 'C'
# 				- 검색 				== 'U'
# 			- 정보 요구 / 조직 기능 상관분석
# 				- 생성, 수정, 삭제 	== 'C'
# 				- 검색 				== 'U'
#
#    		제 2절 추가 및 삭제 정보 요구 사항 도출
# 			- 정보 요구 / 애플리케이션 상관 분석
# 				- 애플리케이션 충족도 분석 매트릭스
# 				- 매트릭스 분석
# 					- 조회, 수정, 삭제 액션 중 하나가 발생해야 한다.
# 					- 생성, 삭제하는 합은 7개를 초과하지 않는다.
# 					- 조회 전용을 제외한 다른 프로세스는 생성, 수정, 삭제 하나를 수행
# 			- 정보 요구 / 업무 기능 상관분석
# 				- 매트릭스 분석
# 					- 적어도 한번 이상의 'C'를 갖는가?
# 			- 정보 요구 / 조직 기능 상관분석
# 				- 매트릭스 분석
# 					- 적어도 한번 이상의 'C'를 갖는가?
#
#    		제 3절 정보 요구 사항 보완 및 확정
# 			- 정보 요구 보완
# 			- 정보 요구 확정
#
#
# #############################################################################
# #############################################################################
# 과목 3 데이터 표준화
# 	제 1장 데이터 표준화 개요
# 		제 1절 데이터 표준화 필요성
# 			- 데이터 관리 현황 및 개선 방안
# 				- 데이터 활용상의 문제점
# 				- 데이터 문제점의 원인
# 				- 데이터 관리 개선 방안
# 			- 데이터 표준화 기대효과
# 				- 기대효과
# 					- 명칭의 통일로 인한 명확한 의사소통의 증대
# 					- 필요한 데이터의 소재 파악에 소요되는 시간 및 노력 감소
# 					- 일관된 데이터 형식 및 규칙의 적용으로 인한 데이터 품질 향상
# 					- 정보시스템 간 데이터 인터페이스 시 데이터 변환, 정제 비용 감소
# 		제 2절 데이터 표준화 개념
# 			- 데이터 표준화 정의
# 				- 데이터 명칭
# 				- 데이터 정의
# 				- 데이터 형식
# 					- 도메인을 정의하여 데이터 표준에 적용함으로써 성격이 유사한 데이터 간의 데이터 형식을 통일화 한다.
# 					- 데이터의 최대값 또는 최대 길이가 고정되어 있지 않을 경우 충분히 여유있게 정의한다.
# 					- 특수 데이터 타입(CLOB, Long Raw 등)은 데이터 조회, 백업, 이행 등에 있어서 제약 사항이 존재하는 경우가 많기 때문에 가급적 사용하지 않는다.
# 				- 데이터 규칙
# 			- 데이터 표준화 구성요소
# 				- 데이터 표준
# 				- 데이터 표준 관리 조직
# 				- 데이터 표준화 절차
# 		제 3절 데이터 표준 관리 도구
# 			- 확장된 데이터 표준 관리 도구의 기능
# 			- 데이터 표준 관리 시스템 기능
# 				- 데이터 표준 관리 기능
# 					- '데이터 사전'
# 				- 데이터 구조 관리 기능
# 					- 'DA# ERD'
# 				- 프로세스 관리 기능
# 					- 'META'
# 			- 데이터 표준 관리 시스템 도입시 고려사항
#
#    	제 2장 데이터 표준화 원칙 정의
# 		제 1절 데이터 표준화 원칙 정의
# 			- 데이터 표준화 요구 사항 수립
# 			- 현행 데이터 표준 원칙 분석
# 				- 현행 데이터 표준 원칙 수집
# 				- 데이터 표준 원칙 사용 현황 분석
# 			- 데이터 표준 개선 방안 정의
# 			- 데이터 표준 원칙 수립
# 				- 데이터 표준 기본 원칙 정의
# 				- 데이터 표준 지침 작성
# 		제 2절 데이터 표준 정의
# 			- 표준 단어(Word) 사전 정의
# 				- 표준 단어 사전
# 				- 표준 단어 정의
# 				- 표준 단어 정의시 고려사항
# 			- 표준 도메인(Domain) 사전 정의
# 				- 표준 도메인 사전
# 				- 표준 도메인 정의
# 				- 표준 도메인 정의시 고려사항
# 			- 표준 코드(Code) 사전 정의
# 				- 표준 코드 사전
# 				- 표준 코드 정의
# 				- 표준 코드 활용
# 				- 표준 코드 정의시 고려사항
# 			- 표준 용어 사전 정의
# 				- 표준 용어 사전
# 				- 표준 용어 정의
# 				- 표준 용어 정의시 고려사항
# 		제 3절 데이터 표준 확정
# 			- 데이터 표준 검토
# 				- 데이터 표준 검토 계획 수립
# 				- 데이터 표준 검토
# 				- 데이터 표준 보완 및 승인
# 			- 데이터 표준 공표
# 				- 데이터 표준 배포
# 				- 데이터 표준 교육
#
#    	제 3장 데이터 표준 관리
# 		제 1절 데이터 표준 관리
# 			- 데이터 표준 관리 개요
# 			- 데이터 표준 관리 프로세스 유형
# 		제 2절 데이터 표준 관리 프로세스
# 			- 데이터 표준 관리 프로세스 구성요소
# 			- 구성요소별 설명
# 				- 프로세스
# 				- 태스크
# 				- 역할과 담당 업무
#
#
#
# #############################################################################
# #############################################################################
# 과목 4 데이터 모델링
# 	제 1장 데이터 모델링 이해
# 		제 1절 데이터 모델링 개요
# 			- 데이터 모델링 정의
# 				- 데이터 모델링 탄생 배경
# 				- 모델 정의
# 				- 모델링 정의
# 				- 데이터 모델이 제공하는 것
# 			- 데이터 모델링 필요성
# 				- 애플리케이션과 데이터의 통합
# 				- 개발자들의 시스템 이해
# 				- 데이터 모델링시 주의점
# 			- 데이터 모델링 단계
# 				- 개념 데이터 모델링 (Conceptual Data Modeling)
# 				- 논리 데이터 모델링 (Logical Data Modeling)
# 				- 물리 데이터 모델링 (Physical Data Modeling)
# 			- 모델링 기본원칙
# 				- 커뮤니케이션 원칙(Communication Principle)
# 				- 모델링 상세화 원칙(Granularity Principle)
# 				- 논리적 표현 원칙
# 			- 좋은 데이터 모델의 요소
# 				- 완전성
# 				- 중복 배제
# 				- 비즈니스 룰
# 				- 데이터 재사용
# 				- 안정성 및 확장성
# 				- 간결성
# 				- 의사소통
# 				- 통합성
# 		제 2절 데이터 모델링 기법 이해
# 			- 데이터 모델 목적
# 			- 개체-관계 모델 기법(Entity-Relationship Modeling)
# 			- 개체-관계 모델 구성 요소
# 				- 엔터티(Entity)
# 				- 속성(Attribute)
# 				- 식별자
# 				- 관계(Relationship)
# 				- 카디날리티(Cardinality)
# 				- 존재 종속
# 				- 서브타입
# 				- 객체지향 모델링(Object-Oriented Modeling)
# 				- 객체지향 개념
# 				- 객체 모형
# 				- 객체 모형 데이터
# 				- 객체 모형의 메소드
# 				- 불명료한 객체 접근 방식
# 				- 객체지향 모델링과 논리 데이터 모델링간의 관계
# 				- 객체지향 모델링 장점
# 		제 3절 데이터 모델링 표기법 이해
# 			- 바커 표기법(Baker Notation)
# 				- 엔터티(Entity)
# 				- 속성(Attribute)
# 				- 관계(Relationship)
# 				- 식별자(Unique Identifier)
# 				- 서브타입(Sub-type)
# 				- 관계의 표현 비교
# 			- I/E 표기법(Information Engineering Notation)
# 				- 엔터티(Entity)
# 				- 속성(Attribute)
# 				- 관계(Relationship)
# 				- 식별자(Unique Identifier)
# 				- 서브타입(Sub-type)
#
# 	제 2장 개념 데이터 모델링
# 		제 1절 개념 데이터 모델링 이해
# 			- 개념 데이터 모델 정의
# 			- 개념 데이터 모델 의의
# 			- 데이터아키텍처 프레임워크 상에서 개념 데이터 모델
# 		제 2절 주제 영역 정의
# 			- 주제 영역 개념
# 			- 주제 영역 분류 원칙 및 기준
# 				- 주제 영역 분류 원칙
# 				- 주제 영역 분류 기준
# 				- 주제 영역 명명
# 				- 주제 영역 분류 방법
# 			- 주제 영역 활용
# 				- 목적
# 				- 장점
# 			- 주제 영역 도출
# 				- 업무에서 사용하는 데이터의 명사형 도출
# 				- 업무 기능의 이름으로부터 도출
# 				- 하향식(Top-down) 접근 방법
# 				- 상향식(Bottom-up) 접근 방법
# 				- 분석 단계에서의 도출
# 			- 주제 영역 정의 내용
# 				- 주제 영역 목록
# 				- 주제 영역 정의서 샘플 양식
# 		제 3절 후보 엔티티 선정
# 			- 개념
# 			- 엔터티 후보 수집
# 			- 엔터티 후보 식별
# 				- 엔터티 후보의 개념 정립
# 				- 관리 대상 판정
# 				- 집합 여부 확인
# 			- 엔터티 후보 선정시 유의사항
# 			- 수집된 엔터티 분류
# 				- 우선적용 대상 분류
# 				- 우선적용 대상 분류 사례
# 				- 데이터 영역별 분류
# 		제 4절 핵심 엔티티 정의
# 			- 개념
# 				- 엔터티란
# 				- 엔터티 정의의 요건
# 			- 의미상 주어 정의
# 				- 본질 식별자 정의의 의의
# 				- 본질 식별자 정의 예
# 			- 코드성 키 엔터티 모델링
# 				- 자식 엔터티 유무 확인
# 				- 속성 존재 여부 확인
# 				- 관계 존재 여부 확인
# 			- 집합 순수성 예
# 				- 집합 순수성 의미
# 				- 집합 순수성 예
# 				- 집합 순수성 적용 예외 사항
# 			- 집합 동질성
# 				- 집합 동질성 의미
# 				- 집합 동질성 부여의 예
# 			- 엔터티 명칭
# 				- 적절하 엔터티 명칭
# 				- 엔터티 명칭 부여하기 예제
# 			- 서브타입
# 				- 서브타입 지정 의의
# 				- 서브타입 지정시 고려사항
# 				- 서브타입 도출
# 				- 서브타입의 활용
# 			- 엔터티 통합과 분할
# 				- 엔터티 독립성
# 				- 엔터티 분할/통합
# 				- 집합 동질성 확대를 통한 집합 통합 사례
# 				- 유연성 향상을 위한 통합
# 			- 엔터티 정의 기술과 엔터티 정의서 작성
# 		제 5절 관계 정의
# 			- 관계(Relationship)란?
# 			- 관계 이해
# 				- 관계도 집합이다.
# 				- 직접 관계를 관계라고 한다.
# 				- 두 엔터티 간에는 하나 이상의 관계가 존재할 수 있다.
# 				- 외래키로 정의
# 				- 관계의 관점
# 			- 관계표현
# 				- 관계 형태(Degree/Cardinality)
# 				- 선택 사양(Optionality)
# 				- 관계명
# 			- 관계 정의 방법
# 				- 관계 구문 이해
# 				- 관계 정의 절차
# 			- 관계 형태
# 				- 1:1 관계
# 				- M:1 관계
# 				- M:M 관계
# 				- 다중 관계 처리
# 				- 특수한 형태 관계
# 					- 순환 관계
# 					- BOM (BILL OF MATERIALS) 관계
# 					- ARC (MUTUALLY EXCLUSIVE) 관계
# 		제 6절 개념 데이터 모델 작성
# 			- 개념 데이터 모델의 구성 요소
# 				- 개념 데이터 모델 미작성시 영향
# 				- 개념 데이터 모델의 작성이 불필요한 경우
# 			- 개념 데이터 모델의 작성 방법
# 				- 개괄 데이터 모델로부터 상세화하는 경우
# 				- 수집된 엔터티 후보로부터 작성하는 경우
# 				- 현행 데이터 리버스를 통해 작성하는 경우
#
# 	제 3장 논리 데이터 모델링
# 		제 1절 논리 데이터 모델링 이해
# 			- 논리 데이터 모델링 정의
# 			- 논리 데이터 모델링 목적 및 효과
# 			- 논리 데이터 모델링 필수 성공요소
# 		제 2절 속성 정의
# 			- 속성 개념
# 				- 속성 정의
# 				- 속성 특징
# 			- 속성 후보 도출
# 				- 속성 후보 수집처
# 				- 속성 후보 선정 원칙
# 				- 속성의 기본 구성요소
# 			- 속성 검증 및 확정
# 				- 최소 단위(Atomic Value)까지 분할하라
# 				- 하나의 값(Single Value)만을 가지는지 검증한다.
# 				- 추출 속성(Derived Attribute)인지 검증한다.
# 				- 보다 상세하게 관리할 것이냐?
# 			- 추출 속성 규칙
# 			- 속성 정의시 유의사항
# 				- 의미가 명확한 속성 명칭을 부여한다.
# 				- 유일한 복합명사 사용
# 				- 단수형으로 속성명을 사용한다.
# 				- 표준 단어 제정
# 				- 작의적인 전용 금지
# 		제 3절 엔티티 상세화
# 			- 식별자(UID, Unique Identifier) 확정
# 				- 본질 식별자
# 				- 후보 식별자 도출
# 				- 대체(보조) 식별자
# 				- 인조 식별자 지정
# 					- 최대한 범용적인 값을 사용한다.
# 					- 유일한 값을 만들기 위한 인조 식별자를 사용한다.
# 					- 하나의 인조 식별자 속성으로 대체할 수 없는 형태를 주의한다.
# 					- 편의성, 단순성 확보를 위한 인조 식별자를 사용할 수 있다.
# 					- 의미의 체계화를 위한 인조 식별자를 사용할 수 있다.
# 					- 내부적으로만 사용하는 인조 식별자
# 				- 식별자 확정
# 			- 정규화(Normalization)
# 				- 정규화의 의미
# 					- 입력 이상
# 					- 삭제 이상
# 					- 갱신 이상
# 				- 정규화의 장점
# 					- 중복값이 줄어든다
# 					- NULL 값이 줄어든다
# 					- 복잡한 코드로 데이터 모델을 보완할 필요가 없다.
# 					- 새로운 요구 사항의 발견 과정을 돕는다
# 					- 업무 규칙의 정밀한 포착을 보증한다.
# 					- 데이터 구조의 안정성을 최대화한다.
# 				- 정규화 단계
# 			- M:M 관계 해소
# 				- m:m 관계의 의미
# 				- m:m 관계 해소의 의의
# 			- 참조무결성 규칙 정의
# 				- 입력 규칙
# 					- DEPENDENT
# 					- AUTOMATIC
# 					- NULLIFY
# 					- DEFAULT
# 					- CUSTOMIZED
# 					- NO EFFECT
# 				- 삭제 규칙
# 					- RESTRICT
# 					- CASCADE
# 					- NULLIFY
# 					- DEFAULT
# 					- CUSTOMIZED
# 					- NO EFFECT
# 		제 4절 이력관리 정의
# 			- 이력 관리란
# 			- 이력 관리 대상 선정
# 				- 사용자 조사
# 				- 이력 데이터의 종류
# 				- 이력 관리 형태
# 				- 선분 이력 관리 유형
# 			- 선분 이력 관리용 식별자 확정
# 				- 선분 이력에서 식별자 결정 시 고려사항
# 				- 선분 이력에서 종료점 처리 시 주의사항
# 		제 5절 논리 데이터 모델 품질 검토
# 			- 논리 데이터 모델 품질 검토 개요
# 			- 논리 데이터 모델 품질 검토 체크리스트의 활용
#
# 	제 4장 물리 데이터 모델링
# 		제 1절 물리 데이터 모델링 이해
# 			- 물리 데이터 모델 정의
# 			- 물리 데이터 모델 의의
# 			- 논리 데이터 모델-물리 데이터 모델
# 				- 분산 데이터베이스 구축 시
# 				- 물리 데이터 모델 비교
# 				- 물리적 환경의 변화
# 				- 물리적 모델의 형상관리
# 		제 2절 물리 요소 조사 및 분석
# 			- 시스템 구축 관련 명명 규칙
# 			- 하드웨어 자원 파악
# 				- CPU
# 				- MEMORY
# 				- DISK
# 				- I/O Controller
# 				- Network
# 			- 운영체제 및 DBMS 버전 파악
# 			- DBMS 파라미터 정보 파악
# 			- 데이터베이스 운영과 관련된 관리 요소 파악
# 		제 3절 논리-물리 모델 변환
# 			- 논리 데이터 모델-물리 데이터 모델 변환(Transformation) 용어
# 			- 엔터티-테이블 변환
# 				- 테이블 설명
# 				- 서브타입 변환(Transformation)
# 				- 서브타입 변환 예
# 				- 테이블 목록 정의서
# 			- 속성-칼럼 변환
# 				- 일반 속성 변환
# 				- Primary UID 기본키(Primary Key) 변환
# 				- Primary UID(관계의 UID Bar) 기본키(Primary Key) 변환
# 				- Secondary (Alternate) UID Unique Key 변환
# 				- 테이블 정의서
# 			- 관계 변환
# 				- 1:m 관계 변환
# 				- 1:1 관계 변환
# 				- 1:m 순환 관계 변환
# 				- 배타적 관계 변환
# 			- 관리상 필요한 칼럼 추가
# 				- 개념
# 				- 시스템 칼럼 추가 예
# 			- 데이터 타입 선택
# 				- 개념
# 				- 문자 타입 (Character Data Types)
# 				- 숫자 타입 (Numeric Types)
# 				- 날짜 타입 (Datetime Types)
# 			- 데이터 표준 적용
# 				- 개념
# 				- 데이터 표준 적용 대상
# 				- 데이터 표준 적용 방법
# 					- 업무영역 + 주제어 수식어 + 주제어 + 분류어 수식어 + 분류어 + 접미사
# 					   (필수)       (선택)      (필수)      (선택)      (필수)   (선택)
# 			       ex)  계약        서비스       계약                    원부
#
# 		제 4절 반정규화
# 			- 테이블 분할
# 				- 개념
# 				- 수평 분할 (Horizontal Partitioning)
# 				- 수직 분할 (Vertical Partitioning)
# 					- 갱신 위주의 칼럼 수직 분할
# 					- 자주 조회되는 칼럼 분할
# 					- 특정 칼럼의 크기가 아주 큰 경우 분할
# 					- 특정 칼럼에 보안을 적용해야 하는 경우의 분할
# 			- 중복 테이블 생성
# 				- 개념
# 				- 중복 테이블 생성 판단 근거
# 				- 중복 테이블 유형
# 					- 집계(통계) 테이블 추가
# 			- 중복 칼럼 생성
# 				- 개념
# 				- 중복 칼럼 생성 상황
# 				- 중복 칼럼 생성시 유의사항
# 		제 5절 물리 데이터 모델 품질 검토
# 			- 물리 데이터 모델 품질 검토 개요
# 			- 물리 데이터 모델 품질 검토 체크리스트의 활용
#
#
# #############################################################################
# #############################################################################
# 과목 5 데이터베이스 설계와 이용
# 	제 1장 데이터베이스 설계
# 		제 1절 저장공간 설계
# 			- 테이블
# 				- 테이블(Table)
# 				- 칼럼(Column)
# 				- 테이블 설계시 고려사항
# 			- 테이블과 테이블스페이스
# 			- 용량 설계
# 		제 2절 무결성 설계
# 			- 데이터 무결성
# 				- 데이터 무결성 종류
# 				- 데이터 무결성 강화 방법
# 			- 실체 무결성
# 			- 영역 무결성
# 			- 참조 무결성
# 		제 3절 인덱스 설계
# 			- 인덱스 기능
# 			- 인덱스 설계 절차
# 				- 접근 경로 수집
# 				- 분포도 조사에 의한 후보 컬럼 선정
# 				- 접근 경로 결정
# 				- 컬럼 조합 및 순서 결정
# 				- 적용 시험
# 			- 인덱스 구조
# 				- 트리 기반 인덱스
# 				- 비트맵 인덱스
# 				- 함수 기반 인덱스
# 				- 비트맵 조인 인덱스
# 				- 도메인 인덱스
# 		제 4절 분산 설계
# 			- 분산 데이터베이스 개요
# 			- 분산 데이터베이스 관리 시스템
# 			- 분산 설계 전략
# 			- 분산 설계 방식
# 				- 테이블 위치 분산
# 				- 분할(Fragmentation)
# 				- 할당(Allocation)
# 			- 데이터 통합
# 		제 5절 보안 설계
# 			- 접근 통제 기능
# 			- 보안 모델
# 				- 접근 통제 행렬(Access control matrix)
# 				- 기밀성 모델
# 				- 무결성 모델
# 			- 접근 통제 정책
# 			- 접근 통제 매커니즘
# 			- 접근 통제 조건
# 			- 감사 추적
#
#    	제 2장 데이터베이스 이용
# 		제 1절 데이터베이스 관리 시스템(DBMS)
# 			- 개념적 데이터베이스 관리 시스템 아키텍처
# 			- 데이터베이스 서버 시작과 종료
# 				- 데이터베이스 서버 시작
# 			- 데이터베이스 구조
# 				- 데이터 딕셔너리
# 				- 데이터베이스, 테이블 스페이스 및 데이터 파일
# 				- 데이터 블록, 확장 영역 및 세그먼트 간의 관계
# 			- 메모리 구조
# 			- 프로세스 구조
# 		제 2절 데이터 액세스
# 			- 실행 구조
# 				- 옵티마이저
# 				- SQL 실행 단계
# 			- 명령어
# 				- 데이터 정의 언어 (DDL, Data DEfinition Language)
# 				- 데이터 조작 언어 (DML, Data Manipulaion Language)
# 				- 제어 명령어 (Control Statement)
# 			- 저장 프로시저
# 				- 저장 프로시저 설계 지침
# 				- 저장 프로시저의 장점
# 			- 트리거(Trigger)
# 				- 트리거 사용
# 				- 트리거 유형
# 				- 트리거링 이벤트와 제한 조건
# 		제 3절 트랜잭션
# 			- 트랜잭션 관리
# 			- 트랜잭션 특성
# 			- 트랜잭션의 일관성
# 				- 낮은 단계 트랜잭션 고립화 수준에서 발생할 수 있는 현상들
# 				- 트랜잭션 고립화 수준 (Transaction Isolation Level)
# 			- 동시성 제어(Concurrency Control)
# 				- 낙관적 동시성 제어
# 				- 비관적 동시성 제어
# 			- 동시성 제어 기능
# 			- 동시성 구현 사례
# 			- 고장 회복(Recovery)
# 			- 로킹 지속 시간(Locking duration)
# 		제 4절 백업 및 복구
# 			- 장애 유형
# 			- 로그 파일
# 			- 데이터베이스 복구 알고리즘
# 				- NO-UNDO/REDO
# 					- 비동기적 갱신
# 					- 데이터베이스 버퍼의 내용을 비동기적으로 갱신한다는 의미는 트랜잭션이 성공적으로 수행되어 완료점에 도달할 때까지 데이터베이스 변경 내용이 기록되지 않는다는 것을 의미한다.
# 					  즉, 트랜잭 션이 완료되기 이전에는 변경 내용이 데이터베이스에 기록되지 않으므로 완료되지 않은 트랜잭션 은 취소할 필요가 없다.
# 					  그러나 트랜잭션이 완료된 후 데이터베이스 버퍼에 기록되고 저장 매체에 기록되지 않는 상태에서 시스템이 파손되었다면 트랜잭션의 내용을 재실행해야 한다.
# 					  이러한 방식 의 알고리즘을 NO-UNDO/REDO 복구 알고리즘이라 한다.
# 				- UNDO/NO-REDO
# 					- 동기적 갱신
# 					- 데이터베이스 버퍼의 내용을 동기적 갱신하는 경우 트랜잭션이 완료되기 전에 데이터베이스 버퍼 내용을 모두 동시적으로 기록하므로
# 					  완료된 트랜잭션들은 어떤 연산도 재실행할 필요가 없다.
# 					  그러나 트랜잭션들이 완료되기 이전에 시스템 파손이 발생할 경우 변경된 내용을 취소해야 한다.
# 					  이러한 방식의 알고리즘을 UNDO/NO-REDO 복구 알고리즘이라 한다.
# 				- UNDO/REDO
# 					- 동기/비동기적 갱신
# 					- 데이터베이스 버퍼의 내용을 동기/비동기적으로 갱신할 경우 모든 갱신이 데이터베이스에 기록되기 전에 트랜잭션이 완료될 수 있으므로
# 					  완료된 트랜잭션이 데이터베이스에 기록되지 못했다면 재 실행을 해야 한다.
# 					  이러한 방식의 알고리즘을 UNDO-REDO 복구 알고리즘이라고 한다.
# 					  이 복구 방법은 가장 일반적인 기법이지만 가장 복잡한 기법이기도 하다.
# 				- NO-UNDO/NO-REDO
# 					- 동시적으로 기록
# 					- 데이터베이스 버퍼 내용을 동시적으로 저장 매체에 기록하나 데이터베이스와는 다른 영역에 기록 하는 경우이다.
# 					  항상 트랜잭션의 실행 상태와 데이터베이스의 내용이 일치하며, 따라서 데이터베 이스 버퍼의 내용을 취소하거나 재실행할 필요가 없다.
# 					  이러한 방식의 알고리즘을 NOUNDO/ NO-REDO 복구 알고리즘이라고 한다.
# 			- 백업 종류
# 			- 데이터베이스 백업 가이드 라인
#
# 	제 3장 데이터베이스 성능 개선
# 		제 1절 성능 개선 방법론
# 			- 성능 개선 목표
# 			- 성능 개선 절차
# 				- 분석
# 				- 이행
# 				- 평가
# 			- 성능 개선 접근방법
# 			- SQL 성능 분석
# 				- 실행 계획 분석 사례
# 			- 성능 개선 도구
# 				- Oracle
# 				- IBM UDB
# 		제 2절 조인
# 			- Nested-Loop 조인
# 			- Sort-Merge 조인
# 			- Hash 조인
# 			- Hybrid 조인
# 		제 3절 애플리케이션 성능 개선
# 			- 온라인 프로그램 성능 개선
# 			- 온라인 프로그램의 성능 개선 사례
# 				- 상수 바인딩에 의해 발생되는 파싱 부하
# 				- 웹 게시글 형태의 인터페이스 시 부분 범위 처리
# 				- 과다한 함수 사용으로 인한 부하 발생
# 			- 배치 프로그램의 성능 개선
# 				- 절차적인 처리 방식의 비효율
# 				- 절차적인 처리방식의 보완 요소
# 				- 집합적인 처리방식의 고려사항
# 			- 배치 프로그램의 성능 개선 방안
# 				- 분석 함수(Analytic Function)를 통한 성능 개선 방안
# 				- 파티션 스토리지 전략을 통한 성능 향상 방안
# 		제 4절 서버 성능 개선
# 			- 객체 튜닝
# 			- 인스턴스 튜닝
# 			- 환경 튜닝
#
#
# #############################################################################
# #############################################################################
# 과목 6 데이터 품질 관리 이해
# 	제 1장 데이터 이해
# 		제 1절 데이터 품질 관리 프레임워크
# 			- 데이터 품질 관리 프레임워크
# 		제 2절 표준 데이터
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 표준 단어(Word) 사전
# 				- 표준 도메인(Domain) 사전
# 				- 표준 용어(Terms) 사전
# 				- 표준 코드
# 				- 데이터 표준 요소
# 				- 표준 데이터 상관도
# 		제 3절 모델 데이터
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 		제 4절 관리 데이터
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 사용 관리 데이터
# 				- 장애 및 보안 관리 데이터
# 				- 성능 관리 데이터
# 				- 흐름 관리 데이터
# 				- 품질 관리 데이터
# 		제 5절 업무 데이터
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 원천(Source) 데이터
# 				- 운영(Operation) 데이터
# 				- 분석(Analysis) 데이터
#
#    	제 2장 데이터 구조 이해
# 		제 1절 개념 데이터 모델
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 주제 영역(Subject Area)
# 				- 핵심 엔터티(Kernal Entity)
# 				- 핵심 관계
# 		제 2절 데이터 참조 모델
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 데이터 참조 모델
# 		제 3절 논리 데이터 모델
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 주제 영역(Subject Area)
# 				- 엔터티(Entity)
# 				- 관계(Relationship)
# 				- 속성(Attribute)
# 		제 4절 물리 데이터 모델
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 주제 영역(Subject Area)
# 				- 테이블
# 				- 관계(Relationship)
# 				- 컬럼
# 		제 5절 데이터베이스
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 저장 공간
# 				- 테이블
# 				- 제약 조건
# 				- 인덱스
# 				- 트리거
# 				- DB 링크
# 				- 프로시저
# 				- 뷰
# 				- 동의어
# 				- 롤
# 		제 6절 사용자 뷰
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 화면
# 				- 출력물
#
# 	제 3장 데이터 품질 관리이해
# 		제 1절 데이터 관리 정책
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 데이터 관리 원칙
# 				- 데이터 관리 프로세스
# 				- 데이터 관리 조직
# 			- 데이터 관리 프로세스
# 				- 데이터 관리 프로세스
# 				- 데이터 관리 정책 수립 프로세스
# 		제 2절 데이터 표준 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 			- 데이터 표준 관리 프로세스
# 				- 데이터 표준 관리 프로세스
# 				- 데이터 표준 개선 프로세스
# 		제 3절 요구 사항 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 외부 인터페이스 요건
# 				- 기능 개선 요건
# 				- 성능 개선 요건
# 				- 보안 개선 요건
# 			- 요구 사항 관리 프로세스
# 		제 4절 데이터 모델 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 			- 데이터 모델 관리 프로세스
# 				- 데이터 모델 관리 프로세스
# 				- 데이터 모델 개선 프로세스
# 		제 5절 데이터 흐름 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 			- 데이터 흐름 관리 프로세스
# 				- 데이터 흐름 관리 프로세스
# 		제 6절 데이터베이스 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 			- 데이터베이스 관리 프로세스
# 				- 데이터베이스 관리 프로세스
# 		제 7절 데이터 활용 관리
# 			- 정의 및 관리 목적
# 			- 세부 관리 대상
# 				- 핵심 데이터
# 				- 측정 방법
# 			- 데이터 활용 관리 프로세스
# 				- 데이터 활용 관리 프로세스
