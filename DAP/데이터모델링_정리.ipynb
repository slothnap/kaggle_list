# %% [markdown]
# 1. 데이터 모델링 이해 (p322)
#     - 데이터 모델링 개요
#     - 데이터 모델링 기법 이해
#     - 데이터 모델링 표기법 이해
#     - 관계형 모델 이론
# 2. 데이터 모델링 (p382)
#     - 논리 데이터 모델링 이해
#     - 주제 영역 정의
#     - 엔터티 정의
#     - 관계 정의
#     - 속성 정의
#     - 식별자 확정
#     - 정규화
#     - 이력 관리
#     - 논리 데이터 모델 품질 검토
# 3. 물리 데이터 모델링 (p482)
#     - 물리 데이터 모델링 이해
#     - 물리 요소 조사 및 분석
#     - 논리-물리모델 변환
#     - 반정규화
#     - 물리 데이터 모델 품질 검토

# %% [markdown]
# 1. 데이터 모델링 이해 (p322)
#     - 데이터 모델링 개요
#         - 데이터 모델링 정의
#             - 데이터 모델링 탄생 배경
#             - 정보시스템 개발 방법론
#         - 데이터 모델링의 중요성
#     - 데이터 모델링 기법 이해
#         - 엔터티-관계 데이터 모델
#             - 추상화
#                 - 정의
#                     - 추상화란 현실세계 존재하는 구체적 개체(Entity) 또는 객체(Object)들의 공통된 특징, 즉 추상적 특징을 파악하여
#                       인식의 대상으로 삼는 행위
#                 - 유형화 == 엔터티
#                 - 집단화 == 속성
#                 - 일반화 == 서브타입
#             - 타입과 인스턴스
#                 - 타입: 실제 발생된 사례들을 추상화한 집합
#                 - 인스턴스: 현실 세계에서 실제로 발생된 사례(타입의 멤버)
#         - 엔터티-관계 데이터 모델 구성요소
#             - 엔터티
#                 - 동일한 업무 행위
#                 - 유사한 속성을 갖는 단일 개념
#             - 관계
#                 - 관계는 여러 개의 엔터티를 조인하여 정보를 조회할 수 있다.
#                 - 관계는 중복 데이터를 배제하는 데 도움이 되므로 데이터 정확성 향상에 기여한다.
#             - 속성과 도메인
#                 - 속성은 엔터티에 저장되는 인스턴스들의 특성을 설명하는 항목
#                 - 속성은 값을 추상화한 타입
#                 - 도메인은 하나의 속성이 갖는 같은 종류의 모든 값들의 집합
#             - 식별자
#                 - 일련의 식별자 속성은 반드시 값을 갖는다.
#                 - 일련의 식별자 속성의 값은 유일하다
#                 - 식별자를 구성하는 일련의 속성은 최소한의 개수로 해야 한다.
#     - 데이터 모델링 표기법 이해
#         - 엔터티-관계 데이터 모델 표기법
#             - 엔터티 표기법
#                 - 특성 엔터티
#                 - 연관 엔터티
#                 - 서브타입 엔터티
#             - 속성 표기법
#             - 관계 표기법
#                 - 관계 기수성 표기법
#                     - 일대일 관계
#                     - 일대다 관계
#                     - 다대다 관계
#                 - 관계 선택성 표기법
#                     - 필수 관계
#                     - 선택 관계
#                 - 관계 식별성 표기법
#                     - 식별 관계
#                     - 비식별 관계
#     - 관계형 모델 이론
#         - 릴레이션 개념
#             - 두 개의 집합 x, y가 있을 때 두 집합간의 관계 R을 만족하는 모든 순서쌍
#             - 차수 == 애트리뷰트(속성)
#             - 기수성 == 튜플(row)
#         - 관계형 모델 이론
#             - 관계형 모델 이론
#                 - 데이터 구조
#                 - 데이터 조작
#                 - 데이터 무결성
#             - 데이터 구조
#                 - 각 열은 하나의 값을 가진다.
#                 - 각 열의 값은 동일한 종류이다.
#                 - 각 행은 유일하다.
#                 - 열의 순서는 의미가 없다.
#                 - 행의 순서는 의미가 없다.
#                 - 각 열은 유일한 이름을 갖는다.
#             - 데이터 조작
#                 - 관계 연산자: 조회
#                     - Select
#                     - Project
#                     - Product
#                     - Join
#                     - Union
#                     - Intersection
#                     - Difference
#                     - Division
#                 - 처리 연산자: 관계 테이블의 내용에 변화
#                     - Insert
#                     - Update
#                     - Delete
#             - 데이터 무결성
#                 - 엔터티 무결성 규칙
#                     - 주 키는 널 값을 포함하지 않는다.
#                 - 참조 무결성 규칙
#                     - 관계 엔터티의 모든 외래 키 값은 관련 있는 관계 엔터티의 모든 주 키 값이 존재해야 한다.
#                 - 도메인(속성) 무결성 규칙
#                     - 엔터티 내의 모든 열에 관한 무결성 규칙으로 데이터 타입, 길이, 허용 값, 기본값, 유일성 널 여부 등에 관한 제한이다.
#                 - 연쇄 작용 또는 업무 규칙
#                     - 입력, 삭제, 수정 또는 조회 등의 작업이 동일 엔터티 혹은 다른 엔터티의 속성에 영향을 미치는 업무규칙을 정의하는 것이다.
# 2. 데이터 모델링 (p382)
#     - 논리 데이터 모델링 이해
#         - 논리 데이터 모델링 핵심
#             - 논리 데이터 모델링 필수 성공 요소
#                 - 가능한 많은 시간을 업무에 능통한 현업 사용자와 함께 데이터 모델링을 진행하라
#                 - 절차(Procedure)보다는 데이터에 초점을 두고 모델링을 진행하라
#                 - 데이터의 구조와 무결성을 함께 고려하라
#                 - 개념화와 정규화 기법을 적용하라
#                 - 가능하면 다이어그램을 이용하여 업무를 표현하라
#                 - 데이터 모델링을 지원하는 데이터 사전을 구축하라
#             - 논리 데이터 모델링 목적 및 효과
#                 - 해당 비즈니스에 대한 데이터 관점에서의 명확한 이해
#                 - 전사적인 통합 데이터 체계 확립
#                 - 데이터의 일관성 및 정확성 유지를 위한 규칙 도출
#                 - 안정적인 데이터베이스 설계의 토대 마련
#                 - 정보시스템 관계자와의 명확한 의사소통을 위한 수단으로 활용
#         - 논리 데이터 모델링 절차
#             - 주제 영역 정의
#             - 엔터티 정의
#             - 관계 정의
#             - 속성 정의
#             - 식별자 정의
#             - 정규화
#             - 이력 관리
#     - 주제 영역 정의
#         - 주제 영역 개념
#             - 주제 영역은 주요 자원, 상품, 활동을 중심으로 조직이 관심을 가지는 영역
#             - 하나의 주제 영역 내에 정의되는 엔터티 간의 관계는 밀접하고, 다른 주제 영역에 포함되는 엔터티 간의 상호작용은 최소화할 수 있도록 정의
#         - 주제 영역 도출
#             - 주제 영역 발견 기법
#             - 주제 영역 도출 방안
#                 - 업무 기능의 이름으로부터 도출
#                 - 업무에서 사용하는 데이터의 명사형 도출
#                 - 하향식 접근방법
#                 - 상향식 접근방법
#             - 주제 영역 명명
#                 - 업무에서 사용하는 용어를 부여한다.
#                 - 유일한 단수형 명사를 사용한다.
#                 - 데이터의 그룹을 의미하는 이름을 부여한다.
#         - 주제 영역 활용
#             - 목적
#                 - 업무 분석의 효율을 높인다.
#                 - 업무 기능과 병행하여 분석하는 경우에 모델의 품질 확보에 기여한다.
#                 - 주제 영역 계층과 업무 기능 계층 간의 대응 관계를 확인한다.
#                 - 주제 영역은 기업의 전사 업무를 위한 전체 데이터 구성에 대한 청사진을 제공한다.
#                 - 데이터 구성 및 통합에 대한 방향을 제시한다.
#                 - 효율적 데이터 관리를 위한 기준을 제공한다.
#             - 장점
#                 - 데이터 및 업무 활동 모델의 품질을 보증한다.
#                 - 프로젝트 관리: 업무 범위에 대한 기준을 확보한다.
#                 - 분할 후 정복으로 집중화한 토의를 할 수 있다.
#                 - 모델 개발 조정을 용이하게 한다.
#                 - 저장소 관리를 좀 더 용이하게 한다.
#                 - 상세 사항의 전개 혹은 축약이 가능하다.
#         - 주제 영역 정의 내용
#             - 주제 영역 목록
#                 - 레벨: 주제 영역의 계층 수준
#                 - 주제 영역 명
#                 - 설명(단위 주제 영역의 경우)
#                 - 대표 엔터티: 해당 주제 영역 내에서 대표적인 엔터티를 기술
#         - 주제 영역 사례
#             - 여신 업무, 여신 상담 및 신청, 신용조사, 여신심사, 여신승인, 여신 약정 체결, 여신실행, 여신사후관리
#     - 엔터티 정의
#         - 엔터티 개념
#             - 동일한 업무 행위
#             - 유사한 속성을 갖는 단일 개념으로 정의한 인스턴스들의 집합체
#         - 엔터티 분류
#             - 일반적인 엔터티 분류
#                 - 유형 엔터티
#                     - 물리적으로 존재하는 대상 (고객, 상품)
#                 - 활동 엔터티
#                     - 어떤 사건에 관한 정보 (주문, 계약, 장비 고장)
#                 - 개념 엔터티
#                     - 관리할 정보가 있는 무형의 개념 (계정과목, 성적)
#             - 모델 관점 엔터티 분류
#                 - 독립 엔터티
#                     - 인스턴스를 식별하는 데 있어서 어떤 다른 인스턴스에 의존하지 않는 엔터티 (고객, 제품, 사원)
#                 - 종속 엔터티
#                     - 인스턴스를 식별하는 데 있어서 하나 또는 하나 이상의 다른 인스턴스에 의존하는 엔터티
#                     - 특성 엔터티
#                         - 하나의 인스턴스에 여러 번 발생하는 속성의 그룹으로, 다른 인스턴스에 의하여 직접적으로 인식되지는 않는 엔터티
#                         - ex) 사원경력
#                     - 연관 엔터티
#                         - 두 개 이상의 연관된 다른 엔터티로부터 식별자를 상속 받는 엔터티
#                         - ex) 다대다 관계 해소 시 생성됨
#                     - 서브타입 엔터티
#                         - 다른 부분집합과 구별되는 공통 속성이나 관계를 공유하는 엔터티의 부분집합
#             - 발생 시점 엔터티 분류
#                 - 키 엔터티
#                     - 사람, 상품, 자재 등과 같이 업무행위의 주체나 목적어가 되는 엔터티
#                     - 자신의 부모를 가지지 않는 엔터티
#                     - ex) 사원, 부서, 고객, 상품, 자재
#                 - 메인 엔터티
#                     - 키 엔터티가 행위를 함으로써 발생되는 행위의 집합 중에서 좀 더 하위의 행위를 발생시키는 주체나 목적어가 될 수 있는 엔터티
#                     - 키 엔터티를 제외한 다른 모든 엔터티는 부모 엔터티를 가지고 있어야만 태어날 수 있다.
#                     - ex) 보험계약, 사고, 예금원장, 청구, 주문, 매출 등
#                 - 액션 엔터티
#                     - 키 엔터티와 메인 엔터티가 아닌 것은 모두 액션 엔터티
#                     - ex) 상태 이력, 차량 수리 내역, 상세 주문 내역
#         - 엔터티 도출
#             - 현행 데이터베이스로부터 엔터티 도출
#                 - 현행 데이터베이스가 조직의 정보 요구 사항을 빠짐없이 정확하게 지원하고 있는지를 알기 위해
#                 - 현행 데이터베이스의 구조적인 문제점 및 해결 방안을 도출하기 위해
#                 - 목표 정보 요구 사항을 지원하기 위하여 논리 데이터 모델을 어떻게 생성할지를 결정하기 위해
#                 - 현행 데이터베이스에서 목표 데이터베이스로의 데이터 이행이 필요한 경우 이에 대한 원천 데이터를 정확하게 파악하기 위해서
#             - 정보요구 분석
#             - 업무에서 사용하는 문서로부터 도출
#             - 사용자 인터뷰로부터 도출
#             - 아키텍처 모델로부터 도출
#             - 업무를 수행하는 프로세스로부터 도출
#             - 엔터티 분류 기법을 활용하여 도출
#         - 엔터티 검증
#             - 조직의 업무를 수행하는데 필요한 의미 있는 정보를 나타내야 한다.
#             - 특정 사례가 아닌 유사한 사물들을 대표하는 집합체
#             - 인스턴스가 포함할 내부 연관성 있는 속성에 의해 결정된 단일개념을 대표해야 한다.
#             - 엔터티 내 인스턴스의 출현을 구별할 수 있는 능력을 제공해야 한다.
#             - 정규화 규칙을 만족해야 한다.
#         - 엔터티 정의 사항
#             - 엔터티 명
#             - 엔티터 설명
#             - 엔터티 분류
#             - 현재 발생 건수
#             - 발생 건수 변화
#             - 권한
#             - 식별자 속성
#             - 외래 식별자 속성
#             - 식별자 이외 속성
#         - 엔터티 일반화
#             - 일반화 정의
#                 - 슈퍼타입 엔터티
#                     - 일반화 계층의 가장 상위에 있는 엔터티
#                 - 서브타입 엔터티
#                     - 다른 부분집합과 구별되며, 공통의 속성이나 관계를 공유하는 인스턴스들의 부분집합
#             - 일반화 특성
#                 - 슈퍼타입은 두 개 이상의 독립적인 서브타입으로 구성된다.
#                 - 슈퍼타입은 각 서브타입들의 공통적인 속성과 관계를 가진다.
#                 - 서브타입은 자신의 속성이나 독립적인 관계를 가진다.
#             - 일반화 시점
#                 - 인스턴스가 공통적인 속성 집합을 가질 때
#                 - 인스턴스가 공통적인 관계 집합을 가질 때
#             - 일반화 장단점
#                 - 데이터가 통합되어 있어 조회가 간편
#                 - 공통적이지 않은 속성이 많은 경우 효과가 반감
#     - 관계 정의
#         - 관계 개념
#         - 관계 도출
#         - 관계 정의 사항
#             - 관계 명
#             - 관계요약 설명
#             - 외래 키
#             - 관계유형
#             - 기수성, 선택성
#             - 참조무결성
#         - 특수 관계
#             - 자기 참조 관계
#             - 다대다 관계
#             - 배타적 관계
#                 - 배타적 관계는 보통 동일하다.
#                 - 배타적 관계는 항상 필수이거나 선택이어야 한다.
#                 - 배타적 관계는 반드시 하나의 인스턴스에만 속해야 한다.
#                 - 어떤 엔터티는 다수의 배타적 관계를 가질 수 있다.
#                   그러나 지정된 관계는 단 하나의 배타적 관계에만 사용되어야 한다.
#     - 속성 정의
#         - 속성 개념
#         - 속성 도출
#             - 현행 시스템 자료
#             - 현업 장표·보고서
#             - 사용자와 협의
#             - 데이터 흐름도의 데이터 저장소
#             - 전문 서적 및 자료
#             - 다른 시스템 자료
#         - 속성 정의 사항
#             - 상세 정보의 중요성
#                 - 속성 상세 정보 정의는 업무 관련 데이터의 본질과 목적을 이해하는데 도움을 준다.
#                 - 속성 수준의 무결성을 설정하고 강화하는 데 도움을 준다.
#                 - 데이터 무결성을 개선하여 데이터 품질을 향상시킨다.
#                 - 데이터 사전을 구성한다.
#             - 속성 명
#                 - 의미가 명확한 속성 명칭 부여
#                 - 유일한 복합명사 사용
#                 - 단수형으로 속성 명 사용
#                 - 표준 단어 및 용어 제정
#             - 속성 설명
#             - 선택성 및 선택성 조건
#             - 속성 유형
#                 - 기본 속성: 속성 값이 해당 인스턴스에 원래 존재하여, 다른 속성 값으로부터 유도될 수 없는 속성
#                 - 유도 속성: 속성 값이 항상 다른 속성의 값으로부터 유도되거나 계산되는 속성
#                 - 설계 속성: 업무 제약사항을 반영하거나 시스템 운영을 단순화하기 위하여 생성하는 속성
#             - 유도 알고리즘
#             - 도메인
#             - 허용 값
#             - 기본 값
#             - 소유 권한
#         - 속성 검증 및 확정
#             - 원자 값 단위까지 분할
#             - 하나의 값만을 가지는지 검증
#             - 유도 속성인지 검증
#         - 유도 속성 규칙
#             - 유도 속성은 경영층이 진실로 원하고 필요로 하는 정보를 대표
#             - 유도 속성은 사용자들이 데이터 요구 사항을 나타낸다.
#     - 식별자 확정
#         - 식별자 개념
#             - 식별자 종류
#                 - 기준 정보 엔터티의 본질 식별자
#                 - 거래 처리 엔터티의 본질 식별자
#             - 후보 식별자 도출
#                 - 널이 될 수 없다.
#                 - 각 인스턴스를 유일하게 식별할 수 있어야 한다.
#                 - 나머지 속성들을 직접 식별할 수 있어야 한다.
#                 - 후보 식별자로 속성 집합을 선택하는 경우에는 개념적으로 유일해야 한다.
#                 - 후보 식별자의 데이터는 자주 변경되지 않는 것이어야 한다.
#             - 보조 식별자
#             - 인조 식별자 지정
#                 - 최대한 범용적인 값을 사용한다.
#                 - 유일한 값을 만들기 위한 인조 식별자를 사용한다.
#                 - 하나의 인조 식별자 속성으로 대체할 수 없는 형태를 주의한다.
#                 - 편의성-단순성 확보를 위한 인조 식별자를 사용할 수 있다.
#                 - 의미의 체계화를 위한 인조 식별자를 사용할 수 있다.
#                 - 내부적으로만 사용하는 인조 식별자
#             - 식별자 확정
#                 - 식별 관계의 두 가지 의미
#                     - 식별자로서의 역할
#                     - 정보로서의 역할
#                 - 식별자 상속과 단절의 원리
#                 - 식별자 확정 절차
#                     - 기준 정보 엔터티 식별자 확정
#                     - 중요 거래 처리 엔터티 식별자 확정
#                     - 기타 거래 처리 엔터티 식별자 확정
#     - 정규화
#         - 정규화 정의
#         - 정규화 장점
#             - 중복 값이 줄어든다
#             - 널 값이 줄어준다
#             - 복잡한 코드로 데이터 모델을 보완할 필요가 없다.
#             - 새로운 요구 사항의 발견 과정을 돕는다.
#             - 업무 규칙의 정밀한 포착을 보증한다.
#             - 데이터 구조의 안정성을 최대화한다.
#         - 정규화 과정
#             - 입력 이상
#                 - 어떤 데이터를 입력하려고 할 때 불필요하게 원하지 않는 데이터도 함께 입력해야 하는 구조
#             - 수정 이상
#                 - 일부 속성 값을 수정함에 있어서 원하지 않는 정보의 이상 현상이 발생할 수도 있다.
#             - 삭제 이상
#                 - 일부 정보를 삭제함으로써 유지되어야 할 정보까지도 연쇄 삭제되는 현상이 발생
#             - 제1정규형
#                 - 정의
#                     - 모든 속성은 반드시 하나의 값을 가져야 한다. 즉 반복 형태가 있어서는 안된다.
#                     - 각 속성의 모든 값은 동일한 형식이어야 한다.
#                     - 각 속성들은 유일한 이름을 가져야 한다.
#                     - 행들은 서로 간에 식별 가능해야 한다.
#             - 제2정규형
#                 - 정의
#                     - 식별자가 아닌 모든 속성은 식별자 전체 속성에 완전 종속되어야 한다.
#             - 제3정규형
#                 - 정의
#                     - 제2정규형을 만족하고 식별자를 제외한 나머지 속성들 간의 종속이 존재하면 안 된다.
#     - 이력 관리
#         - 이력 관리 대상 선정
#             - 이력 데이터의 종류
#                 - 발생 이력 데이터
#                 - 변경 이력 데이터
#                 - 진행 이력 데이터
#             - 이력 관리 형태
#                 - 시점 이력
#                     - 데이터의 변경이 발생한 시각만을 관리
#                 - 선분 이력
#                     - 데이터 변경의 시작 시점부터 그 상태의 종료 시점까지 관리
#             - 선분 이력 관리 유형
#                 - 인스턴스 레벨 이력 관리
#                     - 한 번의 액세스로 스냅 샷을 참조하는 것이 가능
#                     - 로그성 데이터를 저장할 목적인 경우 적당한 방법
#                     - 저장 공간의 낭비를 초래할 수도 있다.
#                 - 속성 레벨 이력 관리
#                     - 변경 이벤트가 매우 분명하게 관리
#                     - 변화가 너무 많은 경우에는 적용이 곤란
#                 - 주제 레벨 이력 관리
#                     - 변경 부분만 처리가 가능하다.
#                     - 다른 엔터티와 통합 이력 관리가 가능하다.
#     - 논리 데이터 모델 품질 검토
# 3. 물리 데이터 모델링 (p482)
#     - 물리 데이터 모델링 이해
#         - 물리 데이터 모델 정의
#             - 물리 데이터 모델이란 논리적 모델을 특정 데이터베이스로 설계함으로써 생성된 데이터를 저장할 수 있는 물리적인 스키마
#         - 물리 데이터 모델 의의
#             - 사전에 작성된 논리적 데이터 모델을 각각의 관계형 데이터베이스 관리 시스템의 특성, 기능, 성능 등을 고려하여
#               데이터베이스의 물리적인 구조를 작성해가는 과정
#         - 논리 데이터 모델-물리 데이터 모델
#             - 분산 데이터베이스 구축 시
#             - 물리 데이터 모델 비교
#             - 물리적 환경의 변화
#             - 물리적 모델의 형상 관리
#     - 물리 요소 조사 및 분석
#         - 시스템 구축 관련 명명 규칙
#         - 하드웨어 자원 파악
#             - CPU, 메모리, 디스크, I/O 컨트롤러, 네트워크
#         - 운영체제 및 DBMS 버전 파악
#         - DBMS 파라미터 정보 파악
#         - 데이터베이스 운영과 관련된 관리 요소 파악
#     - 논리-물리모델 변환
#         - 논리 데이터 모델-물리 데이터 모델 변환 용어
#             - 엔터티               -> 테이블
#             - 애트리뷰트           -> 컬럼
#             - 프라이머리 UID       -> 프라이머리 키
#             - 세컨더리 UID         -> 유니크 키
#             - 릴레이션쉽           -> 폴링 키
#             - 비즈니스 컨스트레인츠 -> 체크 컨스트레인츠
#         - 엔터티-테이블 변환
#             - 테이블 설명
#                 - 테이블, 로우, 컬럼, 기본키, 외래키
#             - 서브타입 변환
#                 - 슈퍼타입 기준 테이블 변환
#                     - 정의
#                         - 서브타입을 슈퍼타입에 통합하여 하나의 테이블로 만든다.
#                         - 이 통합된 테이블에는 모든 서브타입의 데이터를 포함해야 한다.
#                         - 주로 서브타입에 적은 양의 속성이나 관계를 가진 경우에 적용된다.
#                     - 하나의 테이블로의 통합이 유리한 경우
#                         - 데이터 액세스가 좀 더 간편
#                         - 뷰를 활용하여 각 서브타입만을 액세스하거나 수정 가능
#                         - 수행 속도가 좋아지는 경우가 많음
#                         - 서브타입 구분 없는 임의 집합의 가공 용이
#                         - 다수의 서브타입을 통합한 경우 조인 감소 효과가 큼
#                         - 복잡한 처리를 하나의 SQL로 통합가기가 용이
#                     - 하나의 테이블로의 통합이 불리한 경우
#                         - 특정 서브타입의 NOT NULL 제한 불가
#                         - 테이블의 컬럼 수가 증가
#                         - 테이블의 블럭 수가 증가
#                         - 처리 시마다 서브타입의 구분이 필요해지는 경우가 많음
#                         - 인덱스 크기가 증가
#                 - 서브타입 기준 테이블 변환
#                     - 정의
#                         - 슈퍼타입 속성들을 각 서브타입에 추가하여 각각의 서브타입마다 하나의 테이블로 만든다.
#                         - 분할된 테이블에는 해당 서브타입의 데이터만 포함돼야 한다.
#                         - 주로 서브타입에 많은 양의 속성이나 관계를 가진 경우에 적용된다.
#                     - 서브타입 기준으로 여러 개의 테이블로 분할한 경우가 유리한 경우
#                         - 각 서브타입 속성들의 선택 사양이 명확한 경우에 유리하다.
#                         - 처리 시마다 서브타입 유형 구분이 불필요하다.
#                         - 전체 테이블 스캔 시 유리하다.
#                         - 단위 테이블의 크기가 감소한다.
#                     - 서브타입 기준으로 여러 개의 테이블로 분할한 경우가 불리한 경우
#                         - 서브타입 구분 없이 데이터 처리하는 경우 UNION이 발생한다.
#                         - 처리 속도가 감소하는 경우가 많다.
#                         - 트랜잭션 처리 시 여러 테이블을 처리하는 경우가 증가한다.
#                         - 복잡한 처리의 SQL 통합이 어려워진다.
#                         - 부분 범위 처리가 불가능해질 수 있다.
#                         - 여러 테이블을 합친 뷰는 조회만 가능하다.
#                         - UID 유지 관리가 어렵다.
#                 - 개별타입 기준 테이블 변환
#                     - 정의
#                         - 슈퍼타입과 서브타입을 각각 테이블로 변환한 경우이다.
#                         - 슈퍼타입과 서브타입 테이블 간에는 1:1 관계가 생성된다.
#                     - 여러 가지 경우를 만족할 때 사용
#                         - 전체 데이터 처리가 빈번하게 발생할 경우에 적용한다.
#                         - 서브타입의 처리는 주로 독립적으로 발생할 경우에 적용한다.
#                         - 테이블을 통합했을 때 컬럼의 수가 너무 많아지는 경우에 적용한다.
#                         - 서브타입의 컬럼 수가 많은 경우에 적용한다.
#                         - 트랜잭션이 주로 공통 부분에서 발생한다.
#                         - 슈퍼타입의 처리 범위가 넓고 빈번하여 단일 테이블 클러스터링을 해야 할 때 적용한다.
#         - 속성-컬럼 변환
#             - 일반 속성 변환
#                 - 컬럼 명칭은 가급적 표준화도니 약어를 사용한다.
#                 - 가급적 컬럼명칭은 짧은 것이 좋으며, 개발 생산성에 긍정적인 영향을 준다.
#         - 관계 변환
#             - 1:1 관계 변환
#                 - 변환 시 주의 사항
#                     - 1:1 관계에 의해서 생긴 모든 외래키 부분은 Unique Key가 필수적이다.
#                     - 한쪽이 Optional이고 다른 한쪽이 mandatory라면 Mandatory 쪽의 테이블에 외래키가 생성된다.
#                     - 양쪽 다 Mandatory라면 변환 시에 어떤 테이블에 외래키를 생성할 것인지를 선택해야 한다.
#             - 배타적 관계 변환
#         - 데이터 표준 적용
#             - 데이터 표준 적용 대상
#                 - 데이터베이스, 스토리지 그룹, 테이블스페이스, 테이블, 컬럼, 인덱스, 뷰
#             - 데이터 표준 적용 방법
#                 - 명명 규칙에 의한 표준화 적용
#                 - 표준 용어집에 의한 표준화 적용
#     - 반정규화
#         - 테이블 분할
#             - 수평 분할
#                 - 개념
#                     - 레코드를 기준으로 테이블을 분할하는 것
#                 - 사용 의의
#                     - 하나의 테이블에 데이터가 너무 많이 있고, 레코드 중에서 특정한 범위만을 주로 액세스하는 경우에 사용
#                     - 분할된 각 테이블은 서로 다른 디스크에 위치시켜 물리적인 디스크의 효용성을 극대화할 수 있다.
#             - 수직 분할
#                 - 유형
#                     - 조회 위주의 컬럼과 갱신 위주의 컬럼으로 나뉘는 경우
#                     - 특별히 자주 조회되는 컬럼이 있는 경우
#                     - 특정 컬럼 크기가 아주 큰 경우
#                     - 특정 컬럼에 보안을 적용해야 하는 경우
#         - 중복 테이블 생성
#             - 중복 테이블 생성 판단 근거
#                 - 정규화에 충실하면 종속성, 활용성은 향상되지만 수행 속도 증가가 발생하는 경우 고려한다.
#                 - 많은 범위를 자주 처리해야 하는 경우에 고려한다.
#                 - 특정 범위의 데이터만 자주 처리되는 경우에 고려한다.
#                 - 처리 범윌르 줄이지 않고는 수행 속도를 개선할 수 없는 경우에 고려한다.
#                 - 요약 자료만 주로 요구되는 경우에 고려한다.
#                 - 추가된 테이블의 처리를 위한 오버헤드를 고려하여 결정한다.
#                 - 인덱스의 조정이나 부분 범위 처리로 유도하거나 클러스터링을 이용하여 해결할 수 있는지를 철저히 검토한 후 결정한다.
#             - 중복 테이블 유형
#                 - 집계(통계) 테이블 추가
#                     - 집계(통계) 테이블 유형
#                         - 단일 테이블의 GROUP BY
#                         - 여러 테이블의 GROUP BY
#                     - 집계 테이블 생성 시 유의 사항
#                         - 클러스터링, 결합 인덱스, 고단위 SQL을 활용하면 굳이 집계 테이블 없이도 양호한 수행 속도를 낼 수 있다.
#                         - 집계 테이블과 원본 데이터는 일관성 유지가 매우 중요하다.
#                 - 진행 테이블 추가
#                     - 진행 테이블 추가 사항
#                         - 여러 테이블의 조인이 빈번히 발생하며 처리 범위도 넓은 경우
#                         - M:M 관계가 포함된 처리의 과정을 추석, 관리하는 경우
#                         - 검색 조건이 여러 테이블에 걸쳐 다양하게 사용되며 복잡하고 처리량이 많은 경우
#                     - 진행 테이블 생성 시 유의 사항
#                         - 데이터량이 적절하고 활용도가 좋아지도록 기본키를 선정
#                         - 필요에 따라 적절한 추출 컬럼을 추가하여 집계 테이블의 역할도 하는 다목적 테이블을 구상
#                         - 다중 테이블 클러스터링이나 조인 SQL을 적절히 이용하면 굳이 진행 테이블을 만들지 않아도 양호한 수행 속도 됨
#             - 중복 컬럼 생성
#                 - 중복 컬럼 생성 상황
#                     - 빈번하게 조인을 일으키는 컬럼
#                     - 조인의 범위가 다량인 경우
#                     - 액세스 조건으로 자주 사용
#                     - 접근 경로 단축을 위해
#                     - 상위 테이블 집계 컬럼 추가
#                     - 미리 연산하는 경우
#                 - 중복 컬럼 생성 시 유의 사항
#                     - 다중 테이블 클러스터링으로 해결할 수 있는지 검토
#                     - SQL GROUP 함수를 사용
#                     - 저장 공간의 지나친 낭비를 고려하여 적절한 대비책 마련
#                     - 성능을 향상시키기 위해서 데이터 일관성을 그르치는 일이 없게
#                     - 컬럼 중복이 지나치게 심하면 데이터 처리의 오버헤드 발생
#     - 물리 데이터 모델 품질 검토

# %% [markdown]
# * 객체지향 - 논리 데이터 모델링 대응
# 	- 객체 - 엔터티
# 	- 연결 - 관계
# 	- 객체 클래스 - 엔터티 유형
# 	- 메시지 - 대응 개념 없음
#
#
# * 데이터 모델링 기본원칙
# 	- 커뮤니케이션 원칙
# 	- 모델링 상세화 원칙
# 	- 논리적 표현 원칙
#
# * 관계형 모델 이론
# 	- 데이터 중심의 분석 기법
# 	- 데이터의 구조와 조작 및 무결성을 정의
# 	- 데이터를 집합적으로 처리를 요구
#
#
# * 비관계형 모델 이론
# 	- 프로세스 중심의 분석 기법
# 	- 데이터의 구조와 조작을 정의
# 	- 데이터의 레코드 처리를 요구
#
#
# * 논리 데이터 모델링
# 	- 정의
# 		- 논리 데이터 모델은 논리적 관점에서 데이터 모델링이 최종적으로 완료된 상태를 말한다.
# 		- 비즈니스 데이터에 존재하는 사실을 인식 - 기록하는 기법이다.
# 		- 데이터 모델링 과정에서 가장 핵심이 되는 부분으로 분석 초기 단계에서부터 인간이 결정해야 할
# 		  대부분의 사항을 모두 정의함으로써 설계의 전 과정을 지원하는 '과정의 도구'라고 할 수 있다.
# 	- 목적 및 효과
# 		- 해당 비즈니스에 대해 데이터 관점에서 명확한 이해가 가능하다.
# 		- 사용자와 명확한 의사소통을 하기 위한 수단으로 활용된다.
# 		- 데이터의 일관성 및 정확성 유지를 위한 규칙을 도출할 수 있다.
# 	- 필수 성공 요소
# 		- 현업 사용자 참여가 필수적이다.
# 		- 절차 보다는 데이터에 초점을 두고 모델링을 진행해야 한다.
# 		- 데이터의 구조와 무결성을 함께 고려해야 한다.
#
#
#
# * 물리 데이터 모델링
# 	- 정의
# 		- 전사화 대상 시스템의 형태, 목적 등에 의해 영향을 받는다.
# 	- 목적 및 효과
# 		- 데이터베이스를 구성하는 오브젝트들의 설계 전략이 반영되어 있다.
#
#
#
# * 관계 연산자
# 	- select(or Restrict): 열에 의거한 행의 Subset
# 	- Product: 두 관계 테이블 간의 행 조합의 묶음
# 	- Division: 다른 관계 테이블의 모든 행에 대응하는 열을 제외한 열
# 	- Project: 열(Column)의 Subset
#
# * 처리 연산자
# 	- Insert
# 	- Update
# 	- Delete
#
#
#
#
#
# * 참조 무결성 규칙
# 	- 입력 규칙
# 		- Dependent
# 			- 대응되는 부모 실체에 인스턴스가 있는 경우에만 자식 실체에 입력을 허용
# 		- Nullify
# 			- 자식 실체 인스턴스의 입력을 항상 허용하고, 대응되는 부모 건이 없는 경우
# 			  자식 실체의 Foreing Key를 Null 값으로 처리한다.
# 		- Customized
# 			- 특정한 검증조건이 만족되는 경우에만 자식 실체 인스턴스의 입력을 허용한다.
# 		- Default
# 			- 자식 실체 인스턴스의 입력을 항상 허용하고, 대응되는 부모 건이 없는 경우
# 			  자식 실체의 Foreing key를 지정된 기본 값으로 처리한다.
#
#
#
# * 데이터 무결성
# 	- 실체 무결성
# 	- 연쇄 작용
# 	- 참조 무결성
# 	- 영역(속성) 무결성
# 	- 정규화
#
#
#
#
# * 서브타입
# 	- 서브타입 개체는 그것의 슈퍼타입이라 불리는 다른 개체의 특별한 경우이다.
# 	- 서브타입은 배타적이며 포괄적이다.
# 	- 슈퍼타입은 서브타입에 공통적인 모든 속성을 포함한다.
# 	- 모든 슈퍼타입이 구분자를 가지고 있는 것은 아니다.
# 	- 서브타입 간에는 교집합이 존재하지 않아야 한다.
# 	- 서브타입을 모두 결합하면 반드시 전체 집합이 되어야 한다.
#
#
#
#
#
# * 주제영역
# 	- 설명 및 장점
# 		- 주제 영역은 시스템의 대상이 되는 업무를 명백하게 구분이 가능한 단위 업무로 분리하는 개념이다.
# 		- 주제 영역을 결정할 때는 주제 영역 내부에 존재하게 될 개체들이 높은 결합성을 유지하게 해야 한다.
# 		- 주제 영역은 프로세스 모델링의 Function과 매핑 관계를 가지는 것이 보통이다.
# 		- 데이터 및 업무활동 모델의 품질보증이 용이함
# 		- 프로젝트 관리가 용이함
# 		- 모델 개발조정이 용이하고 요구사항 검증 시 기준으로 활용 가능함
# 	- 후보 도출 방법
# 		- 업무에서 사용하는 데이터의 명사형을 도출
# 		- 업무기능의 이름으로부터 도출
# 		- 업무 관리자의 이견을 참조하여 도출
#
#
# * 엔터티
# 	- 후보 도출 방법
# 		- 중요 보고서 제목을 참조하여 도출
# 		- 너무 깊지 않게
# 		- 단어 하나하나에 집중
# 		- 프로세스에 연연해하지 말아야 한다.
# 	- 엔터티 검증
# 		- 엔터티의 개념을 확실하게 모델러들이 정립해야 한다.
# 		- 새로운 목적 시스템에서 관리하고자 하는 대상 집합이 있는지 확인해야 한다.
# 		- 엔터티에 가로(속성)와 새로(개체)를 가진 면적(집합)을 가진 속성이 존재하는지 확인해야 한다.
#
#
# * 속성
# 	- 속성 검증 작업
# 		- 원자단위 검증
# 		- 유일값 검증
# 		- 추출값 검증
# 	- 속성 검증 방법
# 		- 최소 단위 분할 여부를 판단
# 		- 해당 속성 후보가 단일값을 갖는지 판단
# 		- 추출 속성인지 판단
# 	- 실체 정의
# 		- 구별 가능한 사람, 장소, 물건, 행위 또는 개념 등에 대하여 정보가 유지되어야 하는 것
# 		- 다른 것과 구별되어 식별될 수 있는 사물
# 	- 정의
# 		- 더 이상 분리되어지지 않는 단위 값(Atomic Value)
# 		- 실체를 서술하며 양을 계수화하고 자격을 부여 - 분류하며 구체적으로 기입하는 정보항목
# 		- 엔터티에 통합되는 구체적인 정보항목으로써 더이상 분리될 수 없는 최소의 데이터 보관 단위
# 		- 관계도 속성이다.
# 		- 속성들은 서로 독립적이고 식별자에만 종속되어야 한다.
# 	- 후보 도출
# 		- 현업장표/보고서
# 		- 사용자 인터뷰
# 		- 타 시스템 자료
#
#
#
# * 관계
# 	- 정의
# 		- 관계도 집합이다.
# 		- 집합 간에 존재하는 무수히 많은 관계 중에 직접종속인 것만을 관계로 모델링한다.
# 		- 두 엔터티 간에는 하나 이상의 관계가 얼마든지 존재할 수 있다.
# 	- 다대다 관계 해소 시점
# 		- 자신만의 속성을 가져야 할 때
# 		- 자식을 가져야 할 때
# 		- 자신만의 속성을 갖지 않거나 자식을 갖지 않는 경우는 논리 모델 상세화 단계
#
#
#
# * 아크 관계
# 	- 아크 내에 있는 관계는 보통 동일하다.
# 	- 아크 내에 있는 관계는 항상 Mandatory거나 Optional이어야 한다.
# 	- 아크는 반드시 하나의 엔터티에만 속해야 한다.
# 	- 어떤 엔터티는 다수의 아크를 가질 수 있다, 그러나 지정된 관계는 단 하나의 아크에만 사용
#
#
# * 식별자
# 	- 식별자 고려사항
# 		- 상위 엔터티로부터 하위 엔터티로 결정해가는 것이 좋다.
# 		- 메인 엔터티는 하위 엔터티들에 대한 영향이 크기 때문에 식별자 속성의 갯수를 적게 하는 것이 좋다.
# 		- 인조 식별자의 사용은 꼭 필요한 경우에만 한정적으로 사용하는 것이 바람직하다.
#
#
# * 인조식별자
# 	- 설명
# 		- 최대한 범용적인 값을 사용한다.
# 		- 유일한 값을 만들기 위해 인조 식별자를 사용한다.
# 		- 편의성 · 단순성 확보를 위해 인조 식별자를 사용할 수 있다.

# %% [markdown]
# * 실전문제 (p66)
# * 답 (p167)
#
#
# 121. 2
# 	 - 커뮤니케이션 원칙 : 요구 사항은 모든 사람들이 이해할 수 있도록 명확하게 공표됨은 물론 최종 사용자 지향적으로 분명하게 파악되는 수준으로 작성되어야 한다.
#        모델링 상세화 원칙 : 데이터의 상세화 정도를 제시하고, 조직이 사용하는 정보 구조의 ‘최소 공통 분모’ 를 제시해야 한다.
#        논리적 표현 원칙 : 모델은 물리적 제약조건 없이 비즈니스를 그대로 반영해야 한다. 즉, 논리적 데이터 모델은 특정 아키텍처, 기술 또는 제품 등에
#                          독립적이어야 한다.
#
# 122. 2
# 	 - 문제의 아래는 참조 무결성을 설명하고 있다. 이 러한 모델에서의 참조 무결성 규칙은 실제 스키마 의 제약조건으로 생성되게 되면 관련된 테이블
#         레코드간의 관계를 유효하게 하고 사용자 실수로 데 이터를 삭제하거나 변경하지 않도록 하기 위한 규 칙이라고 정의할 수 있다.
#
# 123. 2 / 3
# 	 - 3은 개체-관계 모델에 대한 설명보다는 객체지 향 모델링에 대한 설명이다.
#
# 124. 2 / 1
#      - 데이터를 중복해서 가지고 있으면 데이터 무결성 이 깨질 수 있으므로 중복을 피해야 한다.
#
# 125. 3 / 4
# 	 - 논리 데이터 모델링의 개념을 잘 이해하는 분석가 들은 데이터가 프로세스에 종속하지 않는 방식으 로 데이터와 프로세스의 개념을 결합한다.
#        이것은 객체지향 모델링에 기반한 애플리 케이션을 연구하 고 이해하는 사람들이기 때문이다. 4는 객체지향 모델링의 접근 방식에 대한 내용으로
#        장점과는 거 리가 멀다.
#
# 126. 1 / 2
# 	 - ‘논리적’이라는 용어는 논리 데이터 모델링이 현 실 세계를 추상화기 때문에 사용한다. 개념화 기 법을 적용하여 모델을 만드는데도 이유가 될 수 있 다.
#        또한 현실의 물리적인 장표나 데이터베이스 같은 것이 실질적인 개념이 아니기 때문에 논리적 （개념적）이라는 용어를 사용하는 것이다.
#
# 127. 2
# 	 - 엔터티의 유일성을 보장해주는 것이 식별자이다. 다른 것들은 복수개의 값들이 존재할 수 있기 때문 에 유일성을 보장해 주지 못한다.
#
# 128. 4
# 	 - 관계형 모델 이론이 데이터를 분석하는데 비관계 형 이론보다 반드시 우수하지는 않다.
#
# 129. 2
# 	 - 잘 설계된 논리적 모델은 비록 업무방식이 바뀌어 도 업무영역이 바뀌지 않는다면 설계 변경이 거의 발생하지 않는다.
#
# 130. 1, 4 / 4
# 	 - 4번은 관계 연산자가 아니라 처리 연산자 중에 하 나를 설명하고 있다.
#
# 131. 4
# 	 - 4번의 설명은 도출 공식에 관한 설명이지 도출 속 성에 대한 설명이 아니다.
#
# 132. 3
# 	 - 3번은 처리 연산자가 아니라 관계 연산자 중에 하나를 설명하고 있다.
#
# 133. 3 / 4
# 	 - 누구나 같은 의미로 정확하게 뜻을 알 수 있는 단 어를 사용해야 한다.
#
# 134. 1
# 	 - 참조 무결성은 관계에 관한 것이고, 영역과 속성 무결성은 같은 의미로 속성이 가져야 하는 값에 대 한 무결성이다.
#
# 135. 1 / 3
# 	 - 아크는 반드시 하나의 엔터 티에만 속해야 한다.（하 나의 아크가 여러 엔터티를 가질 수 없다.）
#
# 136. 3 / 4
# 	 - 4번을 올바르게 설명하면 “자식 실체 인스턴스의 입 력을 항상 허용하고 대응되는 부모 건이 없을 경우에 Foreign Key를 지정된 기본 값으로 처리한다.” 이다.
#
# 137. 4
# 	 - 설명은 속성의 검증에 관련된 것이 아니고 속성 후 보를 다양한 경로를 통해서 좋은 속성 후보를 확보 하는 방법을 설명한 것이다.
#
# 138. 3
# 	 - 연쇄작용은 비즈니스 규칙으로 어느 실체에 데이 터의 값이 입력, 수정, 삭제 될 때 그 실체 내지는 다른 실체의 데이터 값에 영향도를 분석하는 것으로
#        데이터의 무결성과 관계가 깊다. 정규화를 잘 못하면 입력, 수정, 삭제 이상이 발생할 수 있다. 인덱스는 수행 성능의 향상을 위한 기법이다.
#
# 139. 1 / 4
# 	 - 4번의 설명은 모델링을 순차적으로 접근해 가야 할 형태별로 분류하는 이유이다.
#
# 140. 4 / 3
# 	 - 아직 대학 졸업장을 가지 지 못한 전도유망한 사람 을 고용한다고 하였으므로 사원과 사원취득대학학 위는 한쪽 선택 적으로 표현해야 한다.
#
# 141. 1
# 	 - 1번은 개념 데이터 모델 단계의 일부분이다.
#
# 142. 3 / 3,4
# 	 - 1번과 2번은 실체 정의를 설명한 것이며, 3번 과 4번은 속성 정의를 설명한 내용이다.
#
# 143. 2
# 	 - 식별자는 개체를 위한 것이며, 키는 테이블이 가진다.
#
# 144. 3 / 1,3
# 	 - 실체는 동질성을 갖는 인스턴스들의 집합이다. ‘영업 담당자’ , ‘인사 담당자’ , ‘구매 담당자’ 등 의 실체를 만든다면 일반화와 추상화 기법에 위배 되며
#        엄청나게 많은 실체를 정의해야 할 것이다. ‘규손금’은 ‘규정 손실금’의 약어로 이런 형태의 실체명을 만드는 것은 논리 데이터 모델링에서 삼 가야 하는
#        사항이다. 왜냐하면 비즈니스 규칙과 관계된 모든 사람들에게 직관적으로 의미를 파악 할 수 있는 명명 규칙이 유용하기 때문이다.
#
# 145. 3 / 2,3
# 	 - 상담 실체의 인스턴스를 인식할 때는 영업담당자 가 누구인지를 반드시 알아야 할 필요가 없기 때문 에 UID Bar를 사용하지 않아도 된다.
#        또한 상식 적으로 당초계약이 발생할 때는 실행계약의 인스턴스가 발생하는 것이 아니므로 양쪽 필수 관계일 필요는 없다.
#
# 146. 2
# 	 - 서브타입은 배타적이며 포괄적이다.
#
# 147. 3
# 	 - 객체 클래스-엔터티 유형
#
# 148. 4
# 	 - 표의 ‘라’ 는 바커 표기법의 관계가 아니라 I/E 표 기법의 관계(Relationship) 예이다
#
# 149. 4
# 	 - 배타관계는 엔터티간의 업무적 연관성을 논리적인 관점에서 명확하게 표현하고 있지만, 실제 데이터 베이스의 저장 구조로 구현되었을 때 애플리케이 션의
#        성능이나 업무 변경에 대한 유연성 확보 등을 고려하여 배타관계에 있는 엔터티들을 하나로 통 합하여 물리 데이터 모델로 정의할 수도 있다.
#
# 150. 4
# 	 - 보통 관계형 모델링에서 비전이성은 별도로 표시 하지만 전이 성은 표현하지 않는다.
#
# 151. 1
# 	 - 정규화, 속성 정의, 참조 무결성 정의 등은 논리 데이터 모델링 과정에서 정의해야할 사항이다.
#
# 152. 4
# 	 - 부서는 조직의 업무에 따라 수시로 바뀌기 때문에 유연하게 대응하기 위해서는 순환 관계 기법으로 모델링을 해야 한다.
#
# 153. 3
# 	 - 주제영역을 계층적으로 표현하고 Top-Down 방 식으로 데이터 모델을 생성하는 것은 체계적인 분 석에 많은 도움을 준다.
#
# 154. 4 / 3
# 	 - 하나의 주제영역에 존재하게 될 데이터 개체들은 높은 결합성을 가지도록 주제영역을 설계하는 것 이 필요하다.
#        3번은 주제영역 활용의 장점으로 생산성 향상과는 관계가 적고 주제영역을 활용함으 로 인해 개발기간이 단축된다고 보기에는 어렵다.
#        데이터 모델링의 주제영역은 프로세스 모델링의 Function과 매핑 관계를 가지는 것이 보통이다.
#
# 155. 1 / 2
# 	 - 주제영역을 활용하는 장점으로 생산성 향상은 관 계가 적다. 또한 주제영역을 활용한다고 프로젝트 전체의 개발 기간이 단축 된다고 볼 수 없다.
#
# 156. 2
# 	 - ‘고객’과의 연관관계는 논리 데이터 모델링 단계 에서 검토되어야 바람직하다. 이력 관리 방안도 집합들이 모두 정의되고 식별자도 정의되어야만
#        가능한부분이다. ‘소속점명’을검토하면서 ‘소속 점’ 을 관리하는 것이 필요하다고 판단하면 ‘소속 점’ 을 엔터티 후보로 도출하는 것이 바람직하다.
#
# 157. 3, 4
# 	 - 중요 보고서 제목은 향후 정의될 엔터티의 후보가 될 수 있다. 또한 시스템 관리자 보다는 업무 관리 자의 의견을 참조하여 주제영역을 생성한다.
#
# 158. 4 / 2
# 	 - 2번에서 한쪽에 인스턴스를 입력하려면 다른 쪽 에 반드시 값이 있어야 한다는 것이 모순이다. 한 쪽을 양쪽 선택적 관계로 바꾸어야 한다.
#
# 159. 2
# 	 - 개념 데이터 모델링에서는 엔터티의 상세 분석을 수행하는 것은 아니다. 또한 개념 데이터 모델 단계 에서 개념에 대해서는 확실하게 정립하여야 한다.
#
# 160. 1
# 	 - 엔터티 후보 식별 단계에서는 해당 엔터티의 개념을 파악하거나 엔터티를 명확히 구분 짓기 위한 속 성들에 대해서 업무담당자와 상의할 수 있다.
#        그러나 일반속성（여기에서는 ‘생년월일’ ）을 이 단계 에서 언급하는 것은 부적절하다.
#
# 161. 3
# 	 - Intersection Entity（교차 엔터티）는 다대다（M：M） 관계의 해소로 생기는 엔터티를 말한다. 교차 엔터티 는 개념 데이터 모델에서 생성되기 보다는
#        논리 데이 터 모델링 단계에서 생성되고, 역할에 따른 분류에는 대부분 Action Entity에 속하는 것이 보통이다.
#
# 162. 4
# 	 - 4번은 모순이다. 왜냐하면 배타적 관계는 모두 선택적이든지 또는 모두 필수적이어야 한다. 한 쪽만 선택적이든지 혹은 한 쪽만 필수적이면 배타적 관계가
#        형성될 수 없기 때문이다.
#        1번은 양쪽 선택적인데 이 것은 관계를 하나도 맺지 않는 업무 를 설명하고 있다.
#        3번은 둘 중에 하나와 관계를 맺는데 반드시 관계가 하나는 있다는 업무 규칙이 다.
#        2번의 기수성（Cardinality, Degree）은 배타적 관계에 아무 영향을 미치지 않는다.
#
# 163. 2, 4 + 3 / 3,4
# 	 - 개념 데이터 모델링에서는 부서 엔터티 자체의 정 의를 명확히 하는 것은 바란직하지만 부서 엔터 티 와 연관된 하위 엔터티들을 정의하는 것은
#        수평적 사고를 방해할 위험요소가 있기 때문에 바람직한 모델링의 방향이라 할 수 없다.
#
# 164. 2
# 	 - 후보키는 후보키 이외의 나머지 속성들을 직접 식별 할 수 있어야 이러한 사항을 어기면 향후 정규화（2, 3정규화） 과정에서 정규화 위배로 도출되 게 된다.
#
# 165. 1 / 4
# 	 - 엔터티 후보를 도출하는 단계에서 주제영역 분류 에 대한 언급은 부적절하다.
#
# 166. 1, 2 / 3
# 	 - 직렬 관계는 여러 개의 로우(Row)로 나누어진다.
#
# 167. 2 / 1
# 	 - 1 신용카드의 카드번호는 실질 식별자에 해당한 다. 즉, 인조 식별자(Artificial UID)에 해당한다.
#        실제 본질 식별자에 해당하는 속성은 고객번호, 카드상품코드, 카드발급일시 등의 속성이 본질 식 별자라고 할 수 있다.
#
# 168. 2 / 4
# 	 - ‘계약속성정보A’와 같은 방식의 관리에서 이력을 관리하기 위해서는 추가 UID 속성을 추가하여 관리하는 것이 일반적인 방법이다.
#
# 169. 1
#      - 대부분의 코드성 엔터티는 개념 데이터 모델링 단 계에서 굳이 엔터티로 도출하지 않아도 무관하다. 하지만 그렇지 않은 경우도 발생한다.
#        즉, 코드성 엔터티가 여러 하위 엔터티를 가지는 경우가 대표 적인 경우이다. 본질 식별자라고 해서 무조건 엔터티로 도출하기 보다는
#        많은 다양한 관계를 가질때 엔터티로 도출 하는 것이 바람직하다.
#        코드성 엔터티의 도출은 개념 데이터 모델에서 꼭 필요한 과정이 라고 볼 수 없다.
#
# 170. 4
# 	 - 수행 성능은 물리적인 요소(인덱스, 저장 기법 등) 이다.
#
# 171. 2 / 1
# 	 - 대부분의 보험사에서 피보험자, 납입자 등은 엔터티 라기 보다는 고객 엔터티와 업무를 표현하고 있는 ‘계약 엔터티와의 관계라고 보는 것이 더 합당하다.
#
# 172. 1
# 	 - 속성의 원자성은 관계형 모델의 이론적 배경이다. 원자성은 비즈니스에서 의미 있는 최소한의 속성단위이다. ‘계좌번호’ 가 문제의 지문과 같이 구성 된 것은
#        속성이 비원자적으로 구성되어 있기 때문 에 ‘구매일자’ 가 지문과 같이 구성된 것은 의미가 없다. ‘구매월’을 모르는 ‘구매일’은 의미가 없고 ‘구매년도’ 를
#        모르는 ‘구매월’ 도 의미가 없다. 즉, ‘구매일’이 25일 이라면 이것이 몇 년, 몇 월의 ‘구매일’ 인지 모른다면 의미가 없다.
#        물론 카드결 제일자가 25일이라는 것은 비즈니스적으로 의미 가 있지만 ‘구매일자’와 같은 속성은 연월일이 있 어야 비로소 의미가 있다.
#
# 173. 1, 3 / 3,4
# 	 - 서브타입은 물리 데이터 모델링 단계에서 별개의 테이블로 생성될 수 있고, 하나의 테이블로 병합 될 수도 있다.
#        물리 모델로 전환하기 위한 기준을 마련한다면 복 잡성을 증가시키 지는 않는다.
#
# 174. 4 / 2
# 	 - 공정제어 집합에 대하여 분석을 실시하는 것은 이 단계 즉, 개념 데이터 모델링 단계에서 언급할 부 분은 아니다.
#
# 175. 2, 4
# 	 - 소수의 선택속성이 존재한다면 굳이 서브타입으로 구분할 필요는 없다. 엔터티 단순화와는 거리가 멀다.
#
# 176. 3 / 1
# 	 - ‘사원’은 ‘부서’에 종속되어 있으므로 사원의 부 서를 알면 ‘접수부서’ 를 알 수 있다. 이것은 데이 터 논리 모델에서 관계 중복에 해당한다.
#        만약 주 문 데이터를 액세스하는데 속도가 느려진다면 조 인의 효율을 위하여 부서와 관계를 설정하여 반정 규화 할 수 있지만 논리 데이터 모델에서는
#        데이터 의 이상 현상이 발생할 수 있으므로 이러한 모델링 은 삼가해야 한다.
#
# 177. 1
# 	 - 엔터티의 통합은 향후에 유연성이 크게 향상된다. 또한 통합을 통해서 배타적관계의 가능성을 줄여 줄 수 있다. 하지만 무리한 통합은
#        집합의 독립성 을 저해하는 결과를 초래한다.
#
# 178. 4 / 2
# 	 - 개념 데이터 모델링 단계에서는 다대다（M：M） 관 계를 풀지 않지만, 논■리 데이터 모델링 단계에서 는 두개의 일대다（1：M）관계 엔터티로 생성하게 된다.
#
# 179. 4 / 3,4
# 	 - 직접 종속, 간접 종속 등의 관계 속성들을 모델링 한다. 두 엔터티 간에는 하나 이상의 관계가 얼마 든지 존재할 수 있다.
#
# 180. 3 / 1
# 	 - ‘금융기관’은 관계라고 보기에는 어렵다. 왜냐하 면 ‘금융’ 은 ‘기관’ 이라는 큰 집합의 특정 부분집 합을 나타내기 위해서 사용된 말이기 때문이다.
#        마치 전체 집합인 ‘고객’의 일부를 ‘법인고객’으 로 표현한 것과 같은 이치이다.
#
# 181. 4 / 2
# 	 - 전산화 대상 시스템의 형태, 목적 등에 의해 영향 을 받는 것은 물리 데이터 모델이다. 물리 데이터 모델은 논리 데이터 모델링 과정에서
#        정의된 내용을 기반으로 물리적인 요소, 시스템 상황 등을 고 려하여 생성한다.
#
# 182. 3
# 	 - 식별자가 ‘주문번호’이고, ‘공급자명’과 ‘공급자 주소’ 는 식별자가 아닌 ‘공급자코드’ 에 종속된 속 성으로 3차 정규화를 실시해야 한다.
#
# 183. 2
# 	 - 데이터베이스를 구성하는 오브젝트들의 설계 전략 은 물리 데이터 모델링 단계에서 생성된다. 특히,파티션닝 전략 등의 내용이 물리 데이터 모델에 포함되어 있다.
#
# 184. 4 / 2
# 	 - 하위 엔터티를 위해서는 최대한 통합을 유도하는 것이 바람직하다. 경우에 따라서는 하나의 집합이 완전히 포함되어지는 통합이 일어나는 경우도 발 생한다.
#        새로운 유형의 집합이 추가되더 라도 새로 운 엔터 티나 기존에는 관계의 변화가 일어나지 않 으면서 부분 집합（서브타입）만 증가하는 형태가 바 람직하다.
#        이를 위해서는 통합을 유도하는 것이 좋다.
#
# 185. 1, 4
# 	 - 데이터 모델링 과정에는 현업사용자의 참여가 필 수적이다. 데이터 모델링을 지원하는 CASE 툴을 사용하면 많은 도움을 줄 수 있다.
#
# 186. 2 / 4
# 	 - 신용카드는 카드를 발급 받은 사람과 발급해 준 카 드사의 상품이 반드시 존재해야만 태어날 수 있는 엔터티이다.
#        따라서 우선순위가 가장 높은 것이라고 보기는 어렵다.
#
# 187. 4
# 	 - 다른 시스템의 문서를 참조하는 것은 현재 시스템 의 개선점을 파악하기 위해서 필요하다.
#        또한 미 쳐 생각하지 못했던 관리 속성들을 추출하기 위한 중요한 소스로도 사용 할 수 있다.
#
# 188. 4
# 	 - 4번은 참조 무결성이 해결하지 못하는 연쇄작용에 의한 데이터 무결성이다.
#
# 189. 4 / 1
# 	 - 속성은 엔터티 내에서 관리해야 할 구체적은 관리항 목이다. 그렇기 때문에 중장기 마스터플랜（Master Plan）에서 속성 후보를 도출한다고 보기는 어렵다.
#
# 190. 2 / 1
# 	 - 2번의 필수-필수 일대일（1：1） 관계는 무리한 수직 분할을 시도하였을 경우에 많이 나타나는 관계의 형태이다.
#        3번의 선택-선택 일대일（1：1） 관계는 데이터 모델링 과정에서 드물게 발생하는 형태이 다.
#        4번의 일대일（1：1） 관계도 때로는 필요하다.
#
# 191. 3 / 4
# 	 - 실별자 검증은 속성 검증이 완료되고 해당 엔터티 내에서 식별자를 지정하게 된다. 따라서 식별자로 사용되는지를 판단하는 것은 속성 검증과는 거리 가 멀다.
#
# 192. 4 / 3
# 	 - 3번은 변화 가능성이 많으므로 데이터 모델에 정 의하면 유지보수에 문제가 발생할 수 있기 때문에 매트릭스 분석 기법을 통한 상호작용 분석으로
#        수 행하는 것이 향후 긍정적 효과를 나타날 수 있다.
#
# 193. 2
# 	 - 속성은 최소단위로 분할해서 정의하는 것이 일반 적이다. 하지만 경우에 따라서는 복합속성을 구성 하는 것도 가능하다.
#
# 194. 1
# 	 - ‘고객주소이력i’, ‘고객주소이력家 등의 형태와 ‘법인고객관리’ 의 형태와는 무관하다.
#
# 195. 1
# 	 - 제 1 정규화란 하나의 속성은 반복되는 중복값을 가질 수 없다는 것이다. 하나의 속성이 중복값을 가지기 위해서는 새로운 엔터티를 생성해야 한다.
#
# 196. 4
# 	 - 구조가 변경되더라도 식별자는 변경되지 않기 때 문에 과거 데이터를 변경할 필요가 없다.
#
# 197. 4
# 	 - ‘결혼 기념일’은 ‘고객’ 엔터티의 추출 속성이라기 보다는 본래의 속성이라고 보는 것이 적절하다.
#
# 198. 1 / 4
# 	 - 의미상으로 식별자의 역할을 하는 속성들은 누가, 무엇을, 언제, 어디서 등과 같은 육하원칙에 해당 하는 속성들의 그룹을 일컫는다.
#
# 199. 3 / 2,3
# 	 - 전화번호가 어떤 전화 번호인지가 명확하게 정의 되는 것이 바람직하다. 순번, 상태 등과 같이 주어 부분이 빠진 형태의 용어는 속성으로 바람직하지 않는다.
#
# 200. 2 / 4
# 	 - 1 너무 깊지 않게, 2 단어 하나하나에 집중, 3 프로세스에 연연해하지 말아야
#
# 201. 4
# 	 - 여러 개의 속성들을 묶어서 식별자로 생성할 수 있다.
#
# 202. 1 / 2
# 	 - 세월이 흐르면 사원의 부서가 바뀌며 상품의 단가 도 세월이 흐르면 바뀔 수 있다. 또한 금융 상품의 이자율도 세월이 흐르며 바뀔 수 있다.
#
# 203. 4
# 	 - 경우에 따라서는 내부적으로만 사용되는 인조 식 별자를 사용 할 수도 있다. 특히, 시스템에서 사용 하는 데이터들에 이러한 유형의 식별자가 많이 존 재한다.
#
# 204. 1
# 	 - 정보공학방법에서 동그라미가 없는 것은 필수 관 계를 말하고, CASE*Method에서는 실선이 필수 관계를 표현한다.
#
# 205. 3
# 	 - 인조 식별자의 사용은 꼭 필요한 경우에만 한정적으로 사용하는 것이 바람직하다.
#        하위 엔터티는 다시 자식 엔터티를 가질 가능성이 적으므로 정보 의 단절과는 거리가 멀다.
#
# 206. 4 / 2
# 	 - 2번과 같은 상황에서 가장 먼저 해야 할 일은 해 당 반복 속성의 내용을 업무담당자를 통하여 정확 히 파악하는 것이다.
#
# 207. 3
# 	 - 1차 정규형 : 반복 속성은 존재할 수 없다. 반복 속 성을 해소 하기 위해서는 자식 엔터티를 생성하게 된다.
#        2차 정규형 : 모든 속성은 식별자 전체에 종속되어 야 한다.
#        그렇지 않은 경우에는 부모 엔터티가 추 가된다.
#        이때 부모 엔터티로부터 관계에 식별자가 포함되어 진다.
#
# 208. 3 / 2
# 	 - 매일매일이므로 일자별로 관리하면 굳이 기간으로 괸-리할 필요기- 없다.
#
# 209. 4
# 	 - 새로운 추가 요구 사항의 반영은 프로젝트 관리 측 면에서 다루어져야 할 부분이다.
#        특히, 이러한 요구 사항의 체계적인 관리는 전체 프로젝트의 성패와도 직결되는 문제이기 때문에 신중을 기해야 한다.
#
# 210. 4
# 	 - 1번과 같이 조치를 취한다면 데이터 무결성을 깨지 않으므로 사용하지 않는 것 보다 유리할 수 있다.
#
# 211. 2, 4 / 3,4
# 	 - 다대다（M：M） 관계는 발생 즉시（개념 데이터 모델 링 단계에서 해소하지 않고 논리 데이터 모델링의 마지막 부분）해소하는 것이 바람직하다.
#        다대다（M：M） 관계가 해소되면 두 개의 일대다 （1：M） 관계를 가지는 새로운 엔터티가 생성된다.
#
# 212. 2 / 4
# 	 - 다른 시스템의 문서를 참조하는 것은 현재 시스템 의 개선점을 파악하기 위해서 필요하다.
#        또한 미 쳐 생각하지 못했던 관리 속성들을 추출하기 위해 서 중요한 소스로서 사용할 수 있다.
#
# 213. 4
# 	 - 삭제 규칙은 부모 실체의 인스턴스를 삭제 할 때 사용되는 참조 무결성 규칙이다.
#
# 214. 1
# 	 - 1번은 제 1 정규형에 대한 설명이다.
#
# 215. 4
# 	 - 변경이 가끔 발생하고 이력 대상 속성이 많다면 인 스턴스 레벨의 이력관리를 고려할 수 있다.
#        물론 이러한 이력관리의 방법을 사용하면 실제 변경된 속성을 찾는데 다소 불편함이 있다는 것은 감안해 야 한다.
#
# 216. 4 / 3
# 	 - 제 3 정규형의 위배하지 않으려면 제1, 2 정규형 을 만족하고 속성들 간의 종속관계가 없어야 한 다.
#        1번은 ‘강좌.과명’ 이 제 3 정규형을 위배하고 있다.
#        2번은 ‘수강등록.교수번호’ 가 제 2정규형 을 위배하고 있다.
#        4번은 학생.수강등록일자’ 가 제 1 정규형을 위배하고 있다.
#
# 217. 2
# 	 - 선분이력에서의 종료점 처리 방법은 계속 진행 중 인 데이터（최종 데이터）에 대해서는 ‘99991231’ 과 같은 수렴값을 지정하여 사용하는 것이
#        여러 측 면에서 바람직하다.
#
# 218. 3
# 	 - 3번의 Difference는 차집합（Minus）을 의미 한다. 이것은 Division에 대한 설명이다.
#
# 219. 1
# 	 - M쪽이 Mandatory인 경우가 가장 많은 경우이다. 현실에서 가장 많이 존재하는 형태의 관계라고 볼 수 있다.
#        양측 필수 관계는 현실에는 존재하기 힘든 관계이다.
#
# 220. 3
# 	 - UID를 제외한 속성 간의 종속관계를 가져서는 안된다. 즉, ‘참여구분코드’, ‘참여구분명’ 등이 제 3정규형을 위배하고 있다
#
# 221. 2
# 	 - 하나의 엔터티는 물리적 요소들을 감안하여 경우에 따라서는 여러 개의 테이블로 생성될 수 있다.
#        특히, 성능의 문제를 고려하여 여러 테이블로 생성하는 경우도 종종 발생한다.
#
# 222. 3
# 	 - 현재 진행 중인 건은 의미적으로는 종료점을 Null로 표현하는 것이 맞지만 실제적으로는 수렴값（99991231）을 지정하는 것이 보다 효율적이다.
#
# 223. 4
# 	 - 사용자의 요구 사항이 명확하지 않았다면 논리 데이터 모델 자체가 확정되지 않은 상황이다.
#        이것은 물리 데이터 모델이 여러 개로 생기는 상황과는 거리가 멀다.
#
# 224. 1 / 4
# 	 - 일대다（1：M） 관계의 이력을 관리하게 된다면 다대다（M：M） 관계로 변하게 되어 새로운 관계 엔터티를 생성해야만 한다.
#
# 225. 4
# 	 - 개발자의 기술 수준은 물리 데이터 모델 설계에 가장 영향을 미치는 요소로 보기 힘들다.
#
# 226. 4
# 	 - 일대일（1：1） 관계에서는 Mandatory 관계를 가진쪽에 왜래키를 생성하는 것이 바람직하다.
#
# 227. 4
# 	 - 논리 데이터 모델에서 Business Rule은 물리 데이터 모델에서 Constraint의 형태로 설계되어 진다.
#        특히, Check Constraint의 형태가 가장 보편적인 형태이다.
#
# 228. 2
# 	 - DBMS 벤더（Vendor）와 버전에 따라서 지원하는 파티셔닝의 기법들이 상이하다. 따라서 상이한 점 들을 파악하는 것이 무엇보다 우선되어야 한다.
#
# 229. 4
# 	 - 법인’ 테이블을 ‘법인사업자’, ‘개인사업자’로 분류하여 별개의 테이블로 생성하는 것은 바람직하지않다.
#        특히, 이렇게 상위 테이블을 분할하게 되면 테이블들을 부모로 가지는 하위 테이블들을 활용하는데 많은 불필요한 일들이 발생할 소지가 있다.
#
# 230. 3
# 	 - 대부분 현재를 읽는 다면 ‘고객번호 + 종료일자 + 시작일자’가 가장 효율적이다.
#
# 231. 4
# 	 - 여러 개의 테이블로 분할하게 되면 유형구분이 필요가 없어진다. 즉, 서브 타입 유형구분별로 별개의 테이블로 생성되기 때문이다.
#
# 232. 3 / 2
# 	 - 자주 사용되는 엑세스 조건이 다른 테이블에 분산되어 있어서 상세한 조건 부여에도 불구하고 엑세스 범위를 줄이지 못하는 경우에
#        사주 사용되는 조건들을 하나의 테이블로 모아서（컬럼의 중복 즉,추출 속성으로 하나의 테이블에 모으는 경우를 의미함） 조건의 변별성을 극대화할 수 있다.
#
# 233. 4
# 	 - 일대다（1：M） 관계에서 1쪽이 Mandatory이고, M쪽이 Optional 경우는 업무 규칙상 발생할 수도있다.
#        즉, 자식쪽의 레코드가 하나 이상 있어야 부모 테이블에 레코드를 생성할 수 있다는 것이다.
#
# 234. 4
# 	 - 외부키의 결합에서는 근본적으로 외부키 제약조건을 생성할 수 없기 때문에 User - Defined Trigger 등의 방법을 통하여 해결해야 한다
#
# 235. 4
# 	 - 일반적으로 SQL 코멘트에 대한 데이터 표준 방안을 수립하지 않고, 해당 SQL의 유의사항 또는 처리 방법 등에 대한 내용을 자유롭게 기록하는 것이 일반적이다.
#
# 236. 3
# 	 - 개별 속성들이 많은 경우에는 하나의 테이블로 변환하는 것이 바람직하다.
#
# 237. 2 / 4
# 	 - 특정 칼럼의 크기가 아주 큰 경우에는 (특히 이미지와 같은 크기가 큰 데이터) 데이터를 저장하기 위해서는 원래의 테이블의 칼럼들과 분리하여 저장하는 것이
#        보통이다. 이렇게 함으로써 이미지를 읽지 않은 경우에 액세스 효율을 증가시킬 수있다.
#
# 238. 1 / 4
# 	 - 1번의 배타적 관계는 항상 Mandatory이거나 Optional이어야 한다. 2번과 3번의 배타적 관계는 반드시 하나의 Entity에만 속해야 한다.
#
# 239. 4
# 	 - M：M 관계가 포함된 처리의 과정을 추적, 관리하고자 하는 경우 진행 테이블 추가를 고려할 수 있으나, 다중 테이블 클러스터링이나 적확한 조인 SQL구사 등을
#        통해 굳이 진행 테이블을 만들지 않아도 양호한 수행속도를 낼수 있는 경우가 많이있다.
#
# 240. 2 / 1
# 	 - 파일 시스템은 업무나 부서 중심의 관점이지만 데이터베이스 시스템은 데이터 통합을 통한 데이터 공유의 관점이라는 것이 가장 큰 차이점이다.
#
# 241. 3
# 	 - 데이터 모델에서 요구되는 필수 조건은 반정규화가 아닌 중복 배제(Non-Redundancy)로, 이를 통해 저장 공간의 낭비를 최소화하고, 데이터 일관성을 유지하도록
#        하고 있다. 반정규화는 이와 같은 관점에서 데이터 모델 설계가 완료된 후 성능을 고려하여 불가피하게 부분적인 중복을 허용한 것이다.
#
# 242. 1
# 	 - 지문의 내용은 커뮤니케이션 원칙에 대한 설명 내용으로, 논리 데이터 모델링의 주목적이 최종 사용자 데이터에 대한 뷰(View)를 개념화하고 추상화하여
#        시스템 설계자들에게 전달하는 것임을 의미한다.
#
# 243. 4
# 	 - 1〜3은 모두 적절한 설명이다.
#
# 244. 4
# 	 - 개체-관계 모델의 구성 요소는 엔터티, 속성, 식별자, 관계, 카디날리티, 존재 종속, 서브타입 등이다.
#
# 245. 2
# 	 - 객체는 연관(Association) 또는 상속(Inher—itance)을 통해 다른 객체들에 연결된다.
#
# 246. 4 / 3
# 	 - 데이터 아키텍처 상에서 데이터에 대한 최상위 수준의 관점을 정의한 것은 개괄 데이터 모델이다.
#
# 247. 4
# 	 - 4는 병렬식 관계의 특징이다
#
# 248. 2 / 1
# 	 - M：M 관계가 나타날 때 관계가 자식을 가져야 하거나, 관계가 추가적인 속성을 가져야 하는 경우는 M：M 관계를 관계 엔터티로 풀어주고 모델링을
#        계속 진행해야 한다.
#
# 249. 2
# 	 - 계좌는 고객이 금융상품에 가입함으로써 생성되는메인 엔터티이다.
#
# 250. 3
# 	 - 엔터티 정의 요건에서 대상 개체 간에는 동질성이 있는지 확인해야 하고, 다른 개체와의 구분에서 독립성이 있는지 확인한다.
#
# 251. 1
# 	 - 다대다 관계의 해소 시점은 2~4에 기술한 내용과 같다.
#
# 252.
#      - ????????????
#
# 253.
#      - ????????????
#
# 254.
#      - ????????????
#
# 255.
#      - ????????????
#
# 256. 4
# 	 - 서브타입을 테이블로 변환하는 방법은 1~3 내용과 같음.
#
# 257. 1
# 	 - 전체 집합에서 임의의 집합을 추출 • 가공하는 경우가 빈번하고, 복잡한 처리를 하나의 쿼리로 통합하고자 하는 경우 유리한 서브타입 변환 형태는
#        슈퍼타입을 기준으로 하나의 테이블로 변환하는 방법이다.
#
# 258. 4
# 	 - 테이블, 뷰, 칼럼 등은 데이터 표준을 적용하는 대상이다.
#
# 259. 3
# 	 - 특정 칼럼 크기가 아주 큰 경우의 수직분할은 I/O 성능 향상에 유리하다.
#
# 260. 4
#      - 인덱스 생성은 엄밀한 의미에서 반정규화로 보지않는다.
#
#
#
#
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# * 책 문제 (p378 ~ p526)
# * 답 (p708)
#
#
# * 데이터 모델링 이해 (p378)
# 1. 2
#     - 논리 데이터 모델링을 수행하는 목적은 전산 시스템과 독립적으로 업무 데이터가 갖는 구조와 규칙을 추상화 기법과 정규화 기법을 통하여 명확하게
#       표현하는 것이다.
#       성능상의 문제는 데이터베이스 설계 시점에 데이터의 사용량 사용자의 데이터에 대한 접근 경로(Access Path)를 파악하여 수행하는 것으로 수행 속도와
#       독립적으로 수행돼야 하는 것이다.
#
# 2. 3
#     - 정보의 고립화는 업무 요구 사항에 대해 빠른 대응을 하기가 어렵기 때문에 정보 요구에 탄력적이지 못하고 비탄력적이다.
#
# 3. 2 / 4
#     - 캡슐화는 논리 데이터 모델링을 수행하는 추상화 기법이 아니고, 객체지향 모델링에 대한 내용이다.
#
# 4. 4
#     - 엔터티-관계 데이터 모델의 구성요소는 엔터티(Entity), 관계(Relationship), 속성(Attribute)이다. 도메인(Domain)은 속성이 취할 수 있는 모든 값의 집합이다.
#
# 5. 3
#     - 일관성(Consistency)은 데이터 무결성 즉, 데이터 값의 정확성과 일관성을 설명할 때 사용하는 용어로 동일한 업무 사실을 두 가지 값으로 표현해서는 안된다는
#       것이다. 예를 들어 성별 구분 코드에서 ‘남자’를 ‘M(Male)’, 또는 ‘1’ 이렇게 두 가지로 표현하는 것을 일관성이 없다고 하는 것이다.
#
# 6. 4
#     - 관계형 모델 이론이 데이터를 분석하는데 있어 비관계형 이론보다 반드시 우수하지는 않다.
#
# 7. 1
#     - 관계형 모델 이론에서 무결성은 개체 무결성, 참조무결성, 도메인 무결성, 연쇄 작용 또는 업무 규칙 이라고 하는 무결성이 있는데 ‘각 열(Column)은
#       동일한 성격을 갖는다’는 도메인 무결성을 말하는 것이다.
#
# 8. 2
#     - 참조무결성은 관계에 관한 것이고, 영역과 속성 무결성은 같은 얘기로 속성이 가져야 하는 값에 대한 무결성이다.
#
# 9. 2 / 3
#     - 납품 여러 개를 모아 한번에 결제하므로 기수성은 결제가 1이고 납품이 여러 개이며, 선택성은 납품이 생길 때는 결제가 없어도 되므로 선택이고,
#       결제가 생성되려면 납품이 반드시 있어야 하기 때문에 필수이다.
#
# 10. 2 / 3
#     - 연쇄작용은 비즈니스 규칙으로 어느 개체에 데이터 값이 입력, 수정, 삭제될 때 그 개체 내지는 다른 개체의 데이터 값에 영향도를 분석하는 것으로
#       데이터의 무결성과 관계가 깊다. 정규화를 잘못하면 입력, 수정, 삭제 이상이 발생할 수 있어 이것도 데이터 무결성과 관계가 있다.
#       인덱스는 데이터를 찾아가는 접근 경로로 수행 성능의 향상을 위한 기법이다.
#
#
#
# * 데이터 모델링 (p478)
# 1. 4
#     - CASE 도구의 사용은 권장사항이지만 필수사항은 아니다.
#
# 2. 2, 4 / 3, 4
#     - 중요 보고서 제목은 향후 정의될 엔터티의 후보가 될 수 있다. 또한 시스템 관리자보다는 업무 관리자의 의견을 참조하여 주제영역을 생성한다.
#
# 3. 4
#     - 경우에 따라서는 내부적으로만 사용되는 인조 식별자를 사용할 수도 있다. 특히 시스템에서 사용하는 데이터들에 이러한 유형의 식별자가 많이 존재한다.
#
# 4. 4
#     - 구조가 변경되더라도 식별자는 변경되지 않기 때문에 과거 데이터를 변경할 필요가 없다.
#
# 5. 4 / 2, 3
#     - 1) 개체가 공통적인 속성 집합(common set of attributes)을 가지고 있을 때. 2) 개체가 공통적인 관계 집합(common set of relationship)을 가질 때
#       일반화를 한다.
#
# 6. 4
#     - 4번은 모순이다. 배타적 관계는 다 선택이든지, 다 필수이어야 한다. 한 쪽만 선택이든지, 한 쪽만 필수이면 이는 배타적 관계가 형성될 수 없다
#       1번은 양쪽 선택적인데 이는 관계를 하나도 맺지 않을 수 있는 업무를 설명하고 있다.
#       2기수성(cardinality, degree)는 배타적 관계에 아무 영향을 미치지 않는다.
#       3번은 둘 중에 하나와 관계를 맺는데 반드시 관계가 하나는 있다는 업무규칙이다.
#
# 7. 2
#     - 과도한 정규화는 오히려 성능을 저해할 수 있다.
#
#
#
#
# * 물리 데이터 모델링 (p526)
# 1. 2
#     - 하나의 엔터티는 물리적 요소들을 감안하여 경우에 따라서는 여러 개의 테이블로 생성될 수 있다.
#       특히 성능을 고려하여 여러 테이블로 생성하는 경우가 종종 발생한다.
#
# 2. 3 / 4
#     - 일대일（1：1） 관계에서는 Mandatory 관계를 가진 쪽에서 외래 키를 생성하는 것이 바람직하다.
#
# 3. 4
#     - 외부 키의 결합에서는 근본적으로 외부 키 제약조건을 생성할 수 없기 때문에 User - Defined Trigger 등의 방법을 통하여 해결해야 한다.
#
# 4. 2
#     - 자주 사용되는 액세스 조건이 다른 테이블에 분산되어 있어서 상세한 조건 부여에도 액세스 범위를 줄이지 못하는 경우에 자주 사용되는 조건들을
#       하나의 테이블로 모아서（칼럼의 중복 즉, 추출 속성으로 하나의 테이블에 모으는 경우를 의미함） 조건의 변별성을 극대화할 수 있다.
#
# 5. 3, 4 / 4
#     - M：M 관계가 포함된 처리의 과정을 추적, 관리하고자 하는 경우 진행 테이블 추가를 고려할 수 있으나, 다중 테이블 클러스터링이나
#       정확한 조인 SQL 구사 등을 통해 굳이 진행 테이블을 만들지 않아도 양호한 수행속도를 낼 수 있는 경우가 많이 있다.
#
# 6. 4
#     - 서브타입을 테이블로 변환하는 방법은 ①~③ 내용과 같음.
#
# 7. 1
#     - 전체 집합에서 임의의 집합을 추출•가공하는 경우가 빈번하고, 복잡한 처리를 하나의 쿼리로 통합하고 자 하는 경우 유리한 서브타입 변환 형태는
#       슈퍼타입을 기준으로 하나의 테이블로 변환하는 방법이다.
#
# 8. 2 / 4
#     - 테이블, 뷰, 칼럼 등은 데이터 표준을 적용하는 대상이다.
#
# 9. 3
#     - 특정 칼럼 크기가 아주 큰 경우의 수직분할은 I/O 성능 향상에 유리하다.
#
# 10. 4
#     - 인덱스 생성은 엄밀한 의미에서 반정규화로 보지 않는다.

# %% [markdown]
# # 데이터 모델링(p319)
# ## 데이터 모델링 개요
# ### 데이터 모델링 정의
# - 데이터 모델
#     - 현실 세계를 데이터베이스로 표현하는 중간 관정
#     - 컴퓨터에 저장할 데이터의 구조 및 업무 규칙을 표현하기 위해 사용하는 지적인 도구
# - 데이터 모델링 탄생 배경
# - 정보시스템 개발 방법론
#     - 구조적 방법론
#         - 데이터 흐름도(DFD)로부터 업무를 구조적으로 분석, 설계 -> 소프트웨어 개발하는 절차
#     - 정보 공학 방법론
#         - 계획
#             - 정보 전략 계획   == ISP (Information Strategy Planning)
#                 - 정보 아키텍처
#                     - 데이터 아키텍처
#                     - 프로세스 아키텍처
#                 - 시스템 아키텍처
#                     - 시스템 단위의 화면 설계
#                     - 데이터베이스 설계
#                 - 기술 아키텍처
#                 - 조직 아키텍처
#         - 분석
#             - 업무 영역 분석   == BAA (Business Area Analysis)
#         - 설계
#             - 업무 시스템 설계 == BSD (Business System DEsing)
#         - 구축
#             - 구축             == CON (Construction)
#     - 객체지향 방법론
#     - 컴포넌트 기반 방법론
# ### 데이터 모델링의 중요성
# - 데이터 모델링
#     - 조직의 업무 수행에 필요한 데이터베이스를 생성하기 위하여 업무에서 필요로 하는 정보의 구조와
#       규칙을 명확하게 표현하기 위한 지적인 작업 과정
# - 데이터 무결성
#     - 사용자가 관계형 테이블에 입력,수정,삭제,조회라는 관계형 연산을 수행할 때, 테이블 내 데이터 값의
#       정확성과 일관성을 보장하는 일련의 업무 규칙
# - 데이터 모델은 데이터베이스 설계에 대한 계획 또는 청사진이다.
#
#
#
#
#
#
# ## 데이터 모델링 기법 이해
# ### 엔터티-관계 데이터 모델
# - 추상화
#     - 현실세계 존재하는 구체적 개체(Entity) 또는 객체(Object)들의 공통된 특징
#     - 추상적 특징을 파악하여 인식의 대상으로 삼는 행위
# - 논리 데이터 모델링 추상화
#     - 유형화 (주제영역)
#         - 현실세계에 존재하는 같은 성질을 갖는 멤버들을 타입 또는 유형이라는 하나의 개념으로 정의
#         - 조직의 업무가 수행되는 관점에 따라서 하나의 엔터티를 여러 가지 엔터티 타입으로 유형화
#             - ex) 소나타 -> 상품, 고정자산, 운송수단
#     - 집단화 (속성)
#         - 값(Value)을 유형화하면 속성이라는 타입
#         - 속성이라는 타입들의 세트로 구성되는 새로운 타입(엔터티 타입)을 정의
#     - 일반화 (서브타입)
#         - 여러 엔터티 타입 간의 공통적인 특성을 파악하는 과정
#         - 둘 또는 그 이상의 엔터티 타입 요소 간에 서브세트(부분집합)를 정의
# - 타입과 인스턴스
#     - 타입: 실제 발생된 사례들을 추상화한 집합
#     - 인스턴스: 현실 세계에서 실제로 발생된 사례(타입의 멤버)
# - 표준 용어 정의
#     - 엔터티-관계 데이터 모델
#         - 업무에서 다루는 사물(thing)
#             - 엔터티 (Entity)-본서 표준
#                 - 엔터티 타입 (Entity Type)
#                 - 개체 타입 (Entity Type)
#                 - 실체 유형 (Entity Type)
#             - 인스턴스(Instance)-본서 표준
#                 - 엔터티 (Entity)
#                 - 개체 (Entity)
#                 - 실체 (Entity)
#         - 사물(thing) 사이 연관
#             - 관계 (Relationship)-본서 표준
#             - 페어링 (Pairing)-본서 표준
#         - 사물(thing)이 갖는 특성
#             - 속성(Attribute)-본서 표준
#             - 값(Value)-보넛 표준
#     - 오브젝트 컴포넌트 모델
#         - 업무에서 다루는 사물(thing)
#             - 클래스(Clss)-본서 표준
#             - 객체(Object)-본서 표준
# ### 엔터티-관계 데이터 모델 구성요소
# - 엔터티
#     - 조직의 업무를 수행하는데 필요로 하는 사물, 사건 또는 개념을 나타내는 것
#     - 동일한 업무 행위를 하는 단일 개념으로 정의한 인스턴스들의 집합체
#     - 유사한 속성을 갖는 단일 개념으로 정의한 인스턴스들의 집합체
# - 관계
#     - 하나 또는 두 개의 엔터티에서 인스턴스를 연관시키는 업무적인 이유
# - 속성과 도메인
#     - 속성은 엔터티에 저장되는 인스턴스들의 특성을 설명하는 항목
#     - 도메인은 하나의 속성이 갖는 같은 종류의 모든 값들의 집합
# - 식별자
#     - 속성 중에서 엔터티에 저장되는 어떤 특징 인스턴스 하나를 식별할 수 있는 하나 또는 하나 이상의 속성을 유일 식별자
#     - 특성
#         - 일련의 식별자 속성은 반드시 값을 갖는다.
#         - 일련의 식별자 속성의 값은 유일(Unique)하다.
#         - 식별자를 구성하는 일련의 속성은 최소한의 개수로 해야 한다.
#
#
#
#
#
#
# ## 데이터 모델링 표기법 이해
# ### 엔터티-관계 데이터 모델 표기법
# - 엔터티 표기법
#     - 정보공학(IE) 엔터티 표기법
#         - 종속 엔터티
#             - 하나의 인스턴스를 식별하는 데 있어서 하나 또는 하나 이상의 다른 인스턴스에 의존하는 엔터티
#             - 특성, 연관, 서브타입
#         - 특성 엔터티
#             - 하나의 인스턴스에 여러 번 발생하는 속성의 그룹 (사원경력, 고객주소)
#         - 연관 엔터티
#             - 두 개 이상의 연관된 다른 엔터티로부터 식별자를 상속 받는 엔터티(다대다 관계 해소 시 생성됨 예, 주문상품 등).
#         - 서브타입 엔터티
#             - 다른 부분집합과 구별되는 공통 속성이나 관계를 공유하는 엔터티의 부분집합(예, 개인고객, 법인고객 등)
#     - CASE*Method 엔터티 표기법
# - 속성 표기법
#     - 속성은 엔터티에 저장되는 인스턴스들의 특성을 설명하는 항목으로, 단어들을 조합한 명사적 용어로 표현한다.
#     - 엔터티 명 + 수식어 + 도메인 명
# - 관계 표기법
#     - 관계란 하나 또는 두 개의 엔터티에서 인스턴스를 연관시키는 업무적인 이유
#     - 관계 기수성(Cardinality, Degree) 표기법
#         - 일대일 관계
#         - 일대다 관계
#         - 다대다 관계
#     - 관계 선택성 표기법
#         - 필수 관계
#         - 선택 관계
#     - 관계 식별성 표기법
#         - 식별 관계
#         - 비식별 관계
#
#
#
#
#
#
# ## 관계형 모델 이론
# ### 릴레이션 개념
# - 용어 비교
#     - 관계형(집합) 이론
#         - 릴레이션
#         - 튜플
#         - 애트리뷰트
#     - 논리 데이터 모델
#         - 엔터티
#         - 인스턴스
#         - 속성
#     - 관계형 데이터베이스
#         - 테이블
#         - ROW
#         - 컬럼
#     - 파일(File) 시스템
#         - 파일
#         - 레코드
#         - 필드
# - 릴레이션
#     - 두 개의 집합 x, y가 있을 때 두 집합간의 관계 R을 만족하는 모든 순서쌍을 말합니다.
#     - 차수(Degree) == 애트리뷰트(속성) 개수
#     - 기수성(Cardinality) == 튜플(Row)
# - 속성과 도메인의 개념
# ### 관계형 모델 이론
# - 관계형 모델 이론
#     - 데이터 구조
#         - 사용자가 인식하는 데이터의 구성
#     - 데이터 조작
#         - 사용자가 관계형 데이터 구조에 행하는 일련의 연산(처리) 형태
#     - 데이터 무결성
#         - 사용자가 일련의 관계형 연산을 수행할 때 관계형 테이블의 데이터 값이 어떻게 되야 하는 지를 통제하는 일련의 업무 규칙
# - 데이터 구조
#     - 각 열은 하나의 값을 가진다.
#         - 정보 접근의 유연성
#         - 테이블 구조 변경의 유연성
#         - 정규화 이론에 나오는 입력이상, 수정이상, 삭제이상 현상을 없애고 데이터 무결성 확보
#     - 각 열의 값은 동일한 종류이다.
#         - 데이터 무결성 규칙
#     - 각 행은 유일하다.
#         - 엔터티 무결성 규칙
#     - 열의 순서는 의미가 없다.
#     - 행의 순서는 의미가 없다.
#     - 각 열은 유일한 이름을 가진다.
# - 데이터 조작
#     - 집합 처리
#     - 관계 연산자: 조회
#         - Select (or Restrict): 열에 의거한 행의 부분집합
#         - Project: 열의 부분집합
#         - Product: 두 관계 테이블간 행의 조합을 묶음
#         - Join: 열의 기준에 의거하여 각 행을 수평적으로 묶음
#         - Union: 중복을 없이하여 각 행을 수직적으로 묶음
#         - Intersection: 관계 테이블간의 공통된 행
#         - Difference: 하나의 관계 테이블에만 있는 행
#         - Division: 다른 관계 테이블의 모든 행에 대응하는 열을 제외한 열
#     - 처리 연산자: 관계 테이블의 내용에 변화
#         - Insert: 행의 입력
#         - Update: 행의 수정
#         - Delete: 행의 삭제
# - 데이터 무결성
#     - 사용자가 일련의 관계형 처리(입력, 수정, 삭제, 조회)를 수행할 때 관계형 엔터티의 데이터 값이 어떻게 작용해야 하는지를 통제하는 일련의
#       업무규칙으로 엔터티, 관계, 도메인 무결성 규칙 및 연쇄 작용이 있다.
#     - 엔터티 무결성 규칙 (Entity Integrity rule)
#         - 주 키는 NULL 값을 포함하지 않는다.
#         - 엔터티 내 특정 건(Instance)의 유일성을 보장할 것
#         - 최소한의 속성 집합(Minimal Set)일 것
#     - 참조 무결성 규칙 (Referential integrity rule)
#         - 관계 엔터티(테이블)의 모든 외래 키 값은 관련 있는 관계 엔터티(테이블)의 모든 주 키 값이 존재해야 한다.
#         - 입력 규칙
#             - 자식 엔터티의 행이 입력 될 때
#         - 삭제 규칙
#             - 부모 엔터티의 행을 삭제할 때
#     - 도메인(속성) 무결성 규칙 (Domain Integrity rule)
#         - 엔터티(테이블) 내의 모든 열에 관한 무결성 규칙으로 데이터 타입, 길이, 허용 값, 기본값, 유일성, NULL 여부 등에 관한 제한
#         - 같은 도메인의 값들끼리만 비교 가능
#         - 속성이 취할 수 있는 값의 제한
#     - 연쇄 작용(Triggering operation) 또는 업무 규칙 (Business Rule)
#         - 입력, 삭제, 수정 또는 조회 등의 작업이 동일 엔터티(테이블) 혹은 다른 엔터티(테이블)의 속성에 영향을 미치는 업무 규칙을 정의
#
#
#
#
# -----------------------------------------------------------------------------------------------------------------------------------------
# # 데이터 모델링 (p381)
# ## 논리 데이터 모델링 이해
# ### 논리 데이터 모델링 핵심
# - 논리 데이터 모델링 필수 성공 요소
#     - 가능한 많은 시간을 업무에 능통한 현업 사용자와 함께 데이터 모델링을 진행하라
#     - 절차보다는 데이터에 초점을 두고 모델링을 진행하라
#     - 데이터의 구조와 무결성을 함께 고려하라
#     - 개념화와 정규화 기법을 적용하라
#     - 가능하면 다이어그램을 이용하여 업무를 표현하라
#     - 데이터 모델링을 지원하는 데이터 사전을 구축하라
# - 논리 데이터 모델링 목적 및 효과
#     - 해당 비즈니스에 대한 데이터 관점에서의 명확한 이해
#     - 전사적인 통합 데이터 체계 확립
#     - 데이터의 일관성 및 정확성 유지를 위한 규칙 도출
#     - 안정적인 데이터베이스 설계의 토대 마련
#     - 정보시스템 관계자와의 명확한 의사소통을 위한 수단으로 활용
# ### 논리 데이터 모델링 절차
# - 논리 데이터 모델링 절차
#     - 주제 영역 정의
#     - 엔터티 정의
#     - 관계 정의
#     - 속성 정의
#     - 식별자 확정
#     - 정규화
#     - 이력 관리
#
#
#
#
#
#
#
# ## 주제 영역 정의
# ### 주제 영역 개념
# - 주제 영역 개념
#     - 주제 영역은 주요 자원, 상품, 활동을 중심으로 조직이 관심을 가지는 영역
# ### 주제 영역 도출
# - 주제 영역 발견 기법
#     - 가치 사슬 분석 기법을 활용
#         - 보조 활동, 본원 활동
# - 주제 영역 도출 방안
#     - 업무 기능의 이름으로부터 도출
#     - 업무에서 사용하는 데이터의 명사형 도출
#     - 하향식 접근방법
#     - 상향식 접근방법
# - 주제 영역 명명
#     - 업무에서 사용하는 용어를 부여한다.
#     - 유일한 단수형 명사를 사용한다.
#     - 데이터의 그룹을 의미하는 이름을 부여한다.
# ### 주제 영역 활용
# - 목적
#     - 업무 분석의 효율을 높인다.
#         - 데이터의 계층적 구조를 파악하는 데 도움이 된다.
#         - 점진적인 상세화로 상위 수준에서 모델의 안정성을 유지한다.
#     - 업무 기능(Function)과 병행하여 분석하는 경우에 모델의 품질 확보에 기여한다.
#     - 주제 영역 계층과 업무 기능 계층 간의 대응 관계를 확인한다.
#     - 주제 영역은 기업의 전사 업무를 위한 전체 데이터 구성에 대한 청사진을 제공한다.
#     - 데이터 구성 및 통합에 대한 방향을 제시한다.
#     - 효율적 데이터 관리를 위한 기준을 제공한다.
# - 장점
#     - 데이터 및 업무 활동 모델의 품질을 보증한다.
#     - 프로젝트 관리: 업무 범위에 대한 기준을 확보한다.
#     - 분할 후 정복으로 집중화한 토의를 할 수 있다.
#     - 모델 개발 조정을 용이하게 한다.
#     - 저장소 관리를 좀 더 용이하게 한다.
#     - 상세 사항의 전개 혹은 축약이 가능하다.
# ### 주제 영역 정의 내용
# - 주제 영역 목록
#     - 레벨: 주제 영역의 계층 수준
#     - 주제 영역 명
#     - 설명
#     - 대표 엔터티: 해당 주체 영역 내에서 대표적인 엔터티를 기술한다.
# ### 주제 영역 사례
# - 사례
#     - 여신 업무
#     - 여신 상담 및 신청
#     - 신용조사
#     - 여신심사
#     - 여신승인
#     - 여신 약정 체결
#     - 여신실행
#     - 여신사후관리
#
#
#
#
#
#
# ## 엔터티 정의
# ### 엔터티 개념
# - 엔터티란
#     - 조직에서 업무를 수행하는데 필요로 하는 사물, 사건 또는 개념을 나타내는 어떤 것
# ### 엔터티 분류
# - 일반적인 엔터티 분류
#     - 유형 엔터티: 물리적으로 존재하는 대상 (고객, 상품 등)
#     - 활동 엔터티: 어떤 사건에 관한 정보 (주문, 계약, 장비 고장 등)
#     - 개념 엔터티: 관리할 정보가 있는 무형의 개념 (계정과목, 성적 등)
# - 모델 관점 엔터티 분류
#     - 독립 엔터티: 인스턴스를 식별하는 데 있어서 어떤 다른 인스턴스에 의존하지 않는 엔터티 (고객, 제품, 사원)
#     - 종속 엔터티: 인스턴스를 식별하는 데 있어서 하나 또는 하나 이상의 다른 인스턴스에 의존하는 엔터티 (사원가족, 주문상품)
#         - 특성 엔터티 (사원경력)
#             - 하나의 인스턴스에 여러 번 발생하는 속성의 그룹
#             - 다른 인스턴스에 의하여 직접적으로 인식되지 않는 엔터티
#         - 연관 엔터티 (다대다 관계 해소시 생성됨)
#             - 두 개 이상의 연관된 다른 엔터티로부터 식별자를 상속 받는 엔터티
#         - 서브타입 엔터티
#             - 다른 부분집합과 구별되는 공통 속성이나 관계를 공유하는 엔터티의 부분집합
# - 발생 시점 엔터티 분류
#     - 키 엔터티 (사람, 상품 등과 같이 업무행위의 주체나 목적어가 되는 엔터티)
#         - 자신의 부모를 가지지 않는 엔터티
#         - 다른 엔터티의 도움을 받지 않더라도 얼마든지 어떤 인스턴스를 새롭게 정의할 수 있는 집합
#         - 사원, 부서, 고객, 상품, 자재
#     - 메인 엔터티 (키 엔터티가 행위를 함으로써 발생되는 행위의 집합 중에서 좀 더 하위의 행위를 발생시키는 주체나 목적어가 되는 엔터티)
#         - 키 엔터티를 제외한 엔터티 중에서 업무 중심에 해당하는 엔터티
#         - 보험계약, 사고, 예금원장, 청구, 주문, 매출 등
#     - 액션 엔터티 (키, 메인 엔터티 이외)
#         - 키 엔터티와 메인 엔터티가 아닌 것
#         - 상태 이력, 차량 수리 내역, 상세 주문 내역
# ### 엔터티 도출 (399)
# - 현행 데이터베이스로부터 엔터티 도출
#     - 현행 데이터베이스가 조직의 정보 요구 사항을 빠짐없이 정확하게 지원하고 있는지를 알기 위해
#     - 현행 데이터베이스의 구조적인 문제점 및 해결 방안을 도출하기 위해
#     - 목표 정보 요구 사항을 지원하기 위하여 논리 데이터 모델을 어떻게 생성할지를 결정하기 위해
#     - 현행 데이터베이스에서 목표 데이터베이스로의 데이터 이행이 필요한 경우 이에 대한 원천 데이터를 정확하게 파악하기 위해
# - 정보요구 분석
#     - 사용자가 일상적으로 수행하는 업무의 개선 사항이나 신규 개발 사항으로 시스템을 통해 기능상의 목적을 달성하기 위해 요청하는 내용
# - 업무에서 사용하는 문서로부터 도출
# - 사용자 인터뷰로부터 도출
# - 아키텍처 모델로부터 도출
# - 업무를 수행하는 프로세스로부터 도출
# - 엔터티 분류 기법을 활용하여 도출
#     - 논리 데이터 모델링 이론을 배울 수 있는 곳은 많아도, 실전을 경험할 수 있는 기회는 별로 많지 않다.
#     - 논리 데이터 모델링의 대상이 되는 업무에 대한 경험 내지는 이해도 부족이라 할 수 있다.
#     - 논리 데이터 모델 이해 관계자의 집합이론과 1차 술어 논리에 근거한 관계형 모델 이론의 이해 부족이라 할 수 있다.
# ### 엔터티 검증
# - 논리 데이터 모델 엔터티
#     - 데이터 모델의 구현 주체인 조직의 업무를 수행하는 데 필요한 의미 있는 정보
#     - 하나하나의 특성 사례가 아닌 유사한 사물들을 대표하는 집합체
#     - 인스턴스가 갖는 속성들에 의해 결정된 단일 개념
#     - 엔터티 내 인스턴스의 출현을 구별할 수 있는 능력을 제공
#     - 정규화 규칙 만족
# - 조직의 업무를 수행하는데 필요한 의미 정보를 나타내야 한다.
# - 특정 사례가 아닌 유사한 사물들을 대표하는 집합체
# - 인스턴스가 포함할 내부 연관성 있는 속성에 의해 결정된 단일개념을 대표해야 한다.
# - 추상화 수준 높은 모델 단점
#     - 업무를 이해하기 매우 어렵다
#     - 데아터 관리 또한 쉽지 않다
#     - 데이터 무결성 보장 어렵다
# - 엔터티 내 인스턴스의 출현을 구별할 수 있는 능력을 제공해야 한다.
#     - 속성 값이 반드시 있어야 한다.
#     - 이 값들이 유일해야 한다.
#     - 일련의 속성이 최소한의 개수로 이루어져야 한다.
# - 정규화 규칙을 만족해야 한다.
# ### 엔터티 정의 사항
# - 엔터티 명
#     - 지켜야 할 명명규칙
#         - 엔터티 명은 현실 세계의 인스턴스 및 정보를 대표하도록 한다.
#         - 엔터티 명 자체로 의미를 표현하도록 한다.
#         - 물리적인 사항을 개념화한 논리적 사물을 반영하도록 한다.
#         - 최소한의 어휘를 사용하여 의미를 전달할 수 있도록 한다.
#     - 지키지 말아야 할 명명규칙
#         - 데이터 관리자의 승인을 받지 않은 약어 또는 두문자어
#         - 테이블, 파일, 메뉴, 보고서, 입력화면 같은 정보시스템 구성요소
#         - 두 가지 이상의 개념을 동시에 사용하는 표현
# - 엔터티 설명
#     - 해당 업무에서 일반적으로 사용하고 있는 용어를 이용하여 기술한다.
# - 엔터티 분류
# - 현재 발생 건수
# - 발생 건수 변화
# - 권한
#     - 엔터티, 속성, 관계 및 기타 모델 구성요소
#     - 엔터티의 데이터를 입력, 수정, 삭제, 조회할 수 있는 권한
# - 식별자 속성
# - 외래 식별자 속성
# - 식별자 이외 속성
# ### 엔터티 일반화
# - 일반화 정의
#     - 현실세계의 사물, 사건을 단순화하여 표현하는 추상화 기법
#     - 슈퍼타입 엔터티: 일반화 계층의 가장 상위에 있는 엔터티
#     - 서브타입 엔터티: 다른 부분집합과 구별되며, 공통의 속성이나 관계를 공유하는 인스턴스들의 부분집합
# - 일반화 특성
#     - 슈퍼타입은 두 개 이상의 독립적인 서브타입으로 구성된다.
#     - 슈퍼타입은 각 서브타입들의 공통적인 속성과 관계를 가진다.
#     - 서브타입은 자신의 속성이나 독립적인 관계를 가진다.
#     - 자신의 속성이나 관계를 가지지 않는 서브타입도 존재할 수 있으나 이런 경우는 일반적인 속성으로 처리하는 것이 좋다.
# - 일반화 시점
#     - 인스턴스가 공통적인 속성 집합을 가지고 있을 때 일반화
#     - 인스턴스가 공통적인 관계 집합을 가질 때 일반화
# - 일반화 장단점
#     - 일반화
#         - 장점
#             - 데이터가 통합되어 있어 조회가 간편하다.
#             - 한 개의 프로그램으로 업무를 처리할 수 있다.
#             - 동일한 종류의 업무 추가 시 최소한의 변경으로 지원 가능하다.
#             - 전체적인 업무 로직 변화의 경우 신속하게 반영 할 수 있다.
#         - 단점
#             - 공통적이지 않은 속성이 많은 경우 효과가 반감된다.
#             - 여러 업무의 데이터가 서로 섞여 있어 내용을 정확하게 파악하기 힘들다.
#             - 모든 업무를 이해하는 인원 만이 데이터 관리르 수행할 수 있다.
#             - 특정 업무에만 관련된 데이터 변경이 있을 경우 타 업무에 영향을 미치게 된다.
#     - 상세화
#         - 장점
#             - 업무에 대한 명확한 파악이 가능하다.
#             - 데이터의 추가나 변경이 자유롭다.
#             - 특화된 업무에 대한 속성 관리나 프로그램이 용이하다.
#             - 장애나 에러에 대한 파급효과가 작다
#             - 데이터 구조가 명확하여 업무 파악이나 인수인계를 신속하게 수행할 수 있다.
#         - 단점
#             - 엔터티의 수효가 늘어나서 관리가 어려움이 발생한다.
#             - 데이터 간의 불일치를 초래할 수 있다.
#             - 통합적인 정보 도출이 어렵다.
#             - 동일한 로직도 별도의 프로그램으로 개발해야 하므로 관리가 비효율적이다.
#
#
#
#
#
#
#
# ## 관계 정의
# ### 관계 개념 (p420)
# - 관계란
#     - 하나 또는 두 개의 엔터티로부터 인스턴스를 연관시키는 업무적인 이유
# - 부모,자식 엔터티
#     - 두 개의 엔터티 사이 관계가 있을 때 기수성과 선택성에 따라 부모, 자식 엔터티를 구분하는데, 외래키 속성이 나타나는 곳이 자식이다.
# - 관계 읽기
#     - 모든 고객은 여러 개의 주문을 할 수도 있다.    == 선택성
#     - 모든 주문은 반드시 하나의 고객에 의하여 된다. == 필수성
# ### 관계 도출
# ### 관계 정의 사항
# - 관계 정의 사항
#     - 관계 명
#     - 관계요약 설명
#     - 외래 키
#     - 관계유형
#     - 기수성, 선택성
#     - 참조무결성
# ### 특수 관계
# - 자기 참조 관계
#     - CODE 대비법
#         - 계층 구조 변경에 매우 취약
#         - 사용이 쉽고 간편, 수행속도에 상대적으로 유리
#         - 계층 구조 변경 시 과거 데이터의 수정 필요
#         - 계층 구조이면서 변동이 거의 없는 업무에 적용
#     - 순환 전개법
#         - 계층 구조 변경에 매우 유연
#         - 사용이 약간 불편, 잘못 사용시 수행속도 저하
#         - 계층 구조 변경 시 과거 데이터의 수정 없음
#         - 계층 구조이면서 변동이 발생하는 업무에 적용
# - 다대다 관계
#     - 카티션 프로덕트가 발생하여 정보의 왜곡이 따른다.
# - 배타적 관계
#     - 어떤 엔터티의 행이 두 개 이상의 다른 엔터티의 행과 관계를 맺는데 있어서 어느 시점에 반드시
#       하나의 엔터티의 행과 관계를 맺는 형태
#     - 특성
#         - 배타적 관계는 보통 동일하다.
#         - 배타적 관계는 항상 필수이거나 선택이어야 한다.
#         - 배타적 관계는 반드시 하나의 인스턴스에만 속해야 한다.
#         - 어떤 엔터티는 다수의 배타적 관계를 가질 수 있다.
#
#
#
#
#
#
#
#
# ## 속성
# ### 속성 개념
# - 속성
#     - 엔터티에 속한 각각의 인스턴스에 대한 중요한 정보를 나타내며 각각의 속성은 특정한 값을 갖게 된다.
#     - 조직의 일상적인 운영 및 그리고 미래의 성장에 극히 중요한 정보의 기초로서 조직이 사용하는 데이터를 저장
# ### 속성 도출
# - 속성 후보 도출
#     - 현행 시스템 자료
#     - 현업 장표, 보고서
#     - 사용자와 협의
#     - 데이터 흐름도의 데이터 저장소
#     - 전문 서적 및 자료
#     - 다른 시스템 자료
# ### 속성 정의 사항
# - 속성 상세 정보 중요성
#     - 속성 상세 정보 정의는 업무 관련 데이터의 본질과 목적을 이해하는데 도움을 준다.
#     - 속성 수준의 무결성을 설정하고 강화하는 데 도움을 준다.
#     - 데이터 무결성을 개선하여 데이터 품질을 향상시킨다.
#     - 데이터 사전을 구성한다.
# - 속성 정의 사항
#     - 속성 명
#         - 속성의 목적이나 내용이 무엇인지 알려주는 명사 또는 명사구
#         - 의미가 명확한 속성 명칭 부여
#         - 유일한 복합명사 사용
#         - 단수형으로 속성 명 사용
#         - 표준 단어 및 용어 제정
#     - 속성 설명
#         - 속성의 정의로 이 속성이 업무에 왜 중요한지 또는 어떤 업무적인 이유에서 이 속성을 사용하게 되었는지를 기록
#         - 선택적 속성인 경우 모든 선택성 조건을 기록
#     - 선택성 및 선택성 조건
#     - 속성 유형
#         - 기본 속성: 속성 값이 해당 인스턴스에 원래 존재하여, 다른 속성 값으로부터 유도될 수 없는 속성
#         - 유도 속성: 속성 값이 항상 다른 속성의 값으로부터 유도되거나 계산되는 속성
#         - 설계 속성: 업무 제약사항을 반영하거나 시스템 운영을 단순화하기 위하여 생성하는 속성
#     - 유도 알고리즘
#         - 유도 알고리즘을 통해 유도형 속성에 값을 지정할 수 있다.
#     - 도메인
#         - 하나의 속성에 대하여 지정 가능한 값의 집합
#     - 허용 값
#     - 기본 값
#     - 소유 권한
#         - 데이터 거버넌스 차원의 속성 및 승인에 대한 권한을 가지는 개인, 기능 또는 조직에 대한 기록을 관리
#         - 데이터를 생성하고 사용하는 것에 대한 권한을 가지는 개인, 기능 또는 조직에 대한 기록을 관리
# ### 속성 검증 및 확정
# - 원자 값 단위까지 분할
#     - 속성은 단일 사실과 단일 개념을 나타내야 한다
#     - 회사가 계속 성장하여 지점이나 상품의 개수가 늘어난다면 이 자릿수만으로는 만족을 못 시킬 수도 있는 것
#     - 구성요소의 특성들을 숨기거나 모호하게 하여 계좌번호만 보고는 업무적으로 계좌번호가 구성된 업무 규칙을 못 보여주며
#       모델의 다른 요소들에 대한 여러 가지 종속성을 모호하게 하고 있는 것
#     - 원자 값이 아닌 속성은 접근경로를 잃어버린다는 것
#     - 원자 값 속성 사례
#         - 일자 형태의 속성: 매출일자, 생년월일
#         - 외부에서 만들어진 공인된 속성: 우편번호 유형
#         - 전화번호 유형: 전화번호, 팩스번호
# - 하나의 값만을 가지는지 검증
#     - 계약일자
#     - 차량번호
#     - 취미
# - 유도 속성인지 검증
#     - 현재 정보만 관리하는 형태: 현주소, 현고객등급코드 등
#     - 최초 정보를 보관하는 형태: 최초가입일자, 모집사원번호 등
#     - 집계 정보를 관리하는 형태: 인원 수, 가족 수, 총직원 수 등
#     - 추출 관계만 관리하는 형태: 가입 계약번호, 관리 사원 등
#     - 대표 정보만 관리하는 형태: 대표 전자메일 ID, 취미, 법인의 대표자 정보
#     - 다른 속성의 일부 정보만 분리한 형태: 성별, 결혼 여부 등
#     - 일부분만 추출 값인 형태: 인원 수, 법인의 대표자 정보 등
# ### 유도 속성 규칙
# - 초기 데이터 모델링 이론을 보면 유도된 속성이나 계산된 속성은 중복으로 인식하고 이를 데이터 모델에 표현하지 말 것을 권고
#   그러나 이러한 속성들이야 말로 기업의 관리자들이 관심을 가지고 보는 속성으로 데이터 모델 내에 반디스 기술할 것을 권장한다.
# - 유도(Derived) 속성이란 하나 이상의 다른 데이터 속성에 축적된 여러 사례의 값을 토대로 어떤 추가 계산 작업을 수행함으로써
#   선택적으로 주제를 도출하는 속성에 대하여 새로운 값을 창출하는 속성이다.
# - 계산(Calculated) 속성은 엔터티의 단일 사례에 대한 어떤 특성을 기술하며, 일반적으로 관련 속성의 또 다른 단일 사례로부터 계산된다.
# - 유도 속성은 경영층이 진실로 원하고 필요로 하는 정보를 대표한다.
# - 유도 속성은 사용자들의 데이터 요구 사항을 나타낸다.
# - 데이터 모델에 유도 속성을 포함시키는 것은 그들의 물리적 구현에 대한 어떤 것도 내포하지 않는다.
# - 유도 속성은 향후 과정에서 결코 식별자로서의 역할을 맡지 않아야 한다.
#
#
#
#
#
#
#
# ## 식별자 확정
# ### 식별자 개념
# - 식별자 종류
#     - 본질 식별자: 업무에서 사용하는 속성을 이용하여 유일성을 보장
#         - 기준 정보 엔터티의 본질 식별자
#         - 거래 처리 엔터티의 본질 식별자
#     - 인조 식별자: 업무에서 사용하는 속성이 아닌 인위적으로 만든 속성으로 유일성을 보장
#     - 보조 식별자: 엔터티 내에서 하나의 인스턴스를 유일하게 식별할 수 있는 속성이지만 대표성을 갖지 못하는 속성
# - 후보 식별자 도출
#     - NULL이 될 수 없다.
#     - 각 인스턴스를 유일하게 식별할 수 있어야 한다.
#     - 나머지 속성들을 직접 식별할 수 있어야 한다.
#     - 후보 식별자로 속성 집합을 선택하는 경우에는 개념적으로 유일해야 한다.
#     - 후보 식별자의 데이터는 자주 변경되지 않는 것이어야 한다.
# - 보조 식별자
#     - 원래의 식별자를 대신할 수 있는 또 다른 속성들이나 관계
# - 인조 식별자 지정
#     - 식별자 확정 시 기존의 본질 식별자를 그대로 인정할 수 없는 여러 가지 상황이 발생했을 때
#       전부 혹은 일부를 임의의 값을 가진 속성들로 대체하여 새롭게 구성한 식별자
#     - 최대한 범용적인 값을 사용한다.
#     - 유일한 값을 만들기 위한 인조 식별자를 사용한다.
#     - 하나의 인조 식별자 속성으로 대체할 수 없는 형태를 주의한다.
#     - 편의성, 단순성 확보를 위한 인조 식별자를 사용할 수 있다.
#     - 내부적으로만 사용하는 인조 식별자
# - 식별자 확정
#     - 식별 관계의 두 가지 의미
#         - 식별자로서의 역할
#         - 정보로서의 역할
#     - 식별자 상속과 단절의 원리
#     - 식별자 확정 절차
#         - 기준 정보 엔터티 식별자 확정
#         - 중요 거래 처리 엔터티 식별자 확정
#         - 기타 거래 처리 엔터티 식별자 확정
#
#
#
#
#
#
# ## 정규화
# ### 정규화 정의
# - 정규화는
#     - 엔터티에 데이터의 입력, 수정, 삭제 연산을 수행할 때 발생하는 이상 현상을 제거하여 논리 데이터 모델링의 목적인
#       정확성, 일관성, 단순성, 비중복성, 안정성을 만족시키는 최적의 데이터 구조를 만들어가는 과정
# ### 정규화 장점
# - 중복 값이 줄어든다.
# - Null 값이 줄어든다.
# - 복잡한 코드로 데이터 모델을 보완할 필요가 없다.
# - 새로운 요구 사항의 발견 과정을 돕는다.
# - 업무 규칙의 정밀한 포착을 보증한다.
# - 데이터 구조의 안정성을 최대화한다.
# ### 정규화 과정
# - 제1정규형
#     - 정의
#         - 모든 속성은 반드시 하나의 값을 가져야 한다. 즉 반복 형태가 있어서는 안 된다.
#         - 각 속성의 모든 값은 동일한 형식이어야 한다.
#         - 각 속성들은 유일한 이름을 가져야 한다.
#         - 행(Row)들은 서로 간에 식별 가능해야 한다.
# - 제2정규형
#     - 정의
#         - 식별자가 아닌 모든 속성은 식별자 전체 속성에 완전 종속되어야 한다.
#         - 주 키(PK)가 아닌 모든 컬럼이 주 키(PK)에 종속적이어야 제2정규형을 만족시킨다.
# - 제3정규형
#     - 정의
#         - 제2정규형을 만족하고 식별자를 제외한 나머지 속성들 간의 종속이 존재하면 안된다.
#
#
#
#
#
#
#
#
# ## 이력 관리
# ### 이력 관리란
# ### 이력 관리 대상 선정
# - 사용자 조사
#     - 변경 내역을 감시할 필요가 있는가?
#     - 시간의 경과에 따라 데이터가 변할 수 있는가?
#     - 시간의 경과에 따라 관계가 변할 수 있는가?
#     - 과거의 데이터를 조회할 필요가 있는가?
#     - 과거 버전을 보관할 필요가 있는가?
# - 이력 데이터의 종류
#     - 발생 이력 데이터
#         - 어떤 데이터가 발생할 때마다 이력 정보를 남겨야만 한다는 이력
#     - 변경 이력 데이터
#         - 데이터가 변경될 때마다 변경 전과 후의 차이를 확인
#     - 진행 이력 데이터
#         - 업무의 진행에 따라 이 데이터를 이력 정보를 남겨야만 하는 경우
# - 이력 관리 형태
#     - 시점 이력
#         - 데이터의 변경이 발생한 시각만을 관리
#         - 어느 시점에 얼마의 값으로 변경되었다는 정보를 관리
#     - 선분 이력
#         - 데이터 변경의 시작 시점부터 그 상태의 종료 시점까지 관리
#         - 각 통화의 특정 기간 동안 유효한 환율을 관리
# - 선분 이력 관리 유형
#     - 인스턴스 레벨 이력 관리
#         - 하나의 인스턴스의 어떤 변경이라도 발생하면 전체 인스턴스를 새롭게 생성하는 방식
#         - 한 번의 액세스로 스냅 샷을 참조하는 것이 가능하다.
#         - 로그성 데이터를 저장할 목적인 경우 적당한 방법
#         - 다른 이력 관리 유형에 비해 저장하기가 쉽다.
#         - 가장 큰 단점 중 하나는 하나 이상의 컬럼에 변경이 발생했을 떄 이벤트가 모호해진다는 점
#         - 만약 이벤트가 자식 정보를 가지게 된다면 매우 치명적.
#           즉 각각의 변경 이벤트가 하위의 데이터를 가지게 된다면 해당 이벤트를 찾기 매우 어려워진다.
#         - 이력 관리의 다른 유형들에 비해 저장 공간의 낭비를 초래할 수 있다.
#         - 실제 어떤 데이터가 변경된 것인지를 찾기 위해서는 과거의 데이터를 Merge해서 비교를 해야만 가능할 수 있다.
#         - 특정 수간의 스냅 샷만 보는 게 아니라면 처리가 복잡해지는 경향이 있다.
#         - 변화가 빈번하게 발생하는 상황이라면 고려해 볼 수 있는 유형이다.
#     - 속성 레벨 이력 관리
#         - 변경 이벤트가 매우 분명하게 관리된다. 즉 실제 어떤 데이터가 변경되었는지가 분명하다.
#         - 하나의 이력 관리 엔터티에서 다른 엔터티와 통합 이력 관리가 가능하다.
#         - 변경된 것만 처리하기 때문에 독립적 처리가 가능하다.
#         - 변화가 발생할 가능성은 매우 낮으면서 이력 관리 대상 속성은 매우 많은 경우에 사용하는 것이 유리하다.
#         - 특정 속성들에 변화가 집중되는 경우에 해당 속성에 대해서만 이력을 관리할 수 있기 때문에 유리하다.
#         - 여러 속성에 대한 이력이 필요할 때 많은 Merge가 발생한다.
#         - 이력 관리의 다른 유형들에 비해서 향후 사용될 데이터 액세스 쿼리에서 조건 검색이 조금 어렵다.
#         - 변화가 너무 많은 경우에는 적용이 곤란하다.
#     - 주제 레벨 이력 관리
#         - 로우 레벨과 속성 레벨의 장점을 모두 수용하는 형태의 이력 관리 형태이다.
#         - 목적이 분명한 엔터티를 생성함으로써 확장성을 확보할 수 있는 용도로 사용할 수 있다.
#         - 변경 부분만 처리가 가능하다(독립적 처리 가능)
#         - 다른 엔터티와 통합 이력 관리가 가능하다.
#         - 속성 레벨의 단점을 해소할 수 있다.
#         - 전체를 참조할 때 로우 레벨에 비해 Merge가 발생하는 문제점이 존재한다.
#         - 부문에 따라 변경 정도의 차이가 심한 경우 유리하다.
# ### 선분 이력 관리용 식별자 확정
# - 선분 이력에서 식별자 결정 시 고려 사항
# - 선분 이력에서 종료점 처리 시 주의 사항
#     - 종료점이 미정이므로 NULL
#         - 논리적으로는 타당하지만 비교가 불가능
#         - 인덱스를 사용하지 못하므로 수행 속도 저하
#     - 수렴하므로 최대치 부여
#         - 아직 종료되지 않았으므로 무한히 계속되는 것으로 간주
#         - 최대치 부여(예, 일자라면 9999/12/31)
#         - 가능한 테이블 생성시 기본 값 제약 부여
#         - 수행 속도에 유리
#
#
#
#
#
#
#
#
# ## 논리 데이터 모델 품질 검토
# ### 논리 데이터 모델 품질 검토 개요
# - 논리 데이터 모델의 품질 기준
#     - 정확성
#         - 데이터 모델이 표기법에 따라 정확하게 표현되었고, 업무 영역 또는 요구 사항이 정확하게 반영되었음을 의미함
#     - 완전성
#         - 데이터 모델 구성요소를 정의하는데 있어서 누락을 최소화하고, 요구 사항 및 업무 영역 반영에 있어서
#           누락이 없음을 의미함
#     - 준거성
#         - 제반 준수 요건들이 누락 없이 정확하게 준수되었음을 의미함
#     - 최신성
#         - 데이터 모델이 현행 시스템의 최신 상태를 반영하고 있고, 이슈 사항들이 제치없이 반영되고 있음을 의미
#     - 일관성
#         - 여러 영역에서 공통 사용되는 데이터 요소가 전사 수준에서 한 번만 정의되고 이를 여러 다른 영역에서
#           참조,활용되면서 모델 표현상의 일관성을 유지하고 있음을 의미
#     - 활용성
#         - 작성된 모델과 그 설명 내용이 이해관계자에게 의미를 충분하게 전달할 수 있으면서, 업무 변화 시에
#           설계 변경이 최소화 하도록 유연하게 설계되어 있음을 의미
# ### 논리 데이터 모델 품질 검토 체크리스트의 활용
# - 논리 데이터 모델 품질 검토 체크리스트 사례
#     - 엔터티
#         - 엔터티명, 엔터티 설명, 엔터티 정의, 통합 수준, 권한, 발생 건수-빈도, 다른 엔터티와의 관계, 법규 준수
#     - 속성
#         - 속성명, 속성 정의, 속성 설명, 속성 유형, 식별자 정의, 법규 준수, 도메인 정의, 추출 속성 정의
#     - 관계
#         - 관계명, 관계 정의, 관계 설명, 관계 표현, 식별자 상속, 요구 사항 추적 가능성, 외래키, 참조무결성
#     - 모델 전반
#         - 주제영역 적절성, 논리모델 상세화, 이력 관리
#
#
# -------------------------------------------------------------------------------------------------------------
# # 물리 데이터 모델링 (p481)
# ## 물리 데이터 모델링 이해
# ### 물리 데이터 모델 정의
# - 물리 데이터 모델이란 논리적 모델을 특정 데이터베이스로 설계함으로써 생성된 데이터를 저장할 수 있는 물리적인 스키마
# ### 물리 데이터 모델 의의
# ### 논리 데이터 모델-물리 데이터 모델
# - 분산 데이터베이스 구축 시
#     - 분산 데이터베이스 구축 시 노드별로 자신이 원하는 형태의 물리적 모델을 생성하고자 할 때 적용
# - 물리 데이터 모델 비교
# - 물리적 환경의 변화
# - 물리적 모델의 현상 관리
#
#
#
#
#
#
#
#
#
# ## 물리 요소 조사 및 분석
# ### 시스템 구축 관련 명명 규칙
# ### 하드웨어 자원 파악
# - CPU
# - 메모리
# - 디스크
# - I/O 컨트롤러
# - 네트워크
# ### 운영체제 및 DBMS 버전 파악
# ### DBMS 파라미터 정보 파악
# ### 데이터베이스 운영과 관련된 관리 요소 파악
# - 사용자 관리 기법 및 정책
# - 백업, 복구 기법 및 정책
# - 보안 관리 정책
#
#
#
#
#
#
#
#
# ## 논리-물리모델 변환
# ### 논리 데이터 모델-물리 데이터 모델 변환 용어
# - Entity -> table
# - Atrribute -> Column
# - Primary UID -> Primary Key
# - Secondary UID -> Unique Key
# - Relationship -> Foreign Key
# - Business Contraints -> Check Constraints
# ### 엔터티-테이블 변환
# - 테이블 설명
#     - 테이블
#     - 로우
#     - 컬럼
#     - 기본키
#     - 외래키
# - 서브타입 변환
#     - 슈퍼타입 기준 테이블 변환
#         - 변환
#             - 서브타입을 슈퍼타입에 통합하여 하나의 테이블로 만든다.
#             - 이 통합된 테이블에는 모든 서브타입의 데이터를 포함해야 한다.
#             - 주로 서브타입에 적은 양의 속성이나 관계를 가진 경우에 적용된다.
#         - 절차
#             - 슈퍼타입으로 테이블 명칭 부여
#             - 서브타입을 구분할 수 있도록 컬럼 추가
#             - 슈퍼타입의 속성을 컬럼명으로
#             - 서브타입의 속성을 컬럼명으로
#             - 슈퍼타입의 관계를 FK로
#             - 서브타입의 관계를 FK로
#         - 하나의 테이블로의 통합이 유리한 경우
#             - 데이터 액세스가 좀 더 간편
#             - 뷰를 활용하여 각 서브타입만을 액세스하거나 수정 가능
#             - 수행 속도가 좋아지는 경우가 많음
#             - 서브타입 구분 없는 임의 집합의 가공 용이
#             - 다수의 서브타입을 통합한 경우 조인(JOIN) 감소 효과가 큼
#             - 복잡한 처리를 하나의 SQL로 통합하기가 용이
#         - 하나의 테이블로의 통합이 불리한 경우
#             - 특정 서브타입의 Not Null 제한 불가
#             - 테이블의 컬럼 수가 증가
#             - 테이블의 블럭 수가 증가
#             - 처리 시마다 서브타입의 구분이 필요해지는 경우가 많음
#             - 인덱스 크기가 증가
#     - 서브타입 기준 테이블 변환
#         - 변환
#             - 슈퍼타입 속성들을 각 서브타입에 추가하여 각각의 서브타입마다 하나의 테이블로 만든다.
#             - 분할된 테이블에는 해당 서브타입의 데이터만 포함돼야 한다.
#             - 주로 서브타입에 많은 양의 속성이나 관계를 가진 경우에 적용된다.
#         - 절차
#             - 서브타입마다 테이블 명칭 부여
#             - 서브타입의 속성을 컬럼명으로
#             - 테이블마다 슈퍼타입의 속성을 컬럼으로
#             - 서브타입마다 해당되는 관계들을 FK로
#             - 테이블마다 슈퍼타입의 관계를 FK로
#         - 서브타입 기준으로 여러 개의 테이블로 분할한 경우가 유리한 경우
#             - 각 서브타입 속성들의 선택 사양이 명확한 경우에 유리하다.
#             - 처리 시마다 서브타입 유형 구분이 필요하다
#             - 전체 테이블 스캔 시 유리하다.
#             - 단위 테이블의 크기가 감소한다.
#         - 서브타입 기준으로 여러 개의 테이블로 분할한 경우가 불리한 경우
#             - 서브타입 구분 없이 데이터 처리하는 경우 UNION이 발생한다.
#             - 처리 속도가 감소하는 경우가 많다.
#             - 트랜잭션 처리 시 여러 테이블을 처리하는 경우가 증가한다.
#             - 복잡한 처리의 SQL 통합이 어려워진다.
#             - 부분 범위 처리가 불가능해질 수 있다.
#             - 여러 테이블을 합친 뷰는 조회만 가능하다.
#             - UID 유지 관리가 어렵다.
#     - 개별타입 기준 테이블 변환
#         - 변환
#             - 슈퍼타입과 서브타입을 각각 테이블로 변환한 경우이다.
#             - 슈퍼타입과 서브타입 테이블 간에는 1:1 관계가 생성된다.
#         - 다음의 여러 가지 경우를 만족할 때 사용
#             - 전체 데이터 처리가 빈번하게 발생할 경우에 적용한다.
#             - 서브타입의 처리는 주로 독립적으로 발생할 경우에 적용한다.
#             - 테이블을 통합했을 때 컬럼의 수가 너무 많아지는 경우에 적용한다.
#             - 서브타입의 컬럼 수가 많은 경우에 적용한다.
#             - 트랜잭션이 주로 공통 부분(슈퍼타입)에서 발생한다.
#             - 슈퍼타입의 처리 범위가 넓고 빈번하여 단일 테이블 클러스터링을 해야 할 때 적용한다.
# - 서브타입 변환 예
# ### 속성-컬럼 변환 (p497)
# - 일반 속성 변환
#     - 엔터티에 있는 각 속성들에 대한 컬럼명을 사례 데이터 표의 컬럼명란에 기록한다.
#     - 컬럼의 명칭은 속성의 명칭과 반드시 일치할 필요는 없으나 개발자와 사용자의 혼동을 피하기 위해 가급적 표준화된 약어를 사용한다.
#     - 표준화된 약어의 사용은 SQL 해독 시간을 감소시킨다.
#     - SQL의 예약어의 사용을 피한다.
#     - 가급적 컬럼명칭은 짧은 것이 좋으며, 짧은 명칭은 개발자의 생산성에 긍정적인 영향을 준다.
#     - 필수 입력 속성은 Nulls/Unique 란에 NN을 표시한다.
#     - 실제 테이블에 대한 설계를 검증하기 위한 목적으로 가능하다면 표본 데이터를 입력한다.
# - Primary UID -> 기본키 변환
#     - 변환 절차
#         - 사례 데이터 표의 키 형태 란에 엔터티의 Primary UID에 속하는 모든 속성에 PK를 표시
#         - PK로 표시된 모든 컬럼은 Nulls/Unique 란에 반드시 NN.U1로 표시되어야 함
#         - 또 다른 Unique Key(Secondary UID)가 있다면 U2로 표시
# - Primary UID(관계의 UID Bar) -> 기본키 변환
#     - 변환 절차
#         - 테이블에 외래키 컬럼을 포함시킨다.
#         - PK의 일부분으로 표시
#             - Nulls/Unique란에 각각 NN, U1을 표시
#             - 키 형태란에 PK, FK를 표시
#             - 여러 UID BAR가 있는 경우는 (PK, FK1), (PK, FK2)
#             - 여러 컬럼으로 구성된 경우 PK, FK1을 각각 표시
#         - 추가된 FK 컬럼에 표본 데이터를 추가
# - Secondary(Alternate) UID -> Unique Key 변환
# - 테이블 정의서
# ### 관계 변환
# - 1:M 관계 변환
#     - 1쪽에 있는 PK를 M의 FK로 변환
#         - FK의 명칭 결정
#         - 키 형태란에 FK 표시
#         - Nulls/Unique란에 NN 표시
#         - 필수 관계가 아닌 경우에는 NN을 체크하지 않는다.
#     - 표본 데이터 추가
#     - UID BAR가 있는 경우는 전단계에서 실시
#     - 1:M 관계에서 1 쪽이 Mandatory 관계일 때의 변환 시 주의 사항
#         - 자식 쪽의 레코드가 반드시 하나 이상은 되어야만 부모 쪽의 레코드를 생성할 수 있다.
#         - 자식 쪽의 레코드를 삭제할 경우에는 전체를 다 삭제할 수는 없고, 반드시 하나 이상의 자식 레코드를 남겨두어야 한다.
# - 1:1 관계 변환
#     - 변환 시 주의 사항
#         - 1:1 관계에 의해서 생긴 모든 외래키 부분은 Unique Key가 필수적이다.
#         - 한쪽이 Optional이고 다른 한쪽이 Mandatory라면 Mandatory 쪽의 테이블에 외래키가 생성된다.
#         - 양쪽 다 Mandatory라면 변환 시에 어떤 테이블에 외래키를 생성할 것인지를 선택해야 한다.
# - 1:M 순환 관계 변환
#     - 해당 테이블 내에 외래키 컬럼을 추가한다. 외래키는 같은 테이블 내의 다른 로우의 기본키 컬럼을 참조하게 된다.
#     - 외래키 컬럼명칭은 가능한 한 관계 명칭을 반영한다. 외래키는 결코 NN이 될 수 없다.
# - 배타적 관계 변환
# ### 관리상 필요한 컬럼 추가
# - 개념
#     - 논리 데이터 모델에는 존재하지 않지만 관리상의 이유로 혹은 데이터베이스를 이용하는 프로그래밍이 좀 더 빠르게 수행되도록
#       하기 위해 테이블이나 컬럼을 추가할 수 있다.
# - 시스템 컬럼 추가
# ### 데이터 타입 선택
# - 문자 타입
#     - 세부 문자 타입 선택을 위한 기준
#         - 영문만 사용되는가?
#         - 4000자 혹은 8000자 이상의 문자열이 포함되는가?
#         - 입력되는 값의 길이가 일정한가?
#     - 문자 형식 데이터 타입 설정 예
# - 숫자 타입
#     - 세부 숫자 타입 선택을 위한 기준
#         - 정말 숫자 데이터인지 판단한다.
#         - 세부 숫자 타입 결정
#             - 불린(Boolean)
#                 - 참 혹은 거짓을 저장하는 경우
#             - 정수(Integer)
#                 - 소수점 이하를 처리하지 않는 경우
#             - 소수(Decimal)
#                 - 소수점 이하를 처리하는 경우
#             - 화폐(Money)
#                 - 금액을 저장하기 위한 경우
#     - 숫자 형식 데이터 타입 지정
#         - 불린
#             - bit
#         - 정수
#             - inyint == 256
#             - smallint == 32,767
#             - int == 2,147,483,647
#             - bigint == 9,223,3272,036,854,775,807
#         - 소수
#             - real
#             - float
#             - numeric
#             - decimal
#         - 화폐
#             - smallmoney == 214,748.3647
#             - money == 922,337,203,685,477.5807
# - 날짜 타입
# ### 데이터 표준 적용
# - 개념
#     - 이름을 변환하는 과정에서 전사적으로 미리 생성된 데이터 표준을 따른다.
# - 데이터 표준 적용 대상
#     - 데이터베이스
#     - 스토리지 그룹
#     - 테이블스페이스
#     - 테이블
#     - 컬럼
#     - 인덱스
#     - 뷰
# - 데이터 표준 적용 방법
#     - 명명 규칙에 의한 표준화 적용
#         - 논리 데이터 모델을 물리 데이터 모델로 전환 시 테이블명은 엔터티 한글명과 동일한 용어를 사용하면서
#           해당 용어를 영문명으로 전환한다.
#         - 영문명은 영문 약어를 사용하며, 표준 용어 사전에 등록된 표준 영문 약어를 참조한다.
#         - 테이블의 명명 순서는 업무 영역 + 주제어 수식어 + 주제어 + 분류어 수식어 + 분류어 + 접미사
#     - 표준 용어집에 의한 표준화 적용
#
#
#
#
#
#
#
#
# ## 반정규화
# ### 테이블 분할
# - 개념
#     - 하나의 테이블을 수직 혹은 수평 분할하는 것을 테이블 분할 또는 파티셔닝
# - 수평 분할
#     - 개념
#         - 레코드를 기준으로 테이블을 분할하는 것
#     - 사용 의의
#         - 하나의 테이블에 데이터가 너무 많이 있고, 레코드 중에서 특정한 범위만을 주로 액세스하는 경우에 사용
#         - 분할된 각 테이블은 서로 다른 디스크에 위치시켜 물리적인 디스크의 효용성을 극대화할 수 있다.
#         - 현재는 이러한 수평 테이블의 분할은 DBMS 차원에서 제공
# - 수직 분할
#     - 개념
#         - 조회 위주의 컬럼과 갱신 위주의 컬럼으로 나뉘는 경우
#         - 특별히 자주 조회되는 컬럼이 있는 경우
#         - 특정 컬럼 크기가 아주 큰 경우
#         - 특정 컬럼에 보안을 적용해야 하는 경우
#     - 갱신 위주의 컬럼 수직 분할
#     - 자주 조회되는 컬럼 분할
#     - 특정 컬럼의 크기가 아주 큰 경우 분할
#     - 특정 컬럼에 보안을 적용해야 하는 경우의 분할
# ### 중복 테이블 생성
# - 중복 테이블 생성 판단 근거
#     - 정규화에 충실하면 종속성, 활용성은 향상되지만 수행 속도 증가가 발생하는 경우 고려한다.
#     - 많은 범위를 자주 처리해야 하는 경우에 고려
#     - 특정 범위의 데이터만 자주 처리되는 경우에 고려한다.
#     - 처리 범위를 줄이지 않고는 수행 속도를 개선할 수 없는 경우에 고려
#     - 요약 자료만 주로 요구되는 경우에 고려
#     - 추가된 테이블의 처리를 위한 오버헤드를 고려하여 결정
#     - 인덱스의 조정이나 부분 범위 처리로 유도하거나 클러스터링을 이용하여 해결할 수 있는지를 철저히 검토한 후 결정
# - 중복 테이블 유형
#     - 집계(통계) 테이블 추가
#         - 집계 테이블 유형
#             - 단일 테이블의 GROUP BY
#             - 여러 테이블의 조인 GROUP BY
#         - 집계 테이블 생성 시 유의 사항
#             - 로우 수와 활용도를 분석하고 시뮬레이션을 통해 그 효용성에 대한 면밀한 검토가 선행되어야 한다.
#             - 집계 테이블에 단일 테이블 클러스터링을 한다면 집계 레벨을 좀 더 낮춰 활용도를 높일 수 있는지를 검토해야 한다.
#             - 클러스터링, 결합 인덱스, 고단위 SQL을 활용하면 굳이 집계 테이블 없이도 양호한 수행 속도를 낼 수 있다.
#             - 집계 테이블을 다시 집계, 조인하면 추출할 수 있는지를 검토하여 지나친 집계 테이블을 만들지 않는 것이 좋다.
#             - 추가된 집계 테이블을 기존 응용 프로그램이 이용할 수 있는지를 찾아 보정하는 노력이 필요하다.
#             - 데이터베이스 트리거의 오버헤드에 주의하고 데이터의 일관성 보장에 유의하여야 한다.
#               즉 집계 테이블과 원본 데이터는 일관성 유지가 매우 중요하다.
#     - 진행 테이블 추가
#         - 진행 테이블 추가 사항
#             - 여러 테이블의 조인이 빈번히 발생하며 처리 범위도 넓은 경우
#             - M:M 관계가 포함된 처리의 과정을 추적, 관리하는 경우
#             - 검색 조건이 여러 테이블에 걸쳐 다양하게 사용되며 복잡하고 처리량이 많은 경우
#         - 진행 테이블 생성 시 유의 사항
#             - 데이터량이 적절하고 활용도가 좋아지도록 기본키를 선정
#             - 필요에 따라 적절한 추출(Derived) 컬럼을 추가하여 집계 테이블의 역할도 하는 다목적 테이블을 구상
#             - 다중 테이블 클러스터링이나 조인 SQL을 적절히 이용하면 굳이 진행 테이블을 만들지 않아도 양호한 수행 속도를 낼 수 있음
# ### 중복 컬럼 생성
# - 중복 컬럼 생성 상황
#     - 빈번하게 조인을 일으키는 컬럼에 대해 고려해 볼 수 있다.
#     - 조인의 범위가 다량인 경우를 온라인화해야 하는 경우처럼 속도가 중요한 컬럼에 대해서는 중복 컬럼을 고려할 수 있다.
#     - 액세스의 조건으로 자주 사용되는 컬럼에 대해 고려해 볼 수 있다.
#     - 자주 사용되는 액세스 조건이 다른 테이블에 분산되어 있어 상세한 조건 부여에도 불구하고 액세스 범위를 줄이지 못하는 경우에
#       자주 사용되는 조건들을 하나의 테이블로 모아 조건의 변별성을 극대화할 수 있다.
#     - 복사된 컬럼의 도메인은 원본 컬럼과 동일하게 해야 한다. 이것은 데이터의 일관성을 위해 필수적인 사항이다.
#     - 접근 경로의 단축을 위해 부모 테이블의 컬럼을 자식 테이블에 중복시킬 수 있다.
#     - 상위 레벨의 테이블에 집계된 컬럼을 추가할 수 있다. 즉 집계 컬럼을 추가한다.
#     - 하위 레벨의 테이블로 중복 컬럼을 복사 할 수 있다.
#     - 연산된 결과를 주로 사용하는 경우에도 미리 연산을 하여 중복 컬럼을 생성할 수 있다.
#     - 여러 컬럼의 조합 또는 복잡한 연산의 결과를 통해서 판단할 수밖에 없는 값이 검색의 조건으로 사용되는 경우에는
#       연산의 결과를 중복 컬럼으로 생성할 수 있다.
#     - 여러 개의 로우로 구성되는 값을 하나의 로우에 나열하는 경우이다. 즉 로우로 관리하던 데이터를 컬럼으로 관리하는 경우
#     - 기본키의 컬럼이 길거나 여러 개의 컬럼으로 구성되어 있는 경우 인위적인 기본키를 추가할 수 있다.
# - 중복 컬럼 생성 시 유의 사항
#     - 다중 테이블 클러스터링으로 해결할 수 있는지 검토한다.
#     - SQL GROUP 함수를 이용하여 처리할 수 있는지 검토한다.
#     - 저장 공간의 지나친 낭비를 고려하여 적절한 대비책을 마련해야 한다.
#     - 반복 컬럼은 특별한 경우를 제외하고는 절대 사용할 필요가 없고, 있다면 sum 용법과 같은 SQL 기법 등을 활용하여 이러한 부분을 피할 수 있도록 한다.
#     - 경우에 따라 상대 테이블의 ROWID를 복사하는 경우가 효과적일 때도 있다.
#     - 데이터의 일관성 보장에 유의해야 한다. 성능을 향상시키기 위해서 데이터의 일관성을 그르치는 일이 일어나서는 안 된다.
#     - 컬럼의 중복이 지나치게 심하면 데이터 처리의 오버헤드가 발생하게 된다.
#     - 사용자나 프로그램은 반드시 원본 컬럼만 수정하는 것이 바람직하다.
#     - 일반적으로 수행 속도를 우려해 지나치게 많은 중복 컬럼을 생성하고 있는 것이 현실이다.
#       가능하면 중복 컬럼을 적게 가져가는 것이 바람직하다.
#     - 클러스터링, 결합 인덱스, 적절한 SQL을 이용하면 특별한 경우를 제외하고는 거의 해결 가능하기 때문에 이 부분을
#       먼저 적극적으로 고려해 보는 것이 바람직하다.
#     - 중복 컬럼을 이용하면 손쉽게 액세스 효율을 개선할 수 있지만, 지나친 중복화는 반드시 데이터 일관성 오류 발생의 개연성 증가 및 데이터 처리
#       오버헤드 증가라는 반대급부가 있다는 것을 염두에 두고 수행해야 한다.
#     - JOIN, SUB-QUERY 액세스 경로의 최적화 방안을 더 철저히 강구해야 한다.
#
#
#
#
#
#
#
#
#
# ## 물리 데이터 모델 품질 검토
# ### 물리 데이터 모델 품질 검토 개요
# - 물리 데이터 모델 품질 기준
#     - 정확성
#         - 데이터 모델이 표기법에 따라 정확하게 표현되었고, 업무 영역 또는 요구 사항이 정확하게 반영되었음을 의미함
#     - 완전성
#         - 데이터 모델의 구성요소를 정의하는 데 있어서 누락을 최소화하고, 요구 사항 및 업무 영역 반영에 있어서 누락이 없음을 의미
#     - 준거성
#         - 제반 준수 요건들이 누락 없이 정확하게 준수되었음을 의미
#     - 최신성
#         - 데이터 모델이 현행 시스템의 최신 상태를 반영하고 있고, 이슈사항들이 지체 없이 반영 되고 있음을 의미
#     - 일관성
#         - 여러 영역에서 공통 사용되는 데이터 요소가 전사 수준에서 한 번만 정의되고 이를 여러 다른 영역에서 참조, 활용되면서
#           모델 표현상의 일관성을 유지하고 있음을 의미
#     - 활용성
#         - 작성된 모델과 그 설명 내용이 이해관계자에게 의미를 충분하게 전달할 수 있으면서, 업무 변화 시에 설계 변경이
#           최소화되도록 유연하게 설계 되어 있음을 의미
# ### 물리 데이터 모델 품질 검토 체크리스트의 활용

# %% [markdown]
# # 데이터 모델링(p319)
# ## 데이터 모델링 이해(p321)
# ### 데이터 모델링 개요(p322)
#     1. 데이터 모델링 정의
#         - 가. 데이터 모델링 탄생 배경
#         - 나. 정보시스템 개발 방법론
#     2. 데이터 모델링의 중요성
# ### 데이터 모델링 기법 이해(p332)
#     1. 엔터티-관계 데이터 모델
#         - 가. 추상화
#             - 유형화
#             - 집단화
#             - 일반화
#         - 나. 타입과 인스턴스
#     2. 엔터티-관계 데이터 모델 구성요소
#         - 가. 엔터티
#         - 나. 관계
#         - 다. 속성과 도메인
#         - 라. 식별자
# ### 데이터 모델링 표기법 이해(p340)
#     1. 엔터티-관계 데이터 모델 표기법
#         - 가. 엔터티 표기법
#         - 나. 속성 표기법
#         - 다. 관계 표기법
#             - 1) 관계 기수성(Cardinality, Degree) 표기법
#                 - 일대일 관계
#                 - 일대다 관계
#                 - 다대다 관계
#             - 2) 관계 선택성 표기법
#                 - 필수 관계
#                 - 선택 관계
#             - 3) 관계 식별성 표기법
#                 - 식별 관계
#                 - 비식별 관계
# ### 관계형 모델 이론(p349)
#     1. 릴레이션 개념
#             - 릴레이션 정의
#             - 속성과 도메인의 개념
#     2. 관계형 모델 이론
#         - 가. 데이터 구조
#             - 1) 각 열은 하나의 값을 가진다.
#             - 2) 각 열의 값은 동일한 종류이다.
#             - 3) 각 행은 유일하다.
#             - 4) 열의 순서는 의미가 없다.
#             - 5) 행의 순서는 의미가 없다.
#             - 6) 각 열은 유일한 이름을 갖는다.
#         - 나. 데이터 조작
#         - 다. 데이터 무결성
#             - 1) 엔터티 무결성 규칙
#             - 2) 참조무결성 규칙
#             - 3) 도메인 무결성 규칙
#             - 4) 연쇄 작용 또는 업무 규칙
# ## 데이터 모델링(p381)
# ### 논리 데이터 모델링 이해(p382)
#     1. 논리 데이터 모델링 핵심
#         - 가. 논리 데이터 모델링 필수 성공 요소
#         - 나. 논리 데이터 모델링 목적 및 효과
#     2. 논리 데이터 모델링 절차
#             - 주제 영역 정의
#             - 엔터티 정의
#             - 관계 정의
#             - 속성 정의
#             - 식별자 확정
#             - 정규화
#             - 이력관리
# ### 주제 영역 정의(p387)
#     1. 주제 영역 개념
#     2. 주제 영역 도출
#         - 가. 주제 영역 발견 기법
#         - 나. 주제 영역 도출 방안
#             - 1) 업무 기능의 이름으로부터 도출
#             - 2) 업무에서 사용하는 데이터의 명사형 도출
#             - 3) 하향식 접근방법
#             - 4) 상향식 접근방법
#         - 다. 주제 영역 명명
#             - 1) 업무에서 사용하는 용어를 부여한다.
#             - 2) 유일한 단수형 명사를 사용한다.
#             - 3) 데이터의 그룹을 의마하는 이름을 부여한다.
#     3. 주제 영역 활용
#         - 가. 목적
#         - 나. 장점
#     4. 주제 영역 정의 내용
#         - 가. 주제 영역 목록
#         - 나. 주제 영역 정의서 샘플 양식
#     5. 주제 영역 사례
# ### 엔티티 정의(p394)
#     1. 엔터티 개념
#     2. 엔터티 분류
#         - 가. 일반적인 엔터티 분류
#         - 나. 모델 관점 엔터티 분류
#             - 독립 엔터티
#             - 종속 엔터티
#         - 다. 발생 시점 엔터티 분류
#             - 1) 키 엔터티
#             - 2) 메인 엔터티
#             - 3) 액션 엔터티
#     3. 엔터티 도출
#         - 가. 현행 데이터베이스로부터 엔터티 도출
#         - 나. 정보요구 분석
#         - 다. 업무에서 사용하는 문서로부터 도출
#         - 라. 사용자 인터뷰로부터 도출
#         - 마. 아키텍처 모델로부터 도출
#         - 바. 업무를 수행하는 프로세스로부터 도출
#         - 사. 엔터티 분류 기법을 활용하여 도출
#     4. 엔터티 검증
#         - 가. 조직의 업무를 수행하는데 필요한 의미 있는 정보를 나타내야 한다.
#         - 나. 특정 사례가 아닌 유사한 사물들을 대표하는 집합체
#         - 다. 인스턴스가 포함할 내부 연관성 있는 속성에 의해 결정된 단일개념을 대표해야 한다.
#         - 라. 엔터티 내 인스턴스의 출현을 구별할 수 있는 능력을 제공해야 한다.
#         - 마. 정규화 규칙을 만족해야 한다.
#     5. 엔터티 정의 사항
#         - 가. 엔터티 명
#             - 지켜야 할 명명규칙
#             - 지키지 말아야 할 명명규칙
#         - 나. 엔터티 설명
#         - 다. 엔터티 분류
#         - 라. 현재 발생 건수
#         - 마. 발생 건수 변화
#         - 바. 권한
#         - 사. 식별자 속성
#         - 아. 외래 식별자 속성
#         - 자. 식별자 이외 속성
#     6. 엔터티 일반화
#         - 가. 일반화 정의
#         - 나. 일반화 특성
#         - 다. 일반화 시점
#         - 라. 일반화 장단점
# ### 관계 정의(p420)
#     1. 관계 개념
#     2. 관계 도출
#     3. 관계 정의 사항
#         - 가. 관계 명
#         - 나. 외래 키
#         - 다. 관계유형
#         - 라. 기수성, 선택성
#         - 마. 참조무결성
#     4. 특수 관계
#         - 가. 자기 참조 관계
#         - 나. 다대다 관계
#         - 다. 배타적 관계
# ### 속성 정의(p432)
#     1. 속성 개념
#     2. 속성 도출
#         - 가. 현행 시스템 자료
#         - 나. 현업 장표 보고서
#         - 다. 사용자와 협의
#         - 라. 데이터 흐름도의 데이터 저장소
#         - 마. 전문 서적 및 자료
#         - 바. 다른 시스템 자료
#     3. 속성 정의 사항
#         - 가. 속성 명
#             - 1) 의미가 명확한 속성 명칭 부여
#             - 2) 유일한 복합명사 사용
#             - 3) 단수형으로 속성 명 사용
#             - 4) 표준 단어 및 용어 제정
#         - 나. 속성 설명
#         - 다. 선택성 및 선택성 조건
#         - 라. 속성 유형
#         - 마. 유도 알고리즘
#         - 바. 도메인
#         - 사. 허용 값
#         - 아. 기본 값
#         - 자. 소유 권한
#     4. 속성 검증 및 확정
#         - 가. 원자 값 단위까지 분할
#             - 1) 일자 형태의 속성 : 매출일자, 생년월일
#             - 2) 외부에서 만들어진 공인된 속성 : 우편번호 유형
#             - 3) 전화번호 유형 : 전화번호, 팩스번호
#         - 나. 하나의 값만을 가지는지 검증
#             - 1) 계약일자
#             - 2) 차량번호
#             - 3) 취미
#         - 다. 유도 속성인지 검증
#             - 1) 현재 정보만 관리하는 형태 : 현주소, 현고객등급코드 등
#             - 2) 최초 정보를 보관하는 형태 : 최초가입일자, 모집사원번호 등
#             - 3) 집계 정보를 관리하는 형태 : 인원 수, 가족 수, 총직원 수 등
#             - 4) 추출 관계만 관리하는 형태 : 가입, 계약번호, 관리 사원 등
#             - 5) 대표 정보만 관리하는 형태 : 대표 전사메일 ID, 취미, 법인의 대표자 정보
#             - 6) 다른 속성의 일부 정보만 분리한 형태 : 성별, 결혼 여부 등
#             - 7) 일부분만 추출 값인 형태 : 인원 수, 법인의 대표자 정보 등
#     5. 유도 속성 규칙
# ### 식별자 확정(p446)
#     1. 식별자 개념
#         - 가. 식별자 종류
#             - 1) 기준 정보 엔터티의 본질 식별자
#             - 2) 거래 처리 엔터티의 본질 식별자
#         - 나. 후보 식별자 도출
#             - 1) 널이 될 수 없다.
#             - 2) 각 인스턴스를 유일하게 식별할 수 있어야 한다.
#             - 3) 나머지 속성들을 직접 식별할 수 있어야 한다.
#             - 4) 후보 식별자로 속성 집합을 선택하는 경우에는 개념적으로 유일해야 한다.
#             - 5) 후보 식별자의 데이터는 자주 변경되지 않는 것이어야 한다.
#         - 다. 보조 식별자
#         - 라. 인조 식별자 지정
#             - 1) 최대한 범용적인 값을 사용한다.
#             - 2) 유일한 값을 만들기 위한 인조 식별자를 사용한다.
#             - 3) 하나의 인조 식별자 속성으로 대체할 수 없는 형태를 주의한다.
#             - 4) 편의성, 단순성 확볼르 위한 인조 식별자를 사용할 수 있다.
#             - 5) 의미의 체계화를 위한 인조 식별자를 사용할 수 있다.
#             - 6) 내부적으로만 사용하는 인조 식별자
#         - 마. 식별자 확정
#             - 1) 식별 관계의 두 가지 의미
#             - 2) 식별자 상속과 단절의 원리
#             - 3) 식별자 확정 절차
# ### 정규화(p454)
#     1. 정규화 정의
#     2. 정규화 장점
#     3. 정규화 과정
#         - 가. 제1정규형
#         - 나. 제2정규형
#         - 다. 제3정규형
# ### 이력 관리(p463)
#     1. 이력 관리란?
#     2. 이력 관리 대상 선정
#         - 가. 사용자 조사
#         - 나. 이력 데이터의 종류
#             - 1) 발생 이력 데이터
#             - 2) 변경 이력 데이터
#             - 3) 진행 이력 데이터
#         - 다. 이력 관리 형태
#             - 1) 시점 이력
#             - 2) 선분 이력
#         - 라. 선분 이력 관리 유형
#             - 1) 인스턴스 레벨 이력 관리
#             - 2) 속성 레벨 이력 관리
#             - 3) 주제 레벨 이력 관리
#     3. 선분 이력 관리용 식별자 확정
#         - 가. 선분 이력에서 식별자 결정 시 고려 사항
#         - 나. 선분 이력에서 종료점 처리 시 주의 사항
#             - 1) 종료점이 미정이므로 NULL
#             - 2) 수렴하므로 최대치 부여
# ### 논리 데이터 모델 품질 검토(p471)
#     1. 논리 데이터 모델 품질 검토 개요
#     2. 논리 데이터 모델 품질 검토 체크리스트의 활용
# ## 물리 데이터 모델링(p481)
# ### 물리 데이터 모델링 이해(p482)
#     1. 물리 데이터 모델 정의
#     2. 물리 데이터 모델 의의
#     3. 논리 데이터 모델-물리 데이터 모델
#         - 가. 분산 데이터베이스 구축 시
#         - 나. 물리 데이터 모델 비교
#         - 다. 물리적 환경의 변화
#         - 라. 물리적 모델의 형상 관리
# ### 물리 요소 조사 및 분석(p484)
#     1. 시스템 구축 관련 명명 규칙
#     2. 하드웨어 자원 파악
#         - 가. CPU
#         - 나. 메모리
#         - 다. 디스크
#         - 라. I/O 컨트롤러
#         - 마. 네트워크
#     3. 운영체제 및 DBMS 버전 파악
#     4. DBMS 파라미터 정보 파악
#     5. 데이터베이스 운영과 관련된 관리 요소 파악
# ### 논리-물리 모델 변환(p486)
#     1. 논리 데이터 모델-물리 데이터 모델 변환 용어
#     2. 엔터티-테이블 변환
#         - 가. 테이블 설명
#             - 1) 테이블
#             - 2) 로우
#             - 3) 칼럼
#             - 4) 기본키
#             - 5) 외래키
#         - 나. 서브타입 변환
#             - 1) 슈퍼타입 기준 테이블 변환
#             - 2) 서브타입 기준 테이블 변환
#             - 3) 개별타입 기준 테이블 변환
#         - 다. 서브타입 변환 예
#             - 1) 케이스 1 : 서브타입을 테이블로 분리
#             - 2) 케이스 2 : 서브타입을 통합 테이블로 생성
#         - 라. 테이블 목록 정의서
#     3. 속성-칼럼 변환
#         - 가. 일반 속성 변환
#         - 나. Primary UID -> 기본키 변환
#             - 1) 변환 절차
#             - 2) 변환 예
#         - 다. Primary UID(관계의 UID Bar) -> 기본키 변환
#             - 1) 변환 절차
#             - 2) 변환 예
#         - 라. Secondary(Alternate) UID -> Unique Key 변환
#         - 마. 테이블 정의
#     4. 관계 변환
#         - 가. 1:M 관계 변환
#             - 1) 변환 절차
#             - 2) 변환 예
#             - 3) 1:M 관계에서 1쪽이 Mandatory 관계일 떄의 변환 시 주의 사항
#         - 나. 1:1 관계 변환
#             - 1) 변환절차
#             - 2) 변환 예
#             - 3) 변환 시 주의 사항
#         - 다. 1:M 순환 관계 변환
#             - 1) 변환절차
#             - 2) 변환 예
#         - 라. 배타적 관계 변환
#             - 1) 외래키 분리 방법
#             - 2) 외래키 결합 방법
#     5. 관리상 필요한 컬럼 추가
#         - 가. 개념
#         - 나. 시스템 컬럼 추가 예
#     6. 데이터 타입 선택
#         - 가. 개념
#         - 나. 문자 타입
#             - 1) 세부 문자 타입 선택을 위한 기준
#             - 2) 문자 형식 데이터 타입 설정 예
#         - 다. 숫자 타입
#             - 1) 세부 숫자 타입 선택을 위한 기준
#             - 2) 숫자 형식 데이터 타입 지정 예
#         - 라. 날짜 타입
#             - 1) 세부 날짜 타입 선택을 위한 기준
#             - 2) 세부 날짜 타입 지정 예
#     7. 데이터 표준 적용
#         - 가. 개념
#         - 나. 데이터 표준 적용 대상
#             - 1) 데이터베이스
#             - 2) 스토리지 그룹
#             - 3) 테이블스페이스
#             - 4) 테이블
#             - 5) 컬럼
#             - 6) 인덱스
#             - 7) 뷰
#         - 다. 데이터 표준 적용 방법
#             - 1) 명명 규칙에 의한 표준화 적용
#             - 2) 표준 용어집에 의한 표준화 적용
# ### 반정규화(p511)
#     1. 테이블 분할
#         - 가. 개념
#         - 나. 수평 분할
#             - 1) 개념
#             - 2) 사용 의의
#         - 다. 수직 분할
#             - 1) 개념
#             - 2) 갱신 위주의 컬럼 수직 분할
#             - 3) 자주 조회되는 컬럼 분할
#             - 4) 특정 컬럼의 크기가 아주 큰 경우 분할
#             - 5) 특정 컬럼에 보안을 적용해야 하는 경우의 분할
#     2. 중복 테이블 생성
#         - 가. 개념
#         - 나. 중복 테이블 생성 판단 근거
#         - 다. 중복 테이블 유형
#             - 1) 집계(통계) 테이블 추가
#             - 2) 진행 테이블 추가
#     3. 중복 컬럼 생성
#         - 가. 개념
#         - 나. 중복 컬럼 생성 상황
#         - 다. 중복 컬럼 생성 시 유의 사항
# ### 물리 데이터 모델 품질 검토(p520)
#     1. 물리 데이터 모델 품질 검토 개요
#     2. 물리 데이터 모델 품질 검토 체크리스트의 활용
