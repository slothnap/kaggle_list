# %% [markdown]
# ################################################################################################################
# # 전사아키텍처개요

# %% [markdown]
# ## 전사아키텍처 정의
#
# - **전사아키텍처 개념**
#     - 전사아키텍처 도입 배경
#     - 전사아키텍처 정의
#         - 기업의 목표와 요구를 잘 지원하기 위해 IT 인프라의 각 부분들이 어떻게 구성되고 작동되어야 하는가를 체계적으로 기술하는 것
#         - 기업의 다양한 측면(비즈니스, 데이터, 애플리케이션, 기술)
#     - 전사개념
#         - 전사란 일반적으로 기업 또는 기관을 지칭
#     - 아키텍처 개념
#         - 규칙 관점
#             - 의사결정 단계에 원칙을 수립하고 적용
#         - 모델 관점
#             - 모델의 표준화 하는것이 중요
#         - 계획 관점
#             - 현재 상태에서 목표 상태로 되기 위한 적절한 이행 전략과 구축 계획이 필요
# - **전사아키텍처 추진 현황**
#     - 전사아키텍처 (EA)
#         - 광의의 아키텍처
#     - 정보기술아키텍처 (ITA)
#         - 정보기술 중심의 아키텍처
# - **전사아키텍처 관련 데이터아키텍처 전문가 역할**

# %% [markdown]
# ## 전사아키텍처 프레임워크
#
# - **전사아키텍처 프레임워크 개념**
# - **전사아키텍처 프레임워크 구성**
#     - 전사아키텍처 정책
#         - 아키텍처 매트릭스
#             - 계획자, 책임자/분석자, 설계짜, 개발자
#             - 비즈니스 아키텍처, 애플리케이션 아키텍처, 데이터 아키텍처, 기술 아키텍처
#         - EA 비전
#             - 전사아키텍처 수립을 통하여 기업이 궁극적으로 달성하고자 하는 모습
#         - EA 원칙
#     - 전사아키텍처 정보
#         - 현행 아키텍처
#             - 아키텍처 도메인벼로 정의된 산출물에 대하여 기업의 현재 상태를 아키텍처 정보로 정의한 것
#         - 목표 아키텍처
#             - 아키텍처 도메인별로 정의된 산출물에 대하여 기업이 궁극적으로 달성하고자 하는 목표를 정의
#         - 전사아키텍처 이행계획
#             - 아키텍처 도메인별로 현재 모습에서 바람직한 목표 모습으로 이행하기 위한 이행 전략과 계획 정의
#         - 아키텍처 도메인
#             - '비즈니스 아키텍처'
#                 - 조직의 목적 및 임무 지원을 위해 업무를 관리
#             - '데이터 아키텍처'
#                 - 효과 적인 업무 처리 및 의사결정을 위한 정보 관리
#             - '애플리케이션 아키텍처'
#                 - 조직의 임무를 수행하는데 필요한 애플리케이션 관리
#             - '기술 아키텍처'
#                 - 비즈니스, 데이터, 애플리케이션 아키텍처 구성을 위한 기술 인프라 관리
#     - 전사아키텍처 관리
#         - 전사아키텍처 관리 체계
#             - 전사아키텍처 거버넌스, 구축된 전사 아키텍처를 유지하고 개선하기 위한 제도적 기반을 수립하는 것
#         - 전사아키텍처 관리 시스템
#             - 전사아키텍처의 정보 관리의 효율성을 제고하고 전사아키텍처 정보의 공유를 활성화하기 위해 구축하는 정보시스템
#         - 전사아키텍처 평가
#             - 전사아키텍처의 수준을 객관적이고 정확하게 평가할 수 있는 전사아키텍처 성숙 모형이 필요
# - **아키텍처 도메인 구성**
# ![image.png](attachment:image.png)
#     - 비즈니스 아키텍처
#         - 기업 업무 구조를 체계화
#     - 애플리케이션 아키텍처
#         - 기업 업무 애플리케이션 구조를 체계화
#     - 데이터 아키텍처
#         - 기업 업무 데이터의 구조를 체계화
#     - 기술 아키텍처
#         - 기업 업무 기술 인프라 체계화
#         - 하드웨어, 시스템 소프트웨어, 통신 네트워크, 시스템 개발도구
# - **전사아키텍처 프레임워크 사례**

# %% [markdown]
# ## 전사아키텍처 참조 모델
#
# - **참조 모델 정의**
#     - 참조 모델 개념
#         - 아키텍처 구성 요소를 식별하여 표준화한 것으로 기관이나 기업의 전사아키텍처를 수립할 때 참조하는 추상화된 모델
#     - 참조 모델 현황
#     - 참조 모델 구축 방법
# - **참조 모델 사례**
#     - '성과 참조 모델'
#         - 정보화 성과 관리를 위한 구성 요소와 관계를 정의
#         - 정보화 성과의 측정을 위한 항목과 지표 및 방법을 제시
#     - '업무 참조 모델'
#         - 특정 기관의 독립적인 업무 기능을 중심으로 정의한 참조 모델
#         - 업무아키텍처의 기준이 되며, 아키텍처 대상 기관의 사업 또는 업무 등을 전체적으로 분류하고 정의하는 것
#     - '서비스 참조 모델'
#         - 업무 수행과 목표 달성을 지원하는 서비스 요소를 분류 참조 모델
#         - 응용아키텍처의 기준이 되며, 응용 서비스의 기능을 분류하고 정의
#     - '기술 참조 모델'
#         - 업무와 서비스 구성 요소의 전달, 구축을 지원해 주는 표준, 명세, 기술 요소를 기술
#         - 기술아키텍처의 기준이 되며, 정보기술을 분류 및 식별
#     - '데이터 참조 모델'
#         - 기관 간의 공통 정보 파악과 활용을 지원하기 위한 모델
#         - 데이터아키텍처의 기준이 되며, 기관 간에 교환되는 주요 데이터 요소를 분석하여 이를 정의하고 표준화
#         - 범정부 데이터 모델, 데이터 분류, 데이터 구조, 데이터 교환, 데이터 관리
# - **참조 모델 활용**
#     - 업무 참조 모델
#         - 관련 기관 간 업무 흐름 촉진
#         - 업무 프로세스 혁신을 통한 업무 처리 생산성 제고
#         - 비즈니스 성과 측정 용이
#     - 데이터 참조 모델
#         - 정보의 상호운용성과 교환 촉진
#         - 정부나 기업 또는 산업 차원의 통합된 데이터 활용
#         - 데이터 중복 배제 및 재사용
#         - 데이터에 대한 표준화된 정의
#     - 서비스 참조 모델
#         - 시스템 간 상호운용성 향상
#         - 신뢰성 있는 시스템 구축 가능
#         - 변화에 신속한 대응 가능
#         - 시스템 개발 생산성, 품질 향상 기대
#     - 기술 참조 모델
#         - 시스템 간 상호운용성 향상
#         - 이식성 향상
#         - 시스템 확장성 향상
#         - 표준화 따른 벤더 독립성
#         - 재활용과 리소스 공유
#     - 성과 참조 모델
#         - 체계적인 정보화 성과 측정 및 관리
#         - 정보화 사업의 중복 투자 최소화
#         - 성과 기반의 예싼 편성 지원
#         - IT 자원의 효율적 관리

# %% [markdown]
# ## 전사아키텍처 프로세스
# - **전사아키텍처 프로세스 개요**
# - **전사아키텍처 프로세스 구성**
#     - 전사아키텍처 비전 수립
#         - 내외부 EA 환경 분석
#         - 기업의 EA 목적 및 방향 정의
#         - 기업의 EA 프레임워크 정의
#     - 전사아키텍처 구축
#         - EA 정보 구성 정의
#             - 아키텍처 매트릭스 정의
#             - EA 정보 구성 요소 정의
#             - EA 참조 모델 정의
#             - EA 원칙 수립
#         - EA 정보 구축
#             - EA 자료 수집
#             - 현행 아키텍처 정보 구축
#             - 목표 아키텍처 정보 구축
#     - 전사아키텍처 관리
#         - EA 관리 체계 구축
#             - EA 정보를 운영 및 활용하기 위한 조직 및 프로세스 정의
#             - 기업 내 EA 홍보 및 내부 추진 체계에 대한 교육 수행
#         - EA 관리 시스템 구축
#             - EA 정보를 관리하기 위한 도구 선정
#             - EA 정보를 관리하는 시스템 구축
#     - 전사아키텍처 활용 단계
#         - EA 이행 계획
#             - 목표 아키텍처를 달성하기 위한 중장기적인 계획 수립
#         - EA 정보 활용
#             - EA 정보를 적용하여 IT 관련 업무를 수행함

# %% [markdown]
# ################################################################################################################
# # 전사아키텍처 구축

# %% [markdown]
# ## 전사아키텍처 방향 수립
# - **전사아키텍처 정보 구성 정의**
# - **전사아키텍처 환경 분석**
#     - 전사아키텍처 환경 분석 수행 과제
#         - 전사아키텍처 환경 분석 수행 과제
#             - 경영 이념 이해
#             - 외부 환경 분석
#             - 내부 환경 분석
#             - 정보기술 환경 분석
#             - 요구사항 분석
#         - 비즈니스 내/외부 환경 분석
#         - IT 내/외부 환경 분석
#         - 전사 범위 정의
# - **전사아키텍처 구축 방향 정의**
#     - 목적 및 범위 정의
#         - 상호운용성 증대
#         - 정보화 투자 의사결정 체계 구축
#         - 비즈니스 변화에 대한 신속한 대응체계 구축
#         - 전사적 정보화 표준 정립
#         - 고객 지향의 정보화 체계 구축
#     - 전사아키텍처 비전 수립
#         - 전사아키텍처 비전
#             - 고객과 성과를 지향하는 업무 중심 전자 정부 통합 관리 체계 구현
#         - 핵심 목적
#             - 행정 서비스에 대한 국민 만족
#             - 고객 중심
#             - 성과 지향
#             - 업무 중심
#         - 핵심 가치
#             - 업무와 정보 기술 연계 노력
#             - 정보화 비전 및 설계도
#             - 변화 대응 체계 구축
#             - 통합 관리 체계 구축
#             - 정보 자원 표준 및 지식 체계 구축
#     - 전사아키텍처 프레임워크 정의
#         - 방향/지침
#             - 정보 기술 정책
#             - 전사아키텍처 전략
#             - 아키텍처 원칙
#             - 요구사항
#         - 전사아키텍처 활동
#             - 아키텍처 모델
#             - 생명주기
#             - 지원 도구
#         - 산출물
#             - 아키텍처 산출물
#             - 자원 산출물

# %% [markdown]
# ## 전사아키텍처 정보 구성 정의
# - **전사아키텍처 정보 구성 개요**
#     - 전사아키텍처 정보는 기업을 잘 이해하기 위해 필요한 업무와 정보기술에 대한 정보로서 활용할만한 가치가 있고 관리가
#       용이한 정보라고 정의할 수 있다.
# - **아키텍처 매트릭스 정의**
#     - 아키텍처 매트릭스 개념
#     - 아키텍처 매트릭스 구성
#         - 의사결정 유형(관점)
#             - 조직의 의사결정 유형을 계층적으로 구분한 것
#             - 구성 요소 도출
#                 - 정보화 관련 이해 관계자 식별
#                 - 의사결정 계층 구조 분석
#                 - 이해 관계자별 의사결정 관계 분석
#                 - 의사결정 계층 구조 조정 및 필요 정보 식별
#         - 아키텍처 정보 유형(뷰)
#             - 특성이 비슷한 아키텍처 정보를 그룹화 한 것
#                 - 아키텍처 뷰 구성 사례 검토
#                 - 기본 구조 선택
#                 - 정보관리 요건 반영
#     - 산출물 정의
#         - 계획자
#             - 조직 구성도 / 정의서 | 업무 구성도 / 정의서
#             - 데이터 구성도 / 정의서
#             - 응용 시스템 구성도 / 정의서
#             - 표준 프로파일 | 기반 구조 구성도 / 정의서 | 기술 자원 목록
#         - 책임자
#             - 업무 관계도 / 기술서 | 업무 기능 분할도 / 기술서
#             - 개념 데이터 관계도 / 기술서 - 데이터 교환 기술서
#             - 응용 시스템 관계도 / 기술서 - 응용 기능 분할도 / 기술서
#             - 기반 구조 관계도 / 기술서
#         - 설계자
#             - 업무 절차 설계서
#             - 논리 데이터 설계서 | 데이터 교환 설계서
#             - 응용 기능 설계서 | 응용 분산 시스템 설계서
#             - 기반 구조 설계서 | 시스템 성능 설계서
#         - 개발자
#             - 업무 메뉴얼
#             - 물리 데이터 모델
#             - 응용 프로그램 목록
#             - 제품 목록
#         - 매트릭스 셀 정의 내역
#             - 현행 산출물 분석
#             - 목표 산출물 정의
#             - 산출물간 연관성 정의
#             - 산출물 표현 방법 및 세부 구성 정의
#     - 전사아키텍처 정보 구성요소 정의
#         - 전사아키텍처 정보 구성요소 식별
#         - 전사아키텍처 정보 구성요소 연관관계
#     - 아키텍처 매트릭스 정의시 고려사항
#         - 아키텍처 매트릭스에 정의되는 산출물은 업무와 IT, 관리자와 실무자 사이의 중요한 커뮤니케이션 툴이다.
#         - 조직적, 정치적, 지리적 특성, 조직의 편견 등 다양한 조직 문화와 의사결정 구조가 반영되어야 한다.
#         - 아키텍처 매트릭스는 실제 시스템과 아키텍처 개발 표준에 대한 준수성을 높이고 조직별로 통일된
#           접근이 가능하도록 정의되어야 한다.
#         - 각 아키텍처 도메인은 상호 간에 연계성을 가져야 한다.
# - **참조 모델 정의**
#     - 참조 모델 정의 작업에서는 기업의 기준 모델로 정의할 참조 모델의 체계와 구조를 정의하고 컨텐츠를 구축한다.
# - **전사아키텍처 원칙 수립**
#     - 원칙
#         - 원칙의 내용을 간략하게 기술
#     - 의미
#         - 원칙이 가지는 의미를 설명
#     - 근거
#         - 원칙으로 채택된 원인 또는 배경
#     - 기대효과
#         - 원칙이 전사아키텍처 수립에 미치는 영향 또는 준수시의 기대효과
#     - 전사아키텍처 기본 원칙
#         - 업무 지향, 성과 지향, 고객 지향, 상호운용
#     - 아키텍처 원칙
#         - 비즈니스, 데이터, 애플리케이션, 기술

# %% [markdown]
# ## 전사아키텍처 정보 구축
# - **전사아키텍처 정보 구축 정비**
#     - 자료 수집
#     - 전사아키텍처 정보 구축 방식
#         - 상향식 구축 방법
#             - 최하위에 있는 구성요소를 조사 분석하여 구성요소들의 공통점을 파악하여 공통적인 구성요소들을 모아
#               상위 구성요소를 정의해 나가는 방식
#             - 상위 업무 기능 분류의 수준이 서로 다르게 나타날 수 있는 단점
#         - 하양식 구축 방법
#             - 최상위의 구성요소로부터 시작하여 분류 기준에 따라 하위 구성요소를 도출해 내는 방식
#             - 일부 업무가 누락될 가능성이 있으며, 어디에도 포함되지 않는 구성요소가 발생할 수 있다는 것이 단점
# - **현행 아키텍처 정보 구축**
#     - 현행 비즈니스 아키텍처 정보 구축
#         - 기업의 비전, 경영 목표, 조직 구조 등을 파악하여 정의하는 것에서 시작
#         - 현행 비즈니스 아키텍처 정의 내역
#             - 전사 사업모델 분석
#             - 조직 모델 분석
#             - 업무 기능 모델 정의
#             - 프로세스 모델 정의
#             - 업무 매뉴얼 파악
#     - 현행 애플리케이션 아키텍처 정보 구축
#         - 업무 기능 분류를 기반으로 전사 애플리케이션을 분류하고, 연관 관계를 분석하는 것에서 시작
#         - 현행 애플리케이션 아키텍처 정의 내역
#             - 전사 애플리케이션 영역 식별
#             - 애플리케이션 모델 정의
#             - 컴포넌트 모델 정의
#             - 프로그램 목록 파악
#             - 애플리케이션 원칙, 표준 파악
#     - 현행 데이터아키텍처 정보 구축
#         - 하향식의 경우 기업의 업무 수행을 위해 필요한 데이터 요건을 식별하여 데이터 모델로 표현
#         - 상향식의 경우 각 시스템에서 사용하는 데이터 정보를 분석하여 데이터 모델로 정렬하여 표현
#         - 현행 데이터아키텍처 정의 내역
#             - 전사 데이터 영역 식별
#             - 개념 데이터 모델 정의
#             - 논리 데이터 모델 정의
#             - 물리 데이터 모델 정의
#             - 데이터베이스 객체 파악
#             - 데이터 원칙, 표준, 관리 프로세스 파악
#     - 현행 기술 아키텍처 정보 구축
#         - 기업의 전산 장비, 시스템 소프트웨어, 네트워크 등 기술 인프라의 구성을 체계적으로 분류하여 표현하는 것
#         - 현행 기술 아키텍처 정의 내역
#             - 전사 기술영역 식별
#             - 기술 참조 모델 정의
#             - 기술 표준 분석
#             - 기술 아키텍처 요소 식별
#             - 기술자원 목록, 제품 목록 파악
# - **목표 아키텍처 정보 구축**
#     - 목표 아키텍처 구축은 현행 아키텍처에 대한 문제점과 개선 사항을 도출하고,
#       이를 목표 아키텍처에 반영하는 방식으로 진행
#     - 목표 비즈니스아키텍처 구축
#         - 현행 추가 업무와 개선 요구 사항을 목표 비즈니스아키텍처에 반영한다.
#         - 목표 비즈니스 아키텍처 정의 내역
#             - 전사 사업 모델 정의
#             - 조직 모델 정의
#             - 업무 기능 모델 정의
#             - 프로세스 모델 정의
#             - 업무 매뉴얼 정보 구축
#     - 목표 애플리케이션 아키텍처 정보 구축
#         - 목표 비즈니스 아키텍처를 지원하는 전사 애플리케이션의 구조를 정의하는 것
#         - 목표 애플리케이션 아키텍처 정의 내역
#             - 전사 애플리케이션 영역 모델 정의
#             - 애플리케이션 모델 정의
#             - 컴포넌트 모델 정의
#             - 프로그램 목록 정보 구축
#     - 목표 데이터아키텍처 정보 구축
#         - 목표 비즈니스 아키텍처를 지원하는 데이터를 식별하여 모델로 표현하는 것
#         - 목표 데이터아키텍처 정의 내역
#             - 전사 데이터 영역 모델 정의
#             - 개념 데이터 모델 정의
#             - 논리 데이터 모델 정의
#             - 물리 데이터 모델 정의
#             - 데이터베이스 개체 정보 구축
#             - 데이터 원칙, 표준, 관리 프로세스 정의
#     - 목표 기술 아키텍처 정보 구축
#         - 목표 애플리케이션 아키텍처와 데이터아키텍처를 잘 지원할 수 있는 기술 아키텍처를 정의하는 것
#         - 목표 기술 아키텍처 정의 내역
#             - 전사 기술 영역 모델 정의
#             - 기술 참조 모델 정의
#             - 표준 프로파일 정의
#             - 기술 아키텍처 모델 정의
#             - 기술자원 목록, 제품 목록 정보 구축

# %% [markdown]
# ################################################################################################################
# # 전사아키텍처 관리 및 활용

# %% [markdown]
# ## 전사아키텍처 관리 체계
# - **전사아키텍처 관리 체계 개요**
#     - 전사아키텍처 관리 체계 개념
#     - 전사아키텍처 관리 체계 구축 방향
# - **전사아키텍처 관리 조직 체계**
#     - 전사아키텍처 관리 조직 개요
#     - 전사아키텍처 관리 조직의 정의
# - **전사아키텍처 관리 프로세스**
#     - 전사아키텍처 관리 프로세스 개요
#     - 전사아키텍처 관리 프로세스 구성
# - **전사아키텍처 관리 이력**
#     - 전사아키텍처 관리 인력 개요
#     - 전사아키텍처 전문가 육성

# %% [markdown]
# ## 전사아키텍처 관리 시스템
# - **전사아키텍처 관리 시스템**
#     - 전사아키텍처 관리 시스템 개요
# - **전사아키텍처 정보 정의 도구**
# - **전사아키텍처 정보 관리 시스템**

# %% [markdown]
# ## 전사아키텍처 활용
# - **전사아키텍처 활용 개요**
# - **목표 아키텍처 이행 계획**
# - **전사아키텍처 정보 상시 활용**
# - **전사아키텍처와 데이터아키텍처 전문가 영역**
#     - 전사아키텍처와 데이터아키텍처 프레임워크
#     - 전사아키텍처와 데이터아키텍처
