# %% [markdown]
# # 전사아키텍처 개요
# * 전사아키텍처 정의
#     - 전사아키텍처 개념
#         - 전사아키텍처 도입 배경
#         - 전사아키텍처 정의
#         - 전사 개념
#         - 아키텍처 개념
#             - 규칙(RULE) 관점
#             - 모델(MODEL) 관점
#             - 계획(PLAN) 관점
#     - 전사아키텍처 추진 현황
#         - 범정부 전사아키텍처 참조모델
#         - 범정부 전사아키텍처 산출물 메타 모델
#         - 범정부 전사아키텍처 성숙도 모델
#         - 범정부 전사아키텍처 지원시스템
#     - 전사아키텍처 관련 데이터아키텍처 전문가 역할
# * 전사아키텍처 프레임워크
#     - 전사아키텍처 프레임워크 개념
#     - 전사아키텍처 프레임워크 구성
#         - 전사아키텍처 정책
#             - 아키텍처 매트릭스
#             - 전사아키텍처 비전
#             - 전사아키텍처 원칙
#         - 전사아키텍처 정보
#             - 현행 아키텍처
#             - 목표 아키텍처
#             - 전사아키텍처 이행계획
#             - 아키텍처 도메인
#         - 전사아키텍처 관리
#             - 전사아키텍처 관리 체계
#             - 전사아키텍처 관리 시스템
#             - 전사아키텍처 평가
#     - 아키텍처 도메인 구성
#         - 비즈니스 아키텍처
#             - 전사 사업 모델(계획자 관점)
#             - 조직 모델(계획자 관점)
#             - 업무 기능 모델(책임자 관점)
#             - 프로세스 모델(설계자 관점)
#             - 업무 메뉴얼(개발자 관점)
#         - 애플리케이션 아키텍처
#             - 전사 애플리케이션 영역 모델(계획자 관점)
#             - 애플리케이션 모델(책임자 관점)
#             - 컴포넌트 모델, 클래스 모델(설계자 관점)
#             - 프로그램 목록(개발자 관점)
#         - 데이터 아키텍처
#             - 전사 데이터 영역 모델(계획자 관점)
#             - 개념 데이터 모델(책임자 관점)
#             - 논리 데이터 모델(설계자 관점)
#             - 물리 데이터 모델(개발자 관점)
#         - 기술 아키텍처
#             - 전사 기술 영역 모델, 기술 참조 모델(계획자 관점)
#             - 표준 프로파일(책임자 관점)
#             - 기술 아키텍처 모델
#             - 기술자원 목록, 제품 목록
#         - 전사아키텍처 프레임워크 사례
#             - ZEAF
#             - FEAF
#             - TEAF
#             - DODAF
#             - TOGAF
#             - 공공부분EAF
# * 전사아키텍처 참조 모델
#     - 참조 모델 정의
#         - 참조 모델 개념
#         - 참조 모델 현황
#             - 성과 참조 모델
#             - 업무 참조 모델
#             - 서비스 참조 모델
#             - 데이터 참조 모델
#             - 기술 참조 모델
#                 - 미연방TRM
#                 - 오픈그룹TRM
#                 - 가트너TRM
#                 - 정보화진흥원TRM
#         - 참조 모델 구축 방법
#     - 참조 모델 사례
#         - 업무 참조 모델
#         - 서비스 참조 모델
#         - 기술 참조 모델
#         - 데이터 참조 모델
#             - 범정부 데이터 모델
#             - 데이터 분류
#             - 데이터 구조
#             - 데이터 교환
#             - 데이터 관리
#         - 성과 참조 모델
#     - 참조 모델 활용
#         - 업무 참조 모델
#         - 데이터 참조 모델
#         - 서비스 참조 모델
#         - 기술 참조 모델
#         - 성과 참조 모델
# * 전사아키텍처 프로세스
#     - 전사아키텍처 프로세스 개요
#     - 전사아키텍처 프로세스 구성
#         - 전사아키텍처(EA) 비전 수립
#             - EA 방향 수립
#         - 전사아키텍처(EA) 구축
#             - EA 정보 구성 정의
#             - EA 정보 구축
#         - 전사아키텍처(EA) 관리 정의
#             - EA 관리 체계 구축
#             - EA 관리 시스템 구축
#         - 전사아키텍처(EA) 활용 정의
#             - EA 이행 계획
#             - EA 정보 활용

# %% [markdown]
# # 전사아키텍처 구축
# * 전사아키텍처 방향 수립
#     - 전사아키텍처 환경 분석
#         - 전사아키텍처 환경 분석 수행 과제
#             - 전사아키텍처 환경 분석 수행 과제
#             - 비즈니스 내/외부 환경 분석
#             - IT 내/외부 환경 분석
#             - 전사 범위 정의
#     - 전사아키텍처 구축 방향 정의
#         - 목적 및 범위 정의
#             - 상호운용성 증대
#             - 정보화 투자 의사결정 체계 구축
#             - 비즈니스 변화에 대한 신속한 대응체계 구축
#             - 전사적 정보화 표준 정립
#             - 고객 지향의 정보화 체계 구축
#         - 전사아키텍처 비전 수립
#             - 전사아키텍처 비전 구성 요소
#                 - 전사아키텍처 비전
#                 - 핵심목표
#                 - 핵심가치
#         - 전사아키텍처 프레임워크 정의
#             - 공공 부문 전사아키텍처 프레임워크 구성 요소
#                 - 방향/지침
#                     - 정보기술 정책
#                     - 전사아키텍처 전략
#                     - 아키텍처 원칙
#                     - 요구 사항
#                 - 전사아키텍처 활동
#                     - 아키텍처 모델
#                     - 생명주기
#                     - 지원 도구
#                 - 산출물
#                     - 아키텍처 산출물
# * 전사아키텍처 정보 구성
#     - 전사아키텍처 정보 구성 개요
#     - 아키텍처 매트릭스 정의
#         - 아키텍처 매트릭스 개념
#         - 아키텍처 매트릭스 구성
#             - 의사결정 유형
#             - 아키텍처 정보 유형
#         - 산출물 정의
#             - 공공 부문 아키텍처 매트릭스
#             - 공공 부문 아키텍처 산출물
#             - 매트릭스 셀 정의 내역
#                 - 현행 산출물 분석
#                 - 목표 산출물 정의
#                 - 산출물간 연관성 정의
#                 - 산출물 표현 방법 및 세부 구성 정의
#             - 전사아키텍처 정보 구성요소 정의
#                 - 전사아키텍처 정보 구성요소 연관관계
#             - 아키텍처 매트릭스 정의시 고려사항
#                 - 첫째
#                 - 둘째
#                 - 셋째
#                 - 넷째
#     - 참조 모델 정의
#     - 전사아키텍처 원칙 수립
#         - 전사아키텍처 원칙 구성 요소
#             - 원칙
#             - 의미
#             - 근거
#             - 기대효과
#         - 전사아키텍처 기본 원칙
#             - 업무 지향
#             - 성과 지향
#             - 고객 지향
#             - 상호운용
#         - 아키텍처 원칙
#             - 아키텍처
#             - 원칙
#             - 의미
#         - 전사아키텍처 원칙 고려사항
#             - 첫째
#             - 둘째
#             - 셋째
#             - 넷째
#             - 다섯째
# * 전사아키텍처 정보 구축
#     - 전사아키텍처 정보 구축 정비
#         - 자료 수집
#         - 전사아키텍처 정보 구축 방식
#     - 현행 아키텍처 정보 구축
#         - 현행 비즈니스 아키텍처 정보 구축
#             - 현행 비즈니스 아키텍처 정의 내역
#                 - 전사 사업모델 분석
#                 - 전사 모델 분석
#                 - 업무 기능 모델 정의
#                 - 프로세스 모델 정의
#                 - 업무 매뉴얼 파악
#         - 현행 애플리케이션 아키텍처 정보 구축
#             - 현행 애플리케이션 아키텍처 정의 내역
#                 - 전사 애플리케이션 영역 식별
#                 - 애플리케이션 모델 정의
#                 - 컴포넌트 모델 정의
#                 - 프로그램 목록 파악
#                 - 애플리케이션 원칙, 표준 파악
#          - 현행 데이터 아키텍처 정보 구축
#             - 현행 데이터아키텍처 정보 구축
#             - 현행 데이터아키텍처 정의 내역
#                 - 전사 데이터 영역 식별
#                 - 개념 데이터 모델 정의
#                 - 논리 데이터 모델 정의
#                 - 물리 데이터 모델 정의
#                 - 데이터베이스 객체 파악
#                 - 데이터 원칙, 표준, 관리 프로세스 파악
#          - 현행 기술 아키텍처 정보 구축
#             - 현행 기술 아키텍처 정보 구축
#             - 현행 기술 아키텍처 정의 내역
#                 - 전사 기술영역 식별
#                 - 기술 참조 모델 정의
#                 - 기술 표준 분석
#                 - 기술 아키텍처 요소 식별
#                 - 기술자원 목록, 제품 목록 파악
#     - 목표 아키텍처 정보 구축
#         - 목표 비즈니스 아키텍처 정보 구축
#             - 목표 비즈니스 아키텍처 정의 내역
#                 - 전사 사업 모델 정의
#                 - 조직 모델 정의
#                 - 업무 기능 모델 정의
#                 - 프로세스 모델 정의
#                 - 업무 메뉴얼 정보 구축
#         - 목표 애플리케이션 아키텍처 정보 구축
#             - 목표 애플리케이션 아키텍처 정의 내역
#                 - 전사 애플리케이션 영역 모델 정의
#                 - 애플리케이션 모델 정의
#                 - 컴포넌트 모델 정의
#                 - 프로그램 목록 정보 구축
#         - 목표 데이터 아키텍처 정보 구축
#             - 목표 데이터 아키텍처 정의 내역
#                 - 전사 데이터 영역 모델 정의
#                 - 개념 데이터 모델 정의
#                 - 논리 데이터 모델 정의
#                 - 물리 데이터 모델 정의
#                 - 데이터베이스 개체 정보 구축
#                 - 데이터 원칙, 표준, 관리 프로세스 정의
#         - 목표 기술 아키텍처 정보 구축
#             - 목표 기술 아키텍처 정의 내역
#                 - 전사 기술 영역 모델 정의
#                 - 기술 참조 모델 정의
#                 - 표준 프로파일 정의
#                 - 기술 아키텍처 모델 정의
#                 - 기술자원 목록, 제품 목록 정보 구축

# %% [markdown]
# # 전사아키텍처 관리 및 활용
# * 전사아키텍처 관리 체계
#     - 전사아키텍처 체계 개요
#         - 전사아키텍처 관리 체계 개념
#             - IT 관리 체계와 전사아키텍처 관리 체계
#         - 전사아키텍처 관리 체계 구축 방향
#             - 정의된 전사아키텍처 조직 체계, 프로세스 체계 등을 문서화하여 전 조직이 준수할 수 있도록 제도화 한다.
#             - 전사아키텍처 관련 제반 이해당사자의 전사아키텍처 인지도 향상 및 업무 수행시 전사아키텍처정보 활용도 증진을 위한 적절한 교육 프로그램을 제공한다.
#             - 목표 아키텍처로의 전환, 정보자원 관리의 혁신 등 전사아키텍처 도입에 따른 변화 관리를 위한 종합적인 프로그램을 운영한다.
#             - 전사아키텍처 관리 체계를 주기적으로 점검하여 개선점을 도출하여 반영할 수 있도록 제도적 장치를 마련한다.
#             - 전사아키텍처 관리 시스템을 활용도와 만족도를 주기적으로 점검하여 시스템의 품질을 지속적으로 개선해 나간다.
#     - 전사아키텍처 관리 조직 체계
#         - 전사아키텍처 관리 조직 개요
#             - 전사아키텍처 담당 인원
#             - 전사아키텍처 아키텍트
#             - 전사아키텍처 영역별 담당자
#             - 전사아키텍처 관리시스템 관리자
#             - 전사아키텍처 추진 위원회
#         - 전사아키텍처 관리 조직의 정의
#             - IT 조직의 규모
#                 - 전사아키텍처 관리 조직을 별도 조직으로 구성할 수 없는 중소 규모의 IT 조직은 전사아키텍처 관리 운영위원회 중심으로 전사아키텍처 관리 조직을 정의하고 전사아키텍처 전담 인력을 양성한다.
#                 - 전사아키텍처 관리 조직을 별도 조직으로 구성할 수 있는 대규모의 IT 조직은 전사아키텍처 관리 전담 조직을 신설하고, 전사아키텍처 관리 운영위원회를 통해 전사적으로 의사결정을 공유할 수 있는 조직 체계를 정의한다.
#             - 전사아키텍처 구축의 목적
#                 - 전사아키텍처 구축 목적이 순수하게 아키텍처 관리와 IT 표준화 등을 위한 것이면 전사 아키텍처와 IT 표준을 통합 관리할 수 있는 전사아키텍처 관리 조직을 정의한다.
#                 - 전사아키텍처 구축 목적이 신시스템 구축을 위한 계획 수립이면, 프로젝트 기간 중 전사아키텍처 정보를 관리할 수 있는 조직이 필요하다. 전사아키텍처 정보 중심으로 프로젝트를 관리할 수 있는 PMO와 전사아키텍처 관리 전담 조직을 정의한다.
#             - IT 조직과 현업과의 관계
#                 - 현업과 IT 조직간의 의사소통 문제가 있을 경우 현업의 요건을 종합적으로 관리하는 조직을 추가로 정의한다.
#     - 전사아키텍처 관리 프로세스
#         - 전사아키텍처 관리 프로세스 개요
#             - 전사아키텍처 기획
#             - 전사아키텍처 변경 기획
#             - 전사아키텍처 준수 통제
#             - 전사아키텍처 활용 지원
#             - 전사아키텍처 관리 시스템 관리
#             - 전사아키텍처 평가
#         - 전사아키텍처 관리 프로세스 구성
#     - 전사아키텍처 관리 이력
#         - 전사아키텍처 관리 인력 개요
#         - 전사아키텍처 전문가 육성
# * 전사아키텍처 관리 시스템
#     - 전사아키텍처 관리 시스템
#         - 전사아키텍처 관리 시스템 개요
#     - 전사아키텍처 정보 정의 도구
#     - 전사아키텍처 정보 관리 시스템
#         - 첫째
#             - 아키텍처 정보를 공유할 수 있어 해당 조직의 각 아키텍처 요소에 대해 이해 관계자들이 정확하게 파악할 수 있다.
#         - 둘째
#             - 의사소통 도구로 전사아키텍처 관리 시스템을 활용할 수 있다.
#         - 셋째
#             - 전사아키텍처 관리 시스템을 의사결정 도구로 활용할 수 있다.
# * 전사아키텍처 활용
#     - 전사아키텍처 활용 개요
#         - 목표 아키텍처 이행 계획
#         - 전사아키텍처 정보 상시 활용
#     - 목표 아키텍처 이행 계획
#         - 아키텍처 차이(GAP) 분석
#         - 프로젝트 정의
#         - 이행 전략 수립
#         - 변화관리 계획 수립
#     - 전사아키텍처 정보 상시 활용
#         - 전사아키텍처 정보 활용 영역
#             - IT 기획 관리
#             - IT 구축 관리
#             - IT 운영 및 통제
#     - 전사아키텍처 효과적 활용 방안
#         - 전사아키텍처 정보 자체의 품질이 보장되어야 한다.
#         - 전사아키텍처 정보를 관리하고 적용을 통제할 수 있는 전담 조직이 구성,운영되어야 한다.
#         - 전사아키텍처 정보를 전사적으로 공유하고 활용할 수 있는 절차와 시스템이 필요하다.
#     - 전사아키텍처와 데이터아키텍처 전문가 영역
#         - 전사아키텍처와 데이터아키텍처 프레임워크
#         - 전사아키텍처와 데이터아키텍처
#             - 범위 통합
#             - 수평 통합
#             - 수직 통합
