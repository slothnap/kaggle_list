# %% [markdown]
# ## 전사아키텍처 이해
# ### 문제: p28 ~ p38
# ### 문항: 1 ~ 40
# ### 답  : p156 ~ p160
# ---------------------------------------------------------------------------
# ## 데이터 요건 분석
# ### 문제: p42 ~ p52
# ### 문항: 41 ~ 80
# ### 답  : p160 ~ p164
# ---------------------------------------------------------------------------
# ## 데이터 표준화
# ### 문제: p56 ~ p63
# ### 문항: 81 ~ 120
# ### 답  : p164 ~ p167
# ---------------------------------------------------------------------------
# ## 데이터 모델링
# ### 문제: p66 ~ p101
# ### 문항: 121 ~ 260
# ### 답  : p167 ~ p178
# ---------------------------------------------------------------------------
# ## 데이터베이스 설계와 이용
# ### 문제: p104 ~ p131
# ### 문항: 261 ~ 340
# ### 답  : p178 ~ p185
# ---------------------------------------------------------------------------
# ## 데이터 품질 관리 이해
# ### 문제: p134 ~ p145
# ### 문항: 341 ~ 395
# ### 답  : p185 ~ p190
