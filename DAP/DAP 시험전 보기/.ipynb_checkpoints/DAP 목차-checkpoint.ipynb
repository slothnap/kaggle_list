# %% [markdown]
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 전사아키텍처 이해
# 1. 전사아키텍처와 데이터아키텍처 (p45)
#     - 아키텍처 개요
#     - 아키텍처 프레임워크
#     - 데이터아키텍처 참조모델
#     - 데이터아키텍처 프로세스
#     - 데이터아키텍트
# 2. 데이터아키텍처 구축 (p104)
#     - 데이터아키텍처 방향 수립
#     - 데이터아키텍처 정보 구성 정의
#     - 데이터아키텍처 구축 프로세스
# 3. 데이터 거버넌스 (p136)
#     - 데이터 거버넌스 개요
#     - 데이터 거버넌스 구성
#     - 데이터 거버넌스 운영
#     - 데이터 거버넌스 확장
# * 책 문제
# 	- 전사아키텍처와 데이터아키텍처 (p100)
# 	- 데이터아키텍처 구축          (p132)
# 	- 데이터 거버넌스              (p173)
# * 실전 문제
#     - 문제: p28 ~ p38
# 	- 문항: 1 ~ 40
# 	- 답  : p156 ~ p160
#
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 데이터 요건 분석
# 1. 정보 요구 사항 개요 (p175)
#     - 정보 요구 사항
#     - 정보 요구 사항 관리
# 2. 정보 요구 사항 조사 (p191)
#     - 정보 요구 사항 수집
#     - 정보 요구 사항 정리
#     - 정보 요구 사항 통합
# 3. 정보 요구 사항 분석 (p217)
#     - 분석 대상 정의
#     - 정보 요구 사항 상세화
#     - 정보 요구 사항 확인
# 4. 정보 요구 사항 명세화 (p237)
#     - 정보 요구 사항 명세 정의
#     - 정보 요구 사항 명세 상세화
# 5. 정보 요구 사항 검증 및 변경 관리 (p247)
#     - 정보 요구 사항 검증 정의
#     - 정보 요구 사항 상관분석 기법
#     - 추가 및 삭제 정보 요구 사항 도출
#     - 정보 요구 사항 변경 관리
# * 책 문제
# 	- 정보 요구 사항 개요         (p189)
# 	- 정보 요구 사항 조사         (p214)
# 	- 정보 요구 사항 분석         (p235)
# 	- 정보 요구 사항 명세화       (p244)
# 	- 정보 요구 검증 및 변경 관리 (p260)
# * 실전 문제
# 	- 문제: p42 ~ p52
# 	- 문항: 41 ~ 80
# 	- 답  : p160 ~ p164
#
#
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 데이터 표준화
# 1. 데이터 표준화 필요성 (p266)
#     - 데이터 표준화 필요성
#     - 데이터 표준화 개념
#     - 데이터 표준 관리 도구
# 2. 데이터 표준 수립 (p283)
#     - 데이터 표준화 원칙 정의
#     - 데이터 표준 정의
#     - 데이터 표준 확정
# 3. 데이터 표준 관리 (p311)
#     - 데이터 표준 관리
#     - 데이터 표준 관리 프로세스
# * 책 문제
# 	- 데이터 표준화 필요성 (p281)
# 	- 데이터 표준 수립     (p309)
# 	- 데이터 표준 관리     (p317)
# * 실전 문제
# 	- 문제: p56 ~ p63
# 	- 문항: 81 ~ 120
# 	- 답  : p164 ~ p167
#
#
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 데이터 모델링
# 1. 데이터 모델링 이해 (p322)
#     - 데이터 모델링 개요
#     - 데이터 모델링 기법 이해
#     - 데이터 모델링 표기법 이해
#     - 관계형 모델 이론
# 2. 데이터 모델링 (p382)
#     - 논리 데이터 모델링 이해
#     - 주제 영역 정의
#     - 엔터티 정의
#     - 관계 정의
#     - 속성 정의
#     - 식별자 확정
#     - 정규화
#     - 이력 관리
#     - 논리 데이터 모델 품질 검토
# 3. 물리 데이터 모델링 (p482)
#     - 물리 데이터 모델링 이해
#     - 물리 요소 조사 및 분석
#     - 논리-물리모델 변환
#     - 반정규화
#     - 물리 데이터 모델 품질 검토
# * 책 문제
# 	- 데이터 모델링 이해 (p378)
# 	- 데이터 모델링      (p478)
# 	- 물리 데이터 모델링 (p526)
# * 실전 문제
# 	- 문제: p66 ~ p101
# 	- 문항: 121 ~ 260
# 	- 답  : p167 ~ p178
#
#
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 데이터베이스 설계와 이용
# 1. 데이터베이스 설계 (p531)
#     - 저장 공간 설계
#     - 무결성 설계
#     - 인덱스 설계
#     - 분산 설계
#     - 보안 설계
#
# 2. 데이터베이스 이용 (p577)
#     - 데이터베이스 관리 시스템 (DBMS)
#     - 데이터베이스 관리 시스템 활용
#     - 트랜잭션
#     - 성능 개선 방법론
#     - 애플리케이션 성능 개선
#     - 서버 성능 개선
# * 책 문제
# 	- 데이터베이스 설계 (p574)
# 	- 데이터베이스 이용 (p634)
# * 실전 문제
# 	- 문제: p104 ~ p131
# 	- 문항: 261 ~ 340
# 	- 답  : p178 ~ p185
#
#
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------
# ## 데이터 품질 관리이해
# 1. 데이터 품질 관리 이해 (p639)
#     - 데이터 품질 관리 프레임워크
#     - 표준 관점 데이터 품질
#     - 모델 관점 데이터 품질
#     - 값(Value) 관점 데이터 품질
#     - 활용 관점 데이터 품질
# 2. 데이터 관리 프로세스 이해 (p659)
#     - 데이터 품질 관리 정책
#     - 데이터 표준 품질 관리 프로세스
#     - 데이터 모델 품질 관리 프로세스
#     - 데이터 값(Value) 품질 관리 프로세스
#     - 데이터 활용 관리 프로세스
# * 책 문제
# 	- 데이터 품질 관리 이해          (p656)
# 	- 데이터 품질 관리 프로세스 이해 (p695)
# * 실전 문제
# 	- 문제: p134 ~ p145
# 	- 문항: 341 ~ 395
# 	- 답  : p185 ~ p190
